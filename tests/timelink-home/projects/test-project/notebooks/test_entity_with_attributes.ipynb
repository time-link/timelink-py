# %% [markdown]
# # group_attributes

# %%
# NBVAL_IGNORE_OUTPUT
from timelink.notebooks import TimelinkNotebook
import logging
# Set up logging to capture output in the notebook
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s - %(name)s')
tlnb = TimelinkNotebook(db_type="sqlite", db_name="group_attribute")
tlnb.print_info()
# Out:
# 2026-01-30 19:59:56,701 - INFO - Database is healthy - root
# 2026-01-30 19:59:56,703 - INFO - Context impl SQLiteImpl. - alembic.runtime.migration
# 2026-01-30 19:59:56,704 - INFO - Will assume non-transactional DDL. - alembic.runtime.migration
# 2026-01-30 19:59:56,759 - WARNING - Reusing existing container busy_kowalevski - root
# 2026-01-30 19:59:56,766 - INFO - Kleio server started successfully - root
# Timelink version: 1.1.30
# Project name: test-project
# Project home: /Users/jrc/develop/timelink-py-worktrees/issue-88/tests/timelink-home/projects/test-project
# Database type: sqlite
# Database name: group_attribute
# Kleio image: timelinkserver/kleio-server
# Kleio server token: 3iuR0...
# Kleio server URL: http://127.0.0.1:8088
# Kleio server home: /Users/jrc/develop/timelink-py-worktrees/issue-88/tests/timelink-home/projects/test-project
# Kleio server container: busy_kowalevski
# Kleio version requested: latest
# Kleio server version: 12.9.588 (2025-06-06 16:04:22)
# SQLite directory: /Users/jrc/develop/timelink-py-worktrees/issue-88/tests/timelink-home/projects/test-project/database/sqlite
# Database version: 6ccf1ef385a6
# Call print_info(show_token=True) to show the Kleio Server token
# Call print_info(show_password=True) to show the Postgres password
# TimelinkNotebook(project_name=test-project, project_home=/Users/jrc/develop/timelink-py-worktrees/issue-88/tests/timelink-home/projects/test-project, db_type=sqlite, db_name=group_attribute, kleio_image=timelinkserver/kleio-server, kleio_version=latest, postgres_image=postgres, postgres_version=latest)

# %% [markdown]
# # Import data

# %%
test_files_path = "sources/reference_sources/linked_data/"
tlnb.get_kleio_files(path=test_files_path)[['name', 'path']]
# Out:
#                           name  \
# 0       dehergne-a-partial.cli
# 1  dehergne-locations-1644.cli
#
#                                                 path
# 0  sources/reference_sources/linked_data/dehergne...
# 1  sources/reference_sources/linked_data/dehergne...

# %%
# NBVAL_IGNORE_OUTPUT


db = tlnb.db
db.update_from_sources(test_files_path, force=True)
# Out:
# 2026-01-30 19:59:56,832 - INFO - Request translation of V sources/reference_sources/linked_data/dehergne-a-partial.cli - root
# 2026-01-30 19:59:56,837 - INFO - Request translation of V sources/reference_sources/linked_data/dehergne-locations-1644.cli - root
# 2026-01-30 20:00:01,834 - INFO - Importing sources/reference_sources/linked_data/dehergne-a-partial.cli - root
# /Users/jrc/develop/timelink-py-worktrees/issue-88/timelink/api/models/pom_som_mapper.py:697: UserWarning: Ambiguous mapping! more than one element of rel is mapped to column class date check mapping for this group
#   element: KElement = group.get_element_by_name_or_class(cattr.colclass)
# 2026-01-30 20:00:04,373 - INFO - Importing sources/reference_sources/linked_data/dehergne-locations-1644.cli - root

# %% [markdown]
# # Usages of entities_with_attribute

# %% [markdown]
# ## Every person with a given attribute type
#
# For every person with attribute jesuita-entrada show birth place and nationality

# %%
from timelink.pandas.group_attributes import group_attributes
from timelink.pandas import entities_with_attribute

# Get list of people with with a certain value in a specific attribute
df = entities_with_attribute(
    entity_type='person',
    show_elements=['name','groupname'],
    the_type='jesuita-entrada',
    more_attributes=['nacionalidade','nascimento'],
    db=tlnb.db,
)
# df.info()
ids = list(df.index.unique())
print(len(ids),ids)
# choose the cols to show
cols = ['name','groupname','jesuita-entrada','jesuita-entrada.comment','jesuita-entrada.date','jesuita-entrada.date.comment','nacionalidade','nascimento', 'nascimento.date']
df[cols].sort_values(['jesuita-entrada','jesuita-entrada.comment','jesuita-entrada.date']).head(50)
# Out:
# 16 ['deh-pedro-de-alcacova', 'deh-antonio-de-abreu-ref1', 'deh-antonio-de-abreu', 'deh-johann-alberich', 'deh-gil-de-abreu', 'deh-pierre-albier', 'deh-joao-de-abreu', 'deh-afonso-aires', 'deh-afonso-aires-ref1', 'deh-joao-de-abreu-ref1', 'deh-adam-algenler', 'deh-ludovico-antonio-adorno', 'deh-bento-de-abreu-ref1', 'deh-francisco-alberto', 'deh-manuel-de-aguiar', 'deh-joseph-de-aguiar-souen']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 17
#      15 # choose the cols to show
#      16 cols = ['name','groupname','jesuita-entrada','jesuita-entrada.comment','jesuita-entrada.date','jesuita-entrada.date.comment','nacionalidade','nascimento', 'nascimento.date']
# ---> 17 df[cols].sort_values(['jesuita-entrada','jesuita-entrada.comment','jesuita-entrada.date']).head(50)
#
# File ~/develop/timelink-py-worktrees/issue-88/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/develop/timelink-py-worktrees/issue-88/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/develop/timelink-py-worktrees/issue-88/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['jesuita-entrada.date.comment'] not in index"

# %% [markdown]
# ## entities with a series of attributes

# %%
from timelink.pandas import entities_with_attribute

# Get list of people with with a certain value in a specific attribute
df = entities_with_attribute(
    entity_type='person',
    show_elements=['name','groupname'],
    the_type=['nascimento','jesuita-entrada','partida','chegada','estadia','jesuita-votos-local','morte'],
    column_name='lugares',
    more_attributes=[],
    db=tlnb.db,
)
ids = list(df.index.unique())
print(len(ids),ids)
df.reset_index(inplace=True)
# df.info()
df.fillna('',inplace=True)
# choose the cols to show
cols = ['id','name','groupname','lugares.type','lugares','lugares.comment','lugares.line','lugares.date','lugares.date.comment']
df[cols].sort_values(['name','id','lugares.line']).head(50)
# Out:
# 86 ['deh-ludovico-antonio-adorno', 'deh-ignacio-xavier-de-aguado', 'deh-adam-algenler', 'deh-pierre-albier', 'deh-pedro-de-alcacova', 'deh-pedro-de-alcacova-ref1', 'deh-hernando-de-alcaraz', 'deh-giulio-aleni', 'deh-michel-alfonso-chen', 'deh-antonio-de-almeida', 'deh-jose-estevao-de-almeida', 'deh-sebastiao-de-almeida', 'deh-domingos-alvares', 'deh-goncalo-alvares', 'deh-miguel-do-amaral', 'deh-paolo-agostino-amoretti', 'deh-antonio-de-andrade', 'deh-jose-de-araujo', 'deh-juan-antonio-arnedo', 'deh-jose-ramon-arxo', 'deh-humbert-augery', 'deh-philippe-avril', 'deh-philippe-avril-ref2', 'deh-manuel-de-azevedo', 'deh-luis-de-almeida', 'deh-domingos-alvares-ref1', 'deh-simao-antunes-ref2', 'deh-diogo-antunes', 'deh-antonio-de-abreu-ref1
# 122  deh-antonio-de-abreu-ref2       António de Abreu  referido
# 118      deh-joao-alberto-ref1       António de Abreu  referido
# 120     deh-simao-antunes-ref1       António de Abreu  referido
# 68      deh-antonio-de-almeida     António de Almeida         n
# 83      deh-antonio-de-almeida     António de Almeida         n
# 93      deh-antonio-de-almeida     António de Almeida         n
# 94      deh-antonio-de-almeida     António de Almeida         n
# 95      deh-antonio-de-almeida     António de Almeida         n
# 16      deh-antonio-de-almeida     António de Almeida         n
# 99      deh-antonio-de-almeida     António de Almeida         n
# 101     deh-antonio-de-almeida     António de Almeida         n
# 100     deh-antonio-de-almeida     António de Almeida         n
# 102     deh-antonio-de-almeida     António de Almeida         n
# 103     deh-antonio-de-almeida     António de Almeida         n
# 104     deh-antonio-de-almeida     António de Almeida         n
# 105     deh-antonio-de-almeida     António de Almeida         n
# 89      deh-antonio-de-andrade     António de Andrade         n
# 108     deh-antonio-de-andrade     António de Andrade         n
# 27      deh-antonio-de-andrade     António de Andrade         n
# 28      deh-antonio-de-andrade     António de Andrade         n
# 138     deh-antonio-de-andrade     António de Andrade         n
# 140     deh-antonio-de-andrade     António de Andrade         n
# 29      deh-antonio-de-andrade     António de Andrade         n
# 30      deh-antonio-de-andrade     António de Andrade         n
# 124     deh-antonio-de-andrade     António de Andrade         n
# 146     deh-antonio-de-andrade     António de Andrade         n
# 330  deh-bartolomeu-de-azevedo  Bartolomeu de Azevedo         n
#
#             lugares.type                                           lugares  \
# 145           nascimento          Tramin, diocese de Trento, Tirol, Itália
# 179      jesuita-entrada                                                 ?
# 3                estadia                                            Brasil
# 223  jesuita-votos-local                              Ingolstadt, Alemanha
# 227                morte                      [No mar, a caminho da China]
# 142           nascimento                                          Santarém
# 170      jesuita-entrada                                           Coimbra
# 189                morte         [No mar, depois do Cabo da Boa Esperança]
# 342           nascimento                                            Lisboa
# 375      jesuita-entrada                                                 ?
# 392              estadia                                               Goa
# 393              estadia                                             China
# 406              estadia                                             Hunan
# 414              estadia                                           Wuchang
# 423                morte                                           Hukwang
# 143           nascimento                                          Santarém
# 171      jesuita-entrada                                                 ?
# 169              estadia                                           Coimbra
# 86       jesuita-entrada                                        Goa, Índia
# 110  jesuita-votos-local                               Negapattinam, Índia
# 116                morte                                  Changchow, China
# 71            nascimento                                            Lisboa
# 82       jesuita-entrada                                           Coimbra
# 122                morte                                   Coulam, Malabar
# 118                morte                    Fukien (Rio de «Tchin-tcheou»)
# 120                morte                    Fukien (Rio de «Tchin Tcheou»)
# 68            nascimento                        Trancoso, diocese de Viseu
# 83       jesuita-entrada                                                 ?
# 93               estadia                                             Macau
# 94               estadia                                            Cantão
# 95               estadia     «Ciquione» (Shaoshing, Chao-hing), Tchö-kiang
# 16               estadia                                             Macau
# 99               estadia   «Sciaochino» (Shiuhing, Tchao-k'ing), Kwangtung
# 101              estadia   «Sciaochino» (Shiuhing, Tchao-k'ing), Kwangtung
# 100              estadia  Kwangtung, (Residência de Shiuchow, Chao-tcheou)
# 102              estadia                                             Macau
# 103              estadia                                             Macau
# 104              estadia                                          Shiuchow
# 105                morte                                          Shiuchow
# 89            nascimento                    Oleiros, diocese de Portalegre
# 108      jesuita-entrada                                           Coimbra
# 27               estadia                                             Índia
# 28               estadia                                              Agra
# 138              estadia                                            Tibete
# 140              estadia                                            Tibete
# 29               estadia                                         Himalaias
# 30               estadia                                 Tsaparang, Tibete
# 124  jesuita-votos-local                                               Goa
# 146                morte                                               Goa
# 330           nascimento                                  Viana do Castelo
#
#                                        lugares.comment  lugares.line  \
# 145        Tramin an der Weinstraße? @wikidata:Q499114           152
# 179                                                              153
# 3                                                                154
# 223                                    @wikidata:Q3004           161
# 227                                                              162
# 142                                  @wikidata:Q273877           174
# 170                                   @wikidata:Q45412           175
# 189                                                              181
# 342                                     @wikidata:Q597          1211
# 375                                                             1212
# 392                                    @wikidata:Q1171          1213
# 393                                     @wikidata:Q148          1215
# 406                                                             1216
# 414                                                             1217
# 423                                                             1219
# 143                                  @wikidata:Q273877           188
# 171                                                              189
# 169                                   @wikidata:Q45412           190
# 86                                     @wikidata:Q1171            11
# 110                                  @wikidata:Q695585            16
# 116        no rio, a caminho do Japão @wikidata:Q57970            17
# 71                                      @wikidata:Q597            24
# 82                                    @wikidata:Q45412            25
# 122                        Naufrágio @wikidata:Q321475            30
# 118                                 A caminho do Japão           248
# 120                                 A caminho do Japão           977
# 68                                   @wikidata:Q686868           402
# 83                                                               403
# 93                                    @wikidata:Q14773           407
# 94                                    @wikidata:Q16572           408
# 95                                                               409
# 16                                    @wikidata:Q14773           410
# 99                                                               411
# 101                                                              412
# 100                                                              413
# 102                                   @wikidata:Q14773           414
# 103                                   @wikidata:Q14773           415
# 104                                                              416
# 105                                                              418
# 89                                  @wikidata:Q1012719           884
# 108                                   @wikidata:Q45412           885
# 27                                      @wikidata:Q668           889
# 28                                    @wikidata:Q42941           890
# 138                                   @wikidata:Q17252           893
# 140                                   @wikidata:Q17252           894
# 29   o primeiro Europeu a visitar os Himalaias @wik...           895
# 30                                  @wikidata:Q2658740           896
# 124                                    @wikidata:Q1171           901
# 146                                    @wikidata:Q1171           902
# 330                                  @wikidata:Q208158          1290
#
#     lugares.date                               lugares.date.comment
# 145     16331014
# 179     16531014
# 3              0
# 223     16710202
# 227     16730826          de peste contraída ao serviço dos doentes
# 142     16300000
# 170     16490000
# 189     16570000
# 342     17250808
# 375     17451207
# 392     17520000
# 393     17520000
# 406     17610000
# 414     17670000
# 423     17880000  segundo carta de P. António de Gouveia de 1788...
# 143     16300000
# 171     16490000
# 169     16490000
# 86      15791200
# 110     16040106
# 116     16110000
# 71      15610000
# 82      15760000
# 122     16111031
# 118     16110000                               com António de Abreu
# 120     16110000
# 68      15570000
# 83      15760104
# 93      15850731
# 94      15851008
# 95      15860123
# 16             0
# 99      15880800
# 101     15890800
# 100     15890000
# 102     15900000                                     fim de, doente
# 103     15910900                                                até
# 104     15910900                                          depois de
# 105     15911017                                        ou 15911200
# 89      15800000
# 108     15961216
# 27             0
# 28             0
# 138     16240000
# 140     16250000
# 29             0
# 30             0
# 124     16121014
# 146     16340319                                         envenenado
# 330     17180824
