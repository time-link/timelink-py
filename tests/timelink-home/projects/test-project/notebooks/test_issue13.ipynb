# %% [markdown]
# # Issue[#13](https://github.com/time-link/timelink-py/issues/13)

# %%
# NBVAL_IGNORE_OUTPUT
from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook(db_name="issue13")
tlnb.print_info()
# Out:
# Project name: test-project
# Project home: /workspaces/timelink-py/tests/timelink-home/projects/test-project
# Database type: sqlite
# Database name: issue13
# Kleio image: timelinkserver/kleio-server
# Kleio version: latest
# Kleio server token: ehZc6csQVMlDJCVJxa3bXQ7xZJCvT3lL
# Kleio server URL: http://127.0.0.1:8088
# Kleio server home: /workspaces/timelink-py/tests/timelink-home/projects/test-project
# SQLite directory: /workspaces/timelink-py/tests/timelink-home/projects/test-project/database/sqlite
# TimelinkNotebook(project_name=test-project, project_home=/workspaces/timelink-py/tests/timelink-home/projects/test-project, db_type=sqlite, db_name=issue13, kleio_image=timelinkserver/kleio-server, kleio_version=latest, postgres_image=postgres, postgres_version=latest)

# %% [markdown]
# ### Import file

# %%
from timelink.api.database import import_from_xml

db = tlnb.db
with db.session() as session:
    import_from_xml( "../../../../xml_data/dehergne-a.xml",session)

# %% [markdown]
# ### Show imported source

# %%
from timelink.api.models import Source

with tlnb.db.session() as session:
    sources = session.query(Source).order_by(Source.id).all()
    for source in sources:
        print(str(source).split()[0])
# Out:
# fonte$dehergne-a/0/type=Dicionário

# %% [markdown]
# ## Use entities from attributes

# %%
from timelink.pandas import entities_with_attribute

# Get list of people with with a certain value in a specific attribute
df = entities_with_attribute(
                    entity_type='person',
                    the_type='estadia',
                    the_value='Macau',
                    dates_in=(1580, 1644),
                    show_elements=['name'],
                    more_attributes=['nacionalidade','jesuita-entrada'],
                    db=tlnb.db,
                    sql_echo=True)
df.info()
# Out:
# Query for estadia:
#  SELECT persons.id, persons.name, attributes.the_value AS estadia, attributes.the_date AS "estadia.date", attributes.obs AS "estadia.obs"
# FROM entities JOIN persons ON entities.id = persons.id JOIN attributes ON attributes.entity = persons.id
# WHERE attributes.the_type LIKE :the_type_1 AND attributes.the_value LIKE :the_value_1 AND attributes.the_date > :the_date_1 AND attributes.the_date < :the_date_2 ORDER BY attributes.the_date
# Query for more_attributes=nacionalidade:
#  SELECT attributes.entity AS id, attributes.the_value AS nacionalidade, attributes.the_date AS "nacionalidade.date", attributes.obs AS "nacionalidade.obs"
# FROM attributes
# WHERE attributes.the_type = :the_type_1 AND attributes.entity IN (__[POSTCOMPILE_entity_1])
# Query for more_attributes=jesuita-entrada:
#  SELECT attributes.entity AS id, attributes.the_value AS "jesuita-entrada", attributes.the_date AS "jesuita-entrada.date", attributes.obs AS "jesuita-entrada.obs"
# FROM attributes
# WHERE attributes.the_type = :the_type_1 AND attributes.entity IN (__[POSTCOMPILE_entity_1])
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, deh-antonio-de-almeida to deh-luis-de-almeida-ref2
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  9 non-null      object
#  1   estadia               9 non-null      object
#  2   estadia.date          9 non-null      object
#  3   estadia.obs           0 non-null      object
#  4   nacionalidade         8 non-null      object
#  5   nacionalidade.date    8 non-null      object
#  6   nacionalidade.obs     0 non-null      object
#  7   jesuita-entrada       8 non-null      object
#  8   jesuita-entrada.date  8 non-null      object
#  9   jesuita-entrada.obs   0 non-null      object
# dtypes: object(10)
# memory usage: 792.0+ bytes

# %%
df[["name","nacionalidade","jesuita-entrada", "estadia","estadia.date","jesuita-entrada"]]
# Out:
#                                                      name nacionalidade  \
# id
# deh-antonio-de-almeida                 António de Almeida      Portugal
# deh-antonio-de-almeida                 António de Almeida      Portugal
# deh-antonio-de-almeida                 António de Almeida      Portugal
# deh-diogo-antunes                           Diogo Antunes      Portugal
# deh-gaspar-do-amaral                     Gaspar do Amaral      Portugal
# deh-gaspar-do-amaral                     Gaspar do Amaral      Portugal
# deh-giulio-aleni                             Giulio Aleni        Itália
# deh-giulio-aleni                             Giulio Aleni        Itália
# deh-luis-de-almeida-ref2  Belchior Miguel Carneiro Leitão           NaN
#
#                          jesuita-entrada estadia estadia.date jesuita-entrada
# id
# deh-antonio-de-almeida                 ?   Macau     15850731               ?
# deh-antonio-de-almeida                 ?   Macau     15900000               ?
# deh-antonio-de-almeida                 ?   Macau     15910900               ?
# deh-diogo-antunes                  Évora   Macau     15870000           Évora
# deh-gaspar-do-amaral                   ?   Macau     16400000               ?
# deh-gaspar-do-amaral                   ?   Macau     16420000               ?
# deh-giulio-aleni               Novellara   Macau     16100000       Novellara
# deh-giulio-aleni               Novellara   Macau     16390000       Novellara
# deh-luis-de-almeida-ref2             NaN   Macau     15800000             NaN

# %%
from timelink.pandas import entities_with_attribute

# Get list of people with with a certain value in a specific attribute
df = entities_with_attribute(
                    entity_type='person',
                    the_type='nacionalidade',
                    the_value='Portugal',
                    show_elements=['name','sex'],
                    more_attributes=['nascimento','jesuita-entrada','wicky'],
                    name_like='%Almeida%',
                    db=tlnb.db,
                    sql_echo=True)
df.info()
# Out:
# Query for nacionalidade:
#  SELECT persons.id, persons.name, persons.sex, attributes.the_value AS nacionalidade, attributes.the_date AS "nacionalidade.date", attributes.obs AS "nacionalidade.obs"
# FROM entities JOIN persons ON entities.id = persons.id JOIN attributes ON attributes.entity = persons.id
# WHERE attributes.the_type LIKE :the_type_1 AND attributes.the_value LIKE :the_value_1 AND persons.name LIKE :name_1 ORDER BY attributes.the_date
# Query for more_attributes=nascimento:
#  SELECT attributes.entity AS id, attributes.the_value AS nascimento, attributes.the_date AS "nascimento.date", attributes.obs AS "nascimento.obs"
# FROM attributes
# WHERE attributes.the_type = :the_type_1 AND attributes.entity IN (__[POSTCOMPILE_entity_1])
# Query for more_attributes=jesuita-entrada:
#  SELECT attributes.entity AS id, attributes.the_value AS "jesuita-entrada", attributes.the_date AS "jesuita-entrada.date", attributes.obs AS "jesuita-entrada.obs"
# FROM attributes
# WHERE attributes.the_type = :the_type_1 AND attributes.entity IN (__[POSTCOMPILE_entity_1])
# Query for more_attributes=wicky:
#  SELECT attributes.entity AS id, attributes.the_value AS wicky, attributes.the_date AS "wicky.date", attributes.obs AS "wicky.obs"
# FROM attributes
# WHERE attributes.the_type = :the_type_1 AND attributes.entity IN (__[POSTCOMPILE_entity_1])
# <class 'pandas.core.frame.DataFrame'>
# Index: 13 entries, deh-afonso-aires-ref1 to deh-simao-de-almeida-ref1
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  13 non-null     object
#  1   sex                   13 non-null     object
#  2   nacionalidade         13 non-null     object
#  3   nacionalidade.date    13 non-null     object
#  4   nacionalidade.obs     0 non-null      object
#  5   nascimento            12 non-null     object
#  6   nascimento.date       12 non-null     object
#  7   nascimento.obs        0 non-null      object
#  8   jesuita-entrada       12 non-null     object
#  9   jesuita-entrada.date  12 non-null     object
#  10  jesuita-entrada.obs   0 non-null      object
#  11  wicky                 7 non-null      object
#  12  wicky.date            7 non-null      object
#  13  wicky.obs             0 non-null      object
# dtypes: object(14)
# memory usage: 1.5+ KB

# %%
df[["name", "nacionalidade","nascimento","jesuita-entrada"]]
# Out:
#                                                   name nacionalidade  \
# id
# deh-afonso-aires-ref1                 Aires de Almeida      Portugal
# deh-antonio-de-almeida              António de Almeida      Portugal
# deh-jose-bernardo-de-almeida  José Bernardo de Almeida      Portugal
# deh-jose-bernardo-de-almeida  José Bernardo de Almeida      Portugal
# deh-jose-de-almeida-i                  José de Almeida      Portugal
# deh-jose-de-almeida-ii                 José de Almeida      Portugal
# deh-jose-de-almeida-iii                José de Almeida      Portugal
# deh-jose-estevao-de-almeida    José Estêvão de Almeida      Portugal
# deh-luis-de-almeida                    Luís de Almeida      Portugal
# deh-sebastiao-de-almeida          Sebastião de Almeida      Portugal
# deh-sebastiao-de-almeida          Sebastião de Almeida      Portugal
# deh-simao-de-almeida                  Simão de Almeida      Portugal
# deh-simao-de-almeida-ref1             Simão de Almeida      Portugal
#
#                                                 nascimento jesuita-entrada
# id
# deh-afonso-aires-ref1                             Santarém               ?
# deh-antonio-de-almeida          Trancoso, diocese de Viseu               ?
# deh-jose-bernardo-de-almeida    Penela, diocese de Coimbra          Lisboa
# deh-jose-bernardo-de-almeida    Penela, diocese de Coimbra          Lisboa
# deh-jose-de-almeida-i                                  NaN             NaN
# deh-jose-de-almeida-ii                              Lisboa               ?
# deh-jose-de-almeida-iii          Arcos, diocese de Coimbra               ?
# deh-jose-estevao-de-almeida   Esgueira, diocese de Coimbra               ?
# deh-luis-de-almeida                                 Lisboa           Japão
# deh-sebastiao-de-almeida                            Lagéas             Goa
# deh-sebastiao-de-almeida                            Lagéas             Goa
# deh-simao-de-almeida                                 Viseu               ?
# deh-simao-de-almeida-ref1                           Lisboa               ?
