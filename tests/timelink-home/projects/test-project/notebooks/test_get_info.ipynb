# %% [markdown]
# # name_to_df

# %%
# NBVAL_IGNORE_OUTPUT
import pandas as pd

pd.set_option('display.max_colwidth', 100)  # Increase column width to 100 characters

from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook(db_name="name_to_df")
info = tlnb.get_info(show_password=True, show_token=False, as_dataframe=True)
info.info()
info["Value"] = info["Value"].astype(str)
info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Attribute  13 non-null     object
#  1   Value      13 non-null     object
# dtypes: object(2)
# memory usage: 336.0+ bytes
#                   Attribute  \
# 0          Timelink version
# 1              Project name
# 2              Project home
# 3             Database type
# 4             Database name
# 5               Kleio image
# 6        Kleio server token
# 7          Kleio server URL
# 8         Kleio server home
# 9    Kleio server container
# 10  Kleio version requested
# 11     Kleio server version
# 12         SQLite directory
#
#                                                                                        Value
# 0                                                                                     1.1.10
# ...
