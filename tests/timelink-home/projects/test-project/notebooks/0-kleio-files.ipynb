# %% [markdown]
# # Managing Kleio files

# %% [markdown]
# > First time use: follow instructions in the [README.md](README.md) file in this directory.

# %% [markdown]
# ## Initial setup
#
# Create a TimelinkNotebook object. This will be the interface for most of your interactions with Timelink.
#
# The first time you run this notebook, you will be prompted to install ìpykernel. This is required to run Timelink in a notebook.
#
# Note:
# * First time run takes a little time as the required Docker images are downloaded.
# * Timelink will default to using sqlite as the database, see [Receipts notebook for more control](1-receipts.ipynb)

# %%
# NBVAL_IGNORE_OUTPUT

from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook(
    kleio_version='12.6.576',
    sqlite_dir='/Users/jrc/develop/timelink-py/tests/sqlite',
    db_name='test.db',
    db_type='sqlite',)
tlnb.print_info(show_token=True)
# Out:
# Timelink version: 1.1.13
# Project name: test-project
# Project home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project
# Database type: sqlite
# Database name: test.db
# Kleio image: timelinkserver/kleio-server
# Kleio server token: vcnDrCLBpUCG02GByZ0uUl13ox81D0Sy
# Kleio server URL: http://127.0.0.1:8088
# Kleio server home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project
# Kleio server container: xenodochial_khorana
# Kleio version requested: 12.6.576
# Kleio server version: 12.6.576 (2024-09-09 17:57:04)
# SQLite directory: /Users/jrc/develop/timelink-py/tests/sqlite
# Call print_info(show_password=True) to show the Postgres password
# TimelinkNotebook(project_name=test-project, project_home=/Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project, db_type=sqlite, db_name=test.db, kleio_image=timelinkserver/kleio-server, kleio_version=12.6.576, postgres_image=postgres, postgres_version=latest)

# %% [markdown]
# TimelinkNotebook created a database to store data and a Kleio server to
# translate transcriptions in Kleio notation into data that can be imported
# into a database.
#
# To get information about the database and the Kleio server do ```tnlb.print_info()```

# %% [markdown]
# ### Database status
#
# Count the number of rows in each table in the database.

# %%
# NBVAL_IGNORE_OUTPUT

tlnb.table_row_count_df()
# Out:
#                table  count
# 0              actas     84
# 1               acts   2536
# 2          acusacoes    178
# 3        aforamentos    126
# 4         aregisters      2
# 5         attributes  38167
# 6             cartas      5
# 7   cartas_de_perdao     45
# 8              casos     26
# 9   class_attributes    159
# 10           classes     28
# 11           dividas     52
# 12          entities  91338
# 13        escrituras    223
# 14           eventos     44
# 15          gelement   1971
# 16       geoentities    245
# 17             goods    238
# 18        households   1008
# 19             items      4
# 20        kleiofiles     95
# 21             links      4
# 22           objects   1648
# 23           perdoes     45
# 24           persons  16663
# 25         relations  29965
# 26         rentities     67
# 27      rgeoentities      0
# 28          robjects      0
# 29          rpersons     65
# 30             sizas      6
# 31           sources     46
# 32            syslog      0
# 33            syspar      0

# %% [markdown]
# ### Show the kleio files available

# %%
# NBVAL_IGNORE_OUTPUT

kleio_files = tlnb.get_kleio_files()
kleio_files
# Out:
#                                                  path  \
# 0       sources/reference_sources/varia/Devedores.cli
# 1      sources/reference_sources/varia/auc-alunos.cli
# 2   sources/reference_sources/varia/auc_cartulario...
# 3      sources/reference_sources/varia/avexplorfa.cli
# 4   sources/reference_sources/paroquiais/baptismos...
# 5   sources/reference_sources/paroquiais/baptismos...
# 6   sources/reference_sources/paroquiais/baptismos...
# 7   sources/reference_sources/paroquiais/baptismos...
# 8   sources/reference_sources/paroquiais/casamento...
# 9   sources/reference_sources/paroquiais/casamento...
# 10  sources/reference_sources/roisdeconfessados/co...
# 11  sources/reference_sources/paroquiais/crisma/cr...
# 12  sources/reference_sources/cronologias/crono-av...
# 13  sources/reference_sources/linked_data/dehergne...
# 14  sources/reference_sources/linked_data/dehergne...
# 15     sources/reference_sources/devassas/dev1692.cli
# 16  sources/reference_sources/notariais/docsregios...
# 17  sources/reference_sources/roisdeconfessados/ei...
# 18  sources/reference_sources/roisdeconfessados/ei...
# 19  sources/reference_sources/roisdeconfessados/ei...
# 20      sources/reference_sources/varia/eleicoes1.cli
# 21  sources/reference_sources/varia/genealdiversas...
# 22  sources/reference_sources/varia/glopes-lap1561...
# 23           sources/reference_sources/varia/ivcc.cli
# 24    sources/reference_sources/varia/lrazao516pe.cli
# 25   identifications/mhk_identification_toliveira.cli
# 26        sources/reference_sources/varia/misMesa.cli
# 27  sources/reference_sources/varia/mp758-santiago...
# 28         sources/reference_sources/varia/nommiz.cli
# 29  sources/reference_sources/notariais/notarial80...
# 30  sources/reference_sources/notariais/notlousa1.cli
# 31  sources/reference_sources/paroquiais/obitos/ob...
# 32  sources/reference_sources/paroquiais/obitos/ob...
# 33  sources/reference_sources/paroquiais/obitos/ob...
# 34  sources/reference_sources/paroquiais/obitos/ob...
# 35  sources/reference_sources/paroquiais/obitos/ob...
# 36  sources/reference_sources/paroquiais/obitos/ob...
# 37  sources/reference_sources/paroquiais/obitos/ob...
# 38    sources/reference_sources/notariais/perdoes.cli
# 39         sources/reference_sources/varia/quotes.cli
# 40                identifications/rentities-tests.cli
# 41  sources/reference_sources/paroquiais/baptismos...
# 42  sources/reference_sources/sameas/sameas-tests.cli
# 43  sources/reference_sources/varia/sourecoimbrabi...
# 44  sources/reference_sources/paroquiais/obitos/te...
# 45       sources/reference_sources/varia/vereacao.cli
# 46  sources/reference_sources/varia/xpto_comuns_so...
#
#                                          name  \
# 0                               Devedores.cli
# 1                              auc-alunos.cli
# 2                        auc_cartulario18.cli
# 3                              avexplorfa.cli
# 4                     bap-com-celebrantes.cli
# 5                                bapt1714.cli
# 6                       bapteirasproblem1.cli
# 7                       bapteirasproblem2.cli
# 8             cas1714-1722-com-celebrante.cli
# 9                            cas1714-1722.cli
# 10                          coja-rol-1841.cli
# 11                             crisma1753.cli
# 12                          crono-avulsos.cli
# 13                             dehergne-a.cli
# 14                dehergne-locations-1644.cli
# 15                                dev1692.cli
# 16                    docsregiospontepisc.cli
# 17                             eiras-rol1.cli
# 18                             eiras-rol2.cli
# 19                             eiras-rol3.cli
# 20                              eleicoes1.cli
# 21                         genealdiversas.cli
# 22                         glopes-lap1561.cli
# 23                                   ivcc.cli
# 24                            lrazao516pe.cli
# 25           mhk_identification_toliveira.cli
# 2   /rest/reports/sources/reference_sources/varia/...
# 3   /rest/reports/sources/reference_sources/varia/...
# 4   /rest/reports/sources/reference_sources/paroqu...
# 5   /rest/reports/sources/reference_sources/paroqu...
# 6   /rest/reports/sources/reference_sources/paroqu...
# 7   /rest/reports/sources/reference_sources/paroqu...
# 8   /rest/reports/sources/reference_sources/paroqu...
# 9   /rest/reports/sources/reference_sources/paroqu...
# 10  /rest/reports/sources/reference_sources/roisde...
# 11  /rest/reports/sources/reference_sources/paroqu...
# 12  /rest/reports/sources/reference_sources/cronol...
# 13  /rest/reports/sources/reference_sources/linked...
# 14  /rest/reports/sources/reference_sources/linked...
# 15  /rest/reports/sources/reference_sources/devass...
# 16  /rest/reports/sources/reference_sources/notari...
# 17  /rest/reports/sources/reference_sources/roisde...
# 18  /rest/reports/sources/reference_sources/roisde...
# 19  /rest/reports/sources/reference_sources/roisde...
# 20  /rest/reports/sources/reference_sources/varia/...
# 21  /rest/reports/sources/reference_sources/varia/...
# 22  /rest/reports/sources/reference_sources/varia/...
# 23  /rest/reports/sources/reference_sources/varia/...
# 24  /rest/reports/sources/reference_sources/varia/...
# 25  /rest/reports/identifications/mhk_identificati...
# 26  /rest/reports/sources/reference_sources/varia/...
# 27  /rest/reports/sources/reference_sources/varia/...
# 28  /rest/reports/sources/reference_sources/varia/...
# 29  /rest/reports/sources/reference_sources/notari...
# 30  /rest/reports/sources/reference_sources/notari...
# 31  /rest/reports/sources/reference_sources/paroqu...
# 32  /rest/reports/sources/reference_sources/paroqu...
# 33  /rest/reports/sources/reference_sources/paroqu...
# 34  /rest/reports/sources/reference_sources/paroqu...
# 35  /rest/reports/sources/reference_sources/paroqu...
# 36  /rest/reports/sources/reference_sources/paroqu...
# 37  /rest/reports/sources/reference_sources/paroqu...
# 38  /rest/reports/sources/reference_sources/notari...
# 39  /rest/reports/sources/reference_sources/varia/...
# 40  /rest/reports/identifications/rentities-tests.rpt
# 41  /rest/reports/sources/reference_sources/paroqu...
# 42  /rest/reports/sources/reference_sources/sameas...
# 43  /rest/reports/sources/reference_sources/varia/...
# 44  /rest/reports/sources/reference_sources/paroqu...
# 45  /rest/reports/sources/reference_sources/varia/...
# 46  /rest/reports/sources/reference_sources/varia/...
#
#                                               xml_url
# 0   /rest/exports/sources/reference_sources/varia/...
# 1   /rest/exports/sources/reference_sources/varia/...
# 2   /rest/exports/sources/reference_sources/varia/...
# 3   /rest/exports/sources/reference_sources/varia/...
# 4   /rest/exports/sources/reference_sources/paroqu...
# 5   /rest/exports/sources/reference_sources/paroqu...
# 6   /rest/exports/sources/reference_sources/paroqu...
# 7   /rest/exports/sources/reference_sources/paroqu...
# 8   /rest/exports/sources/reference_sources/paroqu...
# 9   /rest/exports/sources/reference_sources/paroqu...
# 10  /rest/exports/sources/reference_sources/roisde...
# 11  /rest/exports/sources/reference_sources/paroqu...
# 12  /rest/exports/sources/reference_sources/cronol...
# 13  /rest/exports/sources/reference_sources/linked...
# 14  /rest/exports/sources/reference_sources/linked...
# 15  /rest/exports/sources/reference_sources/devass...
# 16  /rest/exports/sources/reference_sources/notari...
# 17  /rest/exports/sources/reference_sources/roisde...
# 18  /rest/exports/sources/reference_sources/roisde...
# 19  /rest/exports/sources/reference_sources/roisde...
# 20  /rest/exports/sources/reference_sources/varia/...
# 21  /rest/exports/sources/reference_sources/varia/...
# 22  /rest/exports/sources/reference_sources/varia/...
# 23  /rest/exports/sources/reference_sources/varia/...
# 24  /rest/exports/sources/reference_sources/varia/...
# 25  /rest/exports/identifications/mhk_identificati...
# 26  /rest/exports/sources/reference_sources/varia/...
# 27  /rest/exports/sources/reference_sources/varia/...
# 28  /rest/exports/sources/reference_sources/varia/...
# 29  /rest/exports/sources/reference_sources/notari...
# 30  /rest/exports/sources/reference_sources/notari...
# 31  /rest/exports/sources/reference_sources/paroqu...
# 32  /rest/exports/sources/reference_sources/paroqu...
# 33  /rest/exports/sources/reference_sources/paroqu...
# 34  /rest/exports/sources/reference_sources/paroqu...
# 35  /rest/exports/sources/reference_sources/paroqu...
# 36  /rest/exports/sources/reference_sources/paroqu...
# 37  /rest/exports/sources/reference_sources/paroqu...
# 38  /rest/exports/sources/reference_sources/notari...
# 39  /rest/exports/sources/reference_sources/varia/...
# 40  /rest/exports/identifications/rentities-tests.xml
# 41  /rest/exports/sources/reference_sources/paroqu...
# 42  /rest/exports/sources/reference_sources/sameas...
# 43  /rest/exports/sources/reference_sources/varia/...
# 44  /rest/exports/sources/reference_sources/paroqu...
# 45  /rest/exports/sources/reference_sources/varia/...
# 46  /rest/exports/sources/reference_sources/varia/...

# %% [markdown]
# ## Optionally clean translations

# %%
# NBVAL_IGNORE_OUTPUT

# tlnb.kleio_server.translation_clean("", recurse="yes")

# %% [markdown]
# # Update the database from Kleio sources.
#
# Updates source translations and imports into database sources with no errors.
#
# Only changed files since last import, or new files, will be processed.

# %%
# NBVAL_IGNORE_OUTPUT

import logging
logging.basicConfig(level=logging.INFO)

tlnb.update_from_sources(path='', with_import_errors=True)
# get the import status
import_status = tlnb.get_import_status()
# list those with import_error > 0 or error > 0
errors = import_status.query("import_errors > 0 or errors > 0")
if len(errors) > 0:
    for error in errors.iterrows():
        print(error)
# Out:
# INFO:root:Request translation of T sources/reference_sources/varia/glopes-lap1561.cli
# INFO:root:Importing sources/reference_sources/varia/glopes-lap1561.cli
# INFO:root:Storing 23 postponed relations

# %% [markdown]
# ## Check the status of the files

# %% [markdown]
# Check the import status of the translated files
#
# * I: Imported
# * E: Imported with error
# * W: Imported with warnings no errors
# * N: Not imported
# * U: Translation updated need to reimport

# %%
# NBVAL_IGNORE_OUTPUT

imported_files_df = tlnb.get_import_status()
imported_files_df[["import_status","import_errors","import_warnings","name","errors","warnings","path"]].sort_values("name")
# Out:
#    import_status  import_errors  import_warnings  \
# 0              I              0                0
# 1              I              0                0
# 2              I              0                0
# 3              I              0                0
# 4              I              0                0
# 5              I              0                0
# 6              I              0                0
# 7              I              0                0
# 8              I              0                0
# 9              I              0                0
# 10             I              0                0
# 11             I              0                0
# 12             I              0                0
# 13             I              0                0
# 14             I              0                0
# 15             I              0                0
# 16             I              0                0
# 17             I              0                0
# 18             I              0                0
# 19             I              0                0
# 20             I              0                0
# 21             I              0                0
# 22             I              0                0
# 23             I              0                0
# 24             I              0                0
# 25             I              0                0
# 26             I              0                0
# 27             I              0                0
# 28             I              0                0
# 29             I              0                0
# 30             I              0                0
# 31             I              0                0
# 32             I              0                0
# 33             I              0                0
# 34             I              0                0
# 35             I              0                0
# 36             I              0                0
# 37             I              0                0
# 38             I              0                0
# 39             I              0                0
# 40             I              0                0
# 41             I              0                0
# 42             I              0                0
# 43             I              0                0
# 44             I              0                0
# 45             I              0                0
# 46             I              0                0
#
#                                          name  errors  warnings  \
# 0                               Devedores.cli       0         0
# 1                              auc-alunos.cli       0         0
# 2                        auc_cartulario18.cli       0         0
# 3                              avexplorfa.cli       0         0
# 4                     bap-com-celebrantes.cli       0         0
# 5                                bapt1714.cli       0         0
# 6                       bapteirasproblem1.cli       0         0
# 7                       bapteirasproblem2.cli       0         0
# 8             cas1714-1722-com-celebrante.cli       0         0
# 9                            cas1714-1722.cli       0         0
# 10                          coja-rol-1841.cli       0         0
# 11                             crisma1753.cli       0         0
# 12                          crono-avulsos.cli       0         0
# 13                             dehergne-a.cli       0         0
# 14                dehergne-locations-1644.cli       0         0
# 15                                dev1692.cli       0         0
# 16                    docsregiospontepisc.cli       0         0
# 17                             eiras-rol1.cli       0         0
# 18                             eiras-rol2.cli       0         0
# 19                             eiras-rol3.cli       0         0
# 20                              eleicoes1.cli       0         0
# 21                         genealdiversas.cli       0         0
# 22                         glopes-lap1561.cli       0         0
# 23                                   ivcc.cli       0         0
# 24                            lrazao516pe.cli       0         0
# 25           mhk_identification_toliveira.cli       0         0
# 26                                misMesa.cli       0         0
# 27                 mp758-santiago-beduido.cli       0         0
# 28                                 nommiz.cli       0         1
# 29                             notarial80.cli       0         0
# 30                              notlousa1.cli       0         0
# 31                                 ob1688.cli       0         0
# 32                                ob1688b.cli       0         0
# 33                               obit1714.cli       0         0
# 34                       obiteirasproblem.cli       0         0
# 35                             obitoShort.cli       0         0
# 36                          obitoShort_id.cli       0         0
# 37                       obitoShort_id_id.cli       0         0
# 38                                perdoes.cli       0         0
# 39                                 quotes.cli       0         0
# 40                        rentities-tests.cli       0         0
# 41            rogeriodomingos_bap_problem.cli       0         0
# 42                           sameas-tests.cli       0         0
# 43  sourecoimbrabispcoimbra_apontamentosd.cli       0         0
# 44                       testeParentescos.cli       0         0
# 45                               vereacao.cli       0         0
# 46                    xpto_comuns_soure.kleio       0         0
#
#                                                  path
# 0       sources/reference_sources/varia/Devedores.cli
# 1      sources/reference_sources/varia/auc-alunos.cli
# 2   sources/reference_sources/varia/auc_cartulario...
# 3      sources/reference_sources/varia/avexplorfa.cli
# 4   sources/reference_sources/paroquiais/baptismos...
# 5   sources/reference_sources/paroquiais/baptismos...
# 6   sources/reference_sources/paroquiais/baptismos...
# 7   sources/reference_sources/paroquiais/baptismos...
# 8   sources/reference_sources/paroquiais/casamento...
# 9   sources/reference_sources/paroquiais/casamento...
# 10  sources/reference_sources/roisdeconfessados/co...
# 11  sources/reference_sources/paroquiais/crisma/cr...
# 12  sources/reference_sources/cronologias/crono-av...
# 13  sources/reference_sources/linked_data/dehergne...
# 14  sources/reference_sources/linked_data/dehergne...
# 15     sources/reference_sources/devassas/dev1692.cli
# 16  sources/reference_sources/notariais/docsregios...
# 17  sources/reference_sources/roisdeconfessados/ei...
# 18  sources/reference_sources/roisdeconfessados/ei...
# 19  sources/reference_sources/roisdeconfessados/ei...
# 20      sources/reference_sources/varia/eleicoes1.cli
# 21  sources/reference_sources/varia/genealdiversas...
# 22  sources/reference_sources/varia/glopes-lap1561...
# 23           sources/reference_sources/varia/ivcc.cli
# 24    sources/reference_sources/varia/lrazao516pe.cli
# 25   identifications/mhk_identification_toliveira.cli
# 26        sources/reference_sources/varia/misMesa.cli
# 27  sources/reference_sources/varia/mp758-santiago...
# 28         sources/reference_sources/varia/nommiz.cli
# 29  sources/reference_sources/notariais/notarial80...
# 30  sources/reference_sources/notariais/notlousa1.cli
# 31  sources/reference_sources/paroquiais/obitos/ob...
# 32  sources/reference_sources/paroquiais/obitos/ob...
# 33  sources/reference_sources/paroquiais/obitos/ob...
# 34  sources/reference_sources/paroquiais/obitos/ob...
# 35  sources/reference_sources/paroquiais/obitos/ob...
# 36  sources/reference_sources/paroquiais/obitos/ob...
# 37  sources/reference_sources/paroquiais/obitos/ob...
# 38    sources/reference_sources/notariais/perdoes.cli
# 39         sources/reference_sources/varia/quotes.cli
# 40                identifications/rentities-tests.cli
# 41  sources/reference_sources/paroquiais/baptismos...
# 42  sources/reference_sources/sameas/sameas-tests.cli
# 43  sources/reference_sources/varia/sourecoimbrabi...
# 44  sources/reference_sources/paroquiais/obitos/te...
# 45       sources/reference_sources/varia/vereacao.cli
# 46  sources/reference_sources/varia/xpto_comuns_so...

# %%
errors = imported_files_df[imported_files_df.errors>0][["status", "errors","import_warnings","name","imported","warnings","path"]].sort_values("name")
errors
# Out:
# Empty DataFrame
# Columns: [status, errors, import_warnings, name, imported, warnings, path]
# Index: []

# %% [markdown]
# ### Check a translation report
#
# If needed to check for errors.

# %%
# NBVAL_IGNORE_OUTPUT

file_number=list(errors.index.unique())
if len(file_number) > 0:
    rpt = tlnb.get_translation_report(imported_files_df, file_number)
    print(rpt)
else:
    print("No errors found")
# Out:
# No errors found

# %% [markdown]
# ### Get the import report for a file
#
# In case there are errors in the import phase check the import report.

# %%
# NBVAL_IGNORE_OUTPUT

ierrors = imported_files_df[imported_files_df.import_errors>0][["import_status", "import_errors","import_warnings","name","imported","errors","warnings","path"]].sort_values("name")
list(ierrors.index)
# Out:
# []

# %%
rpt = tlnb.get_import_rpt(imported_files_df, rows=list(ierrors.index))
print(rpt)
