# %% [markdown]
# # Managing Kleio files

# %% [markdown]
# > First time use: follow instructions in the [README.md](README.md) file in this directory.

# %% [markdown]
# ## Initial setup
#
# Create a TimelinkNotebook object. This will be the interface for most of your interactions with Timelink.
#
# The first time you run this notebook, you will be prompted to install ìpykernel. This is required to run Timelink in a notebook.
#
# Note:
# * First time run takes a little time as the required Docker images are downloaded.
# * Timelink will default to using sqlite as the database, see [Receipts notebook for more control](1-receipts.ipynb)

# %%
from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook()
tlnb.print_info(show_token=True)
# Out:
# Timelink version: 1.1.12
# Project name: test-project
# Project home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project
# Database type: sqlite
# Database name: test_project
# Kleio image: timelinkserver/kleio-server
# Kleio server token: 8Sevrnnc1EbzZUXB0ipE0btr6KiNjRM0
# Kleio server URL: http://127.0.0.1:8090
# Kleio server home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project
# Kleio server container: bold_liskov
# Kleio version requested: latest
# Kleio server version: 12.6.574 (2024-09-05 21:48:12)
# SQLite directory: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project/database/sqlite
# Call print_info(show_password=True) to show the Postgres password
# TimelinkNotebook(project_name=test-project, project_home=/Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project, db_type=sqlite, db_name=test_project, kleio_image=timelinkserver/kleio-server, kleio_version=latest, postgres_image=postgres, postgres_version=latest)

# %% [markdown]
# TimelinkNotebook created a database to store data and a Kleio server to
# translate transcriptions in Kleio notation into data that can be imported
# into a database.
#
# To get information about the database and the Kleio server do ```tnlb.print_info()```

# %% [markdown]
# ### Database status
#
# Count the number of rows in each table in the database.

# %%
tlnb.table_row_count_df()
# Out:
#                table  count
# 0              actas      0
# 1               acts   1314
# 2        aforamentos    125
# 3         aregisters      1
# 4         attributes  31009
# 5             cartas      5
# 6   cartas_de_perdao      0
# 7   class_attributes    144
# 8            classes     25
# 9            dividas     40
# 10          entities  72218
# 11        escrituras    201
# 12           eventos     42
# 13          gelement     99
# 14       geoentities    242
# 15             goods    179
# 16        households   1008
# 17             items      4
# 18        kleiofiles     40
# 19           objects   1322
# 20           perdoes      0
# 21           persons  12975
# 22         relations  25128
# 23         rentities     65
# 24      rgeoentities      0
# 25          robjects      0
# 26          rpersons     65
# 27           sources     38
# 28            syslog      0
# 29            syspar      0

# %% [markdown]
# ### Show the kleio files available

# %%
kleio_files = tlnb.get_kleio_files()
kleio_files
# Out:
#                                                  path  \
# 0         kleio/reference_sources/varia/Devedores.cli
# 1        kleio/reference_sources/varia/EmpFAfonso.cli
# 2        kleio/reference_sources/varia/auc-alunos.cli
# 3   kleio/reference_sources/varia/auc_cartulario18...
# 4   kleio/reference_sources/paroquiais/baptismos/b...
# 5   kleio/reference_sources/paroquiais/baptismos/b...
# 6   kleio/reference_sources/paroquiais/baptismos/b...
# 7   kleio/reference_sources/paroquiais/baptismos/b...
# 8   kleio/reference_sources/paroquiais/casamentos/...
# 9   kleio/reference_sources/paroquiais/casamentos/...
# 10  kleio/reference_sources/roisdeconfessados/coja...
# 11  kleio/reference_sources/paroquiais/crisma/cris...
# 12  kleio/reference_sources/linked_data/dehergne-a...
# 13  kleio/reference_sources/linked_data/dehergne-l...
# 14  kleio/reference_sources/notariais/docsregiospo...
# 15  kleio/reference_sources/roisdeconfessados/eira...
# 16  kleio/reference_sources/roisdeconfessados/eira...
# 17  kleio/reference_sources/roisdeconfessados/eira...
# 18        kleio/reference_sources/varia/eleicoes1.cli
# 19   kleio/reference_sources/varia/genealdiversas.cli
# 20   kleio/reference_sources/varia/glopes-lap1561.cli
# 21             kleio/reference_sources/varia/ivcc.cli
# 22      kleio/reference_sources/varia/lrazao516pe.cli
# 23   identifications/mhk_identification_toliveira.cli
# 24          kleio/reference_sources/varia/misMesa.cli
# 25  kleio/reference_sources/varia/mp758-santiago-b...
# 26           kleio/reference_sources/varia/nommiz.cli
# 27   kleio/reference_sources/notariais/notarial80.cli
# 28    kleio/reference_sources/notariais/notlousa1.cli
# 29  kleio/reference_sources/paroquiais/obitos/ob16...
# 30  kleio/reference_sources/paroquiais/obitos/ob16...
# 31  kleio/reference_sources/paroquiais/obitos/obit...
# 32  kleio/reference_sources/paroquiais/obitos/obit...
# 33  kleio/reference_sources/paroquiais/obitos/obit...
# 34  kleio/reference_sources/paroquiais/obitos/obit...
# 35  kleio/reference_sources/paroquiais/obitos/obit...
# 36      kleio/reference_sources/notariais/perdoes.cli
# 37           kleio/reference_sources/varia/quotes.cli
# 38  kleio/reference_sources/paroquiais/baptismos/r...
# 39  kleio/reference_sources/varia/sourecoimbrabisp...
# 40  kleio/reference_sources/paroquiais/obitos/test...
# 41         kleio/reference_sources/varia/vereacao.cli
# 42  kleio/reference_sources/varia/xpto_comuns_sour...
#
#                                          name  \
# 0                               Devedores.cli
# 1                              EmpFAfonso.cli
# 2                              auc-alunos.cli
# 3                        auc_cartulario18.cli
# 4                     bap-com-celebrantes.cli
# 5                                bapt1714.cli
# 6                       bapteirasproblem1.cli
# 7                       bapteirasproblem2.cli
# 8             cas1714-1722-com-celebrante.cli
# 9                            cas1714-1722.cli
# 10                          coja-rol-1841.cli
# 11                             crisma1753.cli
# 12                             dehergne-a.cli
# 13                dehergne-locations-1644.cli
# 14                    docsregiospontepisc.cli
# 15                             eiras-rol1.cli
# 16                             eiras-rol2.cli
# 17                             eiras-rol3.cli
# 18                              eleicoes1.cli
# 19                         genealdiversas.cli
# 20                         glopes-lap1561.cli
# 21                                   ivcc.cli
# 22                            lrazao516pe.cli
# 23           mhk_identification_toliveira.cli
# 24                                misMesa.cli
# 25                 mp758-santiago-beduido.cli
# 26                                 nommiz.cli
# 27                             notarial80.cli
# 28                              notlousa1.cli
# 29                                 ob1688.cli
# 30                                ob1688b.cli
# 31                               obit1714.cli
# 32                       obiteirasproblem.cli
# 33                             obitoShort.cli
# 34                          obitoShort_id.cli
# 35                       obitoShort_id_id.cli
# 36                                perdoes.cli
# 37                                 quotes.cli
# 38            rogeriodomingos_bap_problem.cli
# 39  sourecoimbrabispcoimbra_apontamentosd.cli
# 40                       testeParentescos.cli
# 41                               vereacao.cli
# 42                    xpto_comuns_soure.kleio
#
#                            modified status                translated  errors  \
# 0  2024-09-05 14:01:01.795513+00:00      V 2024-09-05 14:01:00+00:00       0
# 1  2024-09-05 14:01:05.038630+00:00      W 2024-09-05 14:01:00+00:00       0
# 2  2024-09-05 14:02:26.342513+00:00      V 2024-09-05 14:02:00+00:00       0
# 3  2024-09-05 14:26:55.124279+00:00      V 2024-09-05 14:26:00+00:00       0
# 4  2024-09-05 14:01:05.902987+00:00      V 2024-09-05 14:01:00+00:00       0
# 5  2024-09-05 14:01:09.770679+00:00      V 2024-09-05 14:01:00+00:00       0
# 6  2024-09-05 14:01:16.066827+00:00      V 2024-09-05 14:01:00+00:00       0
# 7  2024-09-05 14:01:19.983935+00:00      V 2024-09-05 14:01:00+00:00       0
# 8  2024-09-05 14:01:16.930681+00:00      V 2024-09-05 14:01:00+00:00       0
# 9  2024-09-05 14:01:23.708166+00:00      V 2024-09-05 14:01:00+00:00       0
# 10 2024-09-05 14:26:27.117090+00:00      V 2024-09-05 14:26:00+00:00       0
# 11 2024-09-05 14:01:24.653909+00:00      V 2024-09-05 14:01:00+00:00       0
# 12 2024-09-05 14:01:30.067994+00:00      V 2024-09-05 14:01:00+00:00       0
# 13 2024-09-05 14:01:32.558387+00:00      V 2024-09-05 14:01:00+00:00       0
# 14 2024-09-05 14:01:33.493556+00:00      V 2024-09-05 14:01:00+00:00       0
# 15 2024-09-05 14:26:20.211460+00:00      V 2024-09-05 14:26:00+00:00       0
# 16 2024-09-05 14:26:23.063255+00:00      V 2024-09-05 14:26:00+00:00       0
# 17 2024-09-05 14:01:48.432974+00:00      V 2024-09-05 14:01:00+00:00       0
# 18 2024-09-05 14:01:50.153123+00:00      V 2024-09-05 14:01:00+00:00       0
# 19 2024-09-05 14:01:53.071308+00:00      V 2024-09-05 14:01:00+00:00       0
# 20 2024-09-05 14:02:00.827128+00:00      W 2024-09-05 14:02:00+00:00       0
# 21 2024-09-05 14:01:55.585681+00:00      V 2024-09-05 14:01:00+00:00       0
# 22 2024-09-05 14:02:10.662566+00:00      V 2024-09-05 14:02:00+00:00       0
# 23 2024-09-05 14:02:02.743665+00:00      V 2024-09-05 14:02:00+00:00       0
# 24 2024-09-05 14:02:08.576784+00:00      V 2024-09-05 14:02:00+00:00       0
# 25 2024-09-05 14:02:09.695445+00:00      V 2024-09-05 14:02:00+00:00       0
# 26 2024-09-05 14:23:29.460346+00:00      W 2024-09-05 14:23:00+00:00       0
# 27 2024-09-05 14:24:48.712779+00:00      V 2024-09-05 14:24:00+00:00       0
# 28 2024-09-05 14:24:54.836611+00:00      E 2024-09-05 14:24:00+00:00       1
# 29 2024-02-08 06:21:39.112058+00:00      E 2024-02-10 14:33:00+00:00       2
# 30 2024-02-08 06:21:39.112129+00:00      E 2024-02-10 14:33:00+00:00       2
# 31 2024-09-05 14:02:12.457034+00:00      V 2024-09-05 14:02:00+00:00       0
# 32 2024-02-08 06:21:39.112838+00:00      E 2024-02-26 03:29:00+00:00      11
# 33 2024-09-05 14:02:13.431445+00:00      V 2024-09-05 14:02:00+00:00       0
# 34 2024-09-05 14:02:14.327584+00:00      V 2024-09-05 14:02:00+00:00       0
# 35 2024-02-08 06:21:39.113720+00:00      E 2024-02-10 14:33:00+00:00       1
# 36 2024-09-05 14:02:19.133053+00:00      V 2024-09-05 14:02:00+00:00       0
# 37 2024-09-05 14:02:16.099835+00:00      V 2024-09-05 14:02:00+00:00       0
# 38 2024-09-05 14:02:17.034877+00:00      V 2024-09-05 14:02:00+00:00       0
# 39 2024-09-05 14:02:18.005323+00:00      V 2024-09-05 14:02:00+00:00       0
# 40 2024-09-05 14:02:19.064724+00:00      V 2024-09-05 14:02:00+00:00       0
# 41 2024-09-05 14:02:19.997933+00:00      V 2024-09-05 14:02:00+00:00       0
# 42 2024-09-05 14:02:21.851047+00:00      V 2024-09-05 14:02:00+00:00       0
#
#     warnings import_status  import_errors  import_warnings  \
# 0          0             I              0                0
# 1          2             I              0                0
# 2          0             I              0                0
# 3          0             U              0                0
# 4          0             I              0                0
# 5          0             I              0                0
# 6          0             I              0                0
# 7          0             I              0                0
# 8          0             I              0                0
# 9          0             I              0                0
# 10         0             U              0                0
# 11         0             I              0                0
# 12         0             I              0                0
# 13         0             I              0                0
# 14         0             I              0                0
# 15         0             U              0                0
# 16         0             U              0                0
# 17         0             I              0                0
# 18         0             E             28               28
# 19         0             I              0                0
# 20         3             I              0                0
# 21         0             I              0                0
# 22         0             I              0                0
# 23         0             I              0                0
# 24         0             E             83               83
# 25         0             I              0                0
# 26         3             N              0                0
# 27         0             N              0                0
# 28         1             U              0                0
# 29         0             N              0                0
# 30         0             N              0                0
# 31         0             I              0                0
# 32         0             N              0                0
# 33         0             I              0                0
# 34         0             I              0                0
# 35         0             N              0                0
# 36         0             E             80               80
# 37         0             I              0                0
# 38         0             I              0                0
# 39         0             I              0                0
# 40         0             I              0                0
# 41         0             I              0                0
# 42         0             I              0                0
#
#                                      import_error_rpt import_warning_rpt  \
# 0                                           No errors        No warnings
# 1                                           No errors        No warnings
# 2                                           No errors        No warnings
# 3                                                   0                  0
# 4                                           No errors        No warnings
# 5                                           No errors        No warnings
# 6                                           No errors        No warnings
# 7                                           No errors        No warnings
# 8                                           No errors        No warnings
# 9                                           No errors        No warnings
# 10                                                  0                  0
# 11                                          No errors        No warnings
# 12                                          No errors        No warnings
# 13                                          No errors        No warnings
# 14                                          No errors        No warnings
# 15                                                  0                  0
# 16                                                  0                  0
# 17                                          No errors        No warnings
# 18  ERROR: eleicoes1.cli line 6 storing group amz$...        No warnings
# 19                                          No errors        No warnings
# 20                                          No errors        No warnings
# 21                                          No errors        No warnings
# 22                                          No errors        No warnings
# 23                                          No errors        No warnings
# 24  ERROR: misMesa.cli line 6 storing group amz$am...        No warnings
# 25                                          No errors        No warnings
# 26                                                  0                  0
# 27                                                  0                  0
# 28                                                  0                  0
# 29                                                  0                  0
# 30                                                  0                  0
# 31                                          No errors        No warnings
# 32                                                  0                  0
# 33                                          No errors        No warnings
# 34                                          No errors        No warnings
# 35                                                  0                  0
# 36  ERROR: perdoes.cli line 6 storing group cartap...        No warnings
# 37                                          No errors        No warnings
# 38                                          No errors        No warnings
# 39                                          No errors        No warnings
# 40                                          No errors        No warnings
# 41                                          No errors        No warnings
# 42                                          No errors        No warnings
#
#                       imported  \
# 0   2024-09-05 14:04:11.948003
# 1   2024-09-05 14:10:45.736554
# 2   2024-09-05 14:05:25.686704
# 3                            0
# 4   2024-09-05 14:05:39.807214
# 5   2024-09-05 14:05:49.030026
# 6   2024-09-05 14:06:09.339104
# 7   2024-09-05 14:06:36.859571
# 8   2024-09-05 14:06:38.388063
# 9   2024-09-05 14:06:58.830919
# 10                           0
# 11  2024-09-05 14:07:47.876997
# 12  2024-09-05 14:07:57.494549
# 13  2024-09-05 14:08:02.506612
# 14  2024-09-05 14:08:03.802388
# 15                           0
# 16                           0
# 17  2024-09-05 14:08:48.143669
# 18  2024-09-05 14:08:58.722843
# 19  2024-09-05 14:09:08.163728
# 20  2024-09-05 14:13:06.692165
# 21  2024-09-05 14:09:12.591084
# 22  2024-09-05 14:09:32.730449
# 23  2024-09-05 14:09:34.392531
# 24  2024-09-05 14:09:48.971480
# 25  2024-09-05 14:09:50.414725
# 26                           0
# 27                           0
# 28                           0
# 29                           0
# 30                           0
# 31  2024-09-05 14:10:03.841602
# 32                           0
# 33  2024-09-05 14:10:05.025308
# 34  2024-09-05 14:10:06.210959
# 35                           0
# 36  2024-09-05 14:10:20.021564
# 37  2024-09-05 14:10:21.145051
# 38  2024-09-05 14:10:22.423835
# 39  2024-09-05 14:10:25.282262
# 40  2024-09-05 14:10:27.181309
# 41  2024-09-05 14:10:29.694114
# 42  2024-09-05 14:10:35.348691
#
#                                               rpt_url  \
# 0   /rest/reports/kleio/reference_sources/varia/De...
# 1   /rest/reports/kleio/reference_sources/varia/Em...
# 2   /rest/reports/kleio/reference_sources/varia/au...
# 3   /rest/reports/kleio/reference_sources/varia/au...
# 4   /rest/reports/kleio/reference_sources/paroquia...
# 5   /rest/reports/kleio/reference_sources/paroquia...
# 6   /rest/reports/kleio/reference_sources/paroquia...
# 7   /rest/reports/kleio/reference_sources/paroquia...
# 8   /rest/reports/kleio/reference_sources/paroquia...
# 9   /rest/reports/kleio/reference_sources/paroquia...
# 10  /rest/reports/kleio/reference_sources/roisdeco...
# 11  /rest/reports/kleio/reference_sources/paroquia...
# 12  /rest/reports/kleio/reference_sources/linked_d...
# 13  /rest/reports/kleio/reference_sources/linked_d...
# 14  /rest/reports/kleio/reference_sources/notariai...
# 15  /rest/reports/kleio/reference_sources/roisdeco...
# 16  /rest/reports/kleio/reference_sources/roisdeco...
# 17  /rest/reports/kleio/reference_sources/roisdeco...
# 18  /rest/reports/kleio/reference_sources/varia/el...
# 19  /rest/reports/kleio/reference_sources/varia/ge...
# 20  /rest/reports/kleio/reference_sources/varia/gl...
# 21  /rest/reports/kleio/reference_sources/varia/iv...
# 22  /rest/reports/kleio/reference_sources/varia/lr...
# 23  /rest/reports/identifications/mhk_identificati...
# 24  /rest/reports/kleio/reference_sources/varia/mi...
# 25  /rest/reports/kleio/reference_sources/varia/mp...
# 26  /rest/reports/kleio/reference_sources/varia/no...
# 27  /rest/reports/kleio/reference_sources/notariai...
# 28  /rest/reports/kleio/reference_sources/notariai...
# 29  /rest/reports/kleio/reference_sources/paroquia...
# 30  /rest/reports/kleio/reference_sources/paroquia...
# 31  /rest/reports/kleio/reference_sources/paroquia...
# 32  /rest/reports/kleio/reference_sources/paroquia...
# 33  /rest/reports/kleio/reference_sources/paroquia...
# 34  /rest/reports/kleio/reference_sources/paroquia...
# 35  /rest/reports/kleio/reference_sources/paroquia...
# 36  /rest/reports/kleio/reference_sources/notariai...
# 37  /rest/reports/kleio/reference_sources/varia/qu...
# 38  /rest/reports/kleio/reference_sources/paroquia...
# 39  /rest/reports/kleio/reference_sources/varia/so...
# 40  /rest/reports/kleio/reference_sources/paroquia...
# 41  /rest/reports/kleio/reference_sources/varia/ve...
# 42  /rest/reports/kleio/reference_sources/varia/xp...
#
#                                               xml_url
# 0   /rest/exports/kleio/reference_sources/varia/De...
# 1   /rest/exports/kleio/reference_sources/varia/Em...
# 2   /rest/exports/kleio/reference_sources/varia/au...
# 3   /rest/exports/kleio/reference_sources/varia/au...
# 4   /rest/exports/kleio/reference_sources/paroquia...
# 5   /rest/exports/kleio/reference_sources/paroquia...
# 6   /rest/exports/kleio/reference_sources/paroquia...
# 7   /rest/exports/kleio/reference_sources/paroquia...
# 8   /rest/exports/kleio/reference_sources/paroquia...
# 9   /rest/exports/kleio/reference_sources/paroquia...
# 10  /rest/exports/kleio/reference_sources/roisdeco...
# 11  /rest/exports/kleio/reference_sources/paroquia...
# 12  /rest/exports/kleio/reference_sources/linked_d...
# 13  /rest/exports/kleio/reference_sources/linked_d...
# 14  /rest/exports/kleio/reference_sources/notariai...
# 15  /rest/exports/kleio/reference_sources/roisdeco...
# 16  /rest/exports/kleio/reference_sources/roisdeco...
# 17  /rest/exports/kleio/reference_sources/roisdeco...
# 18  /rest/exports/kleio/reference_sources/varia/el...
# 19  /rest/exports/kleio/reference_sources/varia/ge...
# 20  /rest/exports/kleio/reference_sources/varia/gl...
# 21  /rest/exports/kleio/reference_sources/varia/iv...
# 22  /rest/exports/kleio/reference_sources/varia/lr...
# 23  /rest/exports/identifications/mhk_identificati...
# 24  /rest/exports/kleio/reference_sources/varia/mi...
# 25  /rest/exports/kleio/reference_sources/varia/mp...
# 26  /rest/exports/kleio/reference_sources/varia/no...
# 27  /rest/exports/kleio/reference_sources/notariai...
# 28  /rest/exports/kleio/reference_sources/notariai...
# 29  /rest/exports/kleio/reference_sources/paroquia...
# 30  /rest/exports/kleio/reference_sources/paroquia...
# 31  /rest/exports/kleio/reference_sources/paroquia...
# 32  /rest/exports/kleio/reference_sources/paroquia...
# 33  /rest/exports/kleio/reference_sources/paroquia...
# 34  /rest/exports/kleio/reference_sources/paroquia...
# 35  /rest/exports/kleio/reference_sources/paroquia...
# 36  /rest/exports/kleio/reference_sources/notariai...
# 37  /rest/exports/kleio/reference_sources/varia/qu...
# 38  /rest/exports/kleio/reference_sources/paroquia...
# 39  /rest/exports/kleio/reference_sources/varia/so...
# 40  /rest/exports/kleio/reference_sources/paroquia...
# 41  /rest/exports/kleio/reference_sources/varia/ve...
# 42  /rest/exports/kleio/reference_sources/varia/xp...

# %% [markdown]
# ## Optionally clean translations

# %%
tlnb.kleio_server.translation_clean("", recurse="yes")
# Out:
# ['kleio/dehergne-locations-1701.cli',
#  'kleio/dehergne-locations-1644.cli',
#  'kleio/dehergne-a.cli',
#  'kleio/b1685.cli',
#  'kleio/auc-alunos.cli']

# %% [markdown]
# # Update the database from Kleio sources.
#
# Updates source translations and imports into database sources with no errors.
#
# Only changed files since last import, or new files, will be processed.

# %%
import logging
logging.basicConfig(level=logging.INFO)

tlnb.update_from_sources()
# get the import status
import_status = tlnb.get_import_status()
# list those with import_error > 0 or error > 0
errors = import_status.query("import_errors > 0 or errors > 0")
if len(errors) > 0:
    print(errors)
# Out:
# INFO:root:Importing kleio/reference_sources/varia/Devedores.cli
# INFO:root:Importing kleio/reference_sources/varia/auc-alunos.cli
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element obs of group fonte:auc-alunos is too long for column obs of class source truncating to 1024 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element obs of group n:140513 is too long for column obs of class person truncating to 1024 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element obs of group n:140538 is too long for column obs of class person truncating to 1024 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element obs of group n:140565 is too long for column obs of class person truncating to 1024 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element obs of group n:140627 is too long for column obs of class person truncating to 1024 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element obs of group n:140695 is too long for column obs of class person truncating to 1024 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element obs of group n:140699 is too long for column obs of class person truncating to 1024 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element obs of group n:269364 is too long for column obs of class person truncating to 1024 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# INFO:root:Importing kleio/reference_sources/varia/auc_cartulario18.cli
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for fol. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# INFO:root:Storing 7 postponed relations
# INFO:root:Importing kleio/reference_sources/paroquiais/baptismos/bap-com-celebrantes.cli
# INFO:root:Importing kleio/reference_sources/paroquiais/baptismos/bapt1714.cli
# INFO:root:Storing 1 postponed relations
# INFO:root:Importing kleio/reference_sources/paroquiais/baptismos/bapteirasproblem1.cli
# INFO:root:Storing 1 postponed relations
# INFO:root:Importing kleio/reference_sources/paroquiais/baptismos/bapteirasproblem2.cli
# INFO:root:Storing 18 postponed relations
# INFO:root:Importing kleio/reference_sources/paroquiais/casamentos/cas1714-1722-com-celebrante.cli
# INFO:root:Importing kleio/reference_sources/paroquiais/casamentos/cas1714-1722.cli
# INFO:root:Importing kleio/reference_sources/roisdeconfessados/coja-rol-1841.cli
# INFO:root:Importing kleio/reference_sources/paroquiais/crisma/crisma1753.cli
# INFO:root:Storing 1 postponed relations
# INFO:root:Importing kleio/reference_sources/linked_data/dehergne-a.cli
# INFO:root:Storing 11 postponed relations
# INFO:root:Importing kleio/reference_sources/linked_data/dehergne-locations-1644.cli
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element obs of group fonte:dehergne-locations-1644 is too long for column obs of class source truncating to 1024 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# INFO:root:Importing kleio/reference_sources/notariais/docsregiospontepisc.cli
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for titulo. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for resumo. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# INFO:root:Importing kleio/reference_sources/roisdeconfessados/eiras-rol1.cli
# INFO:root:Storing 9 postponed relations
# INFO:root:Importing kleio/reference_sources/roisdeconfessados/eiras-rol2.cli
# INFO:root:Storing 3 postponed relations
# INFO:root:Importing kleio/reference_sources/roisdeconfessados/eiras-rol3.cli
# INFO:root:Storing 3 postponed relations
# INFO:root:Importing kleio/reference_sources/varia/eleicoes1.cli
# INFO:root:Storing 568 postponed relations
# INFO:root:Importing kleio/reference_sources/varia/genealdiversas.cli
# INFO:root:Storing 26 postponed relations
# INFO:root:Importing kleio/reference_sources/varia/ivcc.cli
# INFO:root:Storing 21 postponed relations
# INFO:root:Importing kleio/reference_sources/varia/lrazao516pe.cli
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element name of group n:livrz516-1-per66 is too long for column name of class person truncating to 64 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# INFO:root:Storing 78 postponed relations
# INFO:root:Importing identifications/mhk_identification_toliveira.cli
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for dbase. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for user. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for mode. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for status. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for the_class. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# INFO:root:Importing kleio/reference_sources/varia/misMesa.cli
# INFO:root:Storing 696 postponed relations
# INFO:root:Importing kleio/reference_sources/varia/mp758-santiago-beduido.cli
# INFO:root:Storing 2 postponed relations
# INFO:root:Importing kleio/reference_sources/notariais/notlousa1.cli
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for juro. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for moeda. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for forma. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for subtipo. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# INFO:root:Storing 66 postponed relations
# INFO:root:Importing kleio/reference_sources/paroquiais/obitos/obit1714.cli
# INFO:root:Importing kleio/reference_sources/paroquiais/obitos/obitoShort.cli
# INFO:root:Importing kleio/reference_sources/paroquiais/obitos/obitoShort_id.cli
# INFO:root:Importing kleio/reference_sources/notariais/perdoes.cli
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for tabeliao. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for objecto. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for ocorrencia. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for tempo. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for descricao. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for pronuncia. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py/timelink/kleio/groups/kgroup.py:733: UserWarning: Created a KElement class for situacao. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# INFO:root:Storing 369 postponed relations
# INFO:root:Importing kleio/reference_sources/varia/quotes.cli
# INFO:root:Importing kleio/reference_sources/paroquiais/baptismos/rogeriodomingos_bap_problem.cli
# INFO:root:Importing kleio/reference_sources/varia/sourecoimbrabispcoimbra_apontamentosd.cli
# INFO:root:Storing 1 postponed relations
# INFO:root:Importing kleio/reference_sources/paroquiais/obitos/testeParentescos.cli
# INFO:root:Importing kleio/reference_sources/varia/vereacao.cli
# INFO:root:Importing kleio/reference_sources/varia/xpto_comuns_soure.kleio
# INFO:root:Importing kleio/reference_sources/varia/EmpFAfonso.cli
# INFO:root:Importing kleio/reference_sources/varia/glopes-lap1561.cli
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element sex of group filha:p-1136-per2-per6 is too long for column sex of class person truncating to 1 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element sex of group pmulher:p-1285-per2-per6 is too long for column sex of class person truncating to 1 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# /Users/jrc/develop/timelink-py/timelink/api/models/pom_som_mapper.py:535: UserWarning: Element sex of group mmulher:p-1285-per2-per7 is too long for column sex of class person truncating to 1 characters
#   entity_from_group: Entity = cls.kgroup_to_entity(group, session)
# INFO:root:Storing 23 postponed relations
#                                                  path                  name  \
# 18        kleio/reference_sources/varia/eleicoes1.cli         eleicoes1.cli
# 24          kleio/reference_sources/varia/misMesa.cli           misMesa.cli
# 26           kleio/reference_sources/varia/nommiz.cli            nommiz.cli
# 27   kleio/reference_sources/notariais/notarial80.cli        notarial80.cli
# 28    kleio/reference_sources/notariais/notlousa1.cli         notlousa1.cli
# 29  kleio/reference_sources/paroquiais/obitos/ob16...            ob1688.cli
# 30  kleio/reference_sources/paroquiais/obitos/ob16...           ob1688b.cli
# 32  kleio/reference_sources/paroquiais/obitos/obit...  obiteirasproblem.cli
# 35  kleio/reference_sources/paroquiais/obitos/obit...  obitoShort_id_id.cli
# 36      kleio/reference_sources/notariais/perdoes.cli           perdoes.cli
#
#       size                                  directory  \
# 18   50693              kleio/reference_sources/varia
# 24   80126              kleio/reference_sources/varia
# 26  113694              kleio/reference_sources/varia
# 27   38720          kleio/reference_sources/notariais
# 28   60802          kleio/reference_sources/notariais
# 29   16671  kleio/reference_sources/paroquiais/obitos
# 30   16672  kleio/reference_sources/paroquiais/obitos
# 32  268277  kleio/reference_sources/paroquiais/obitos
# 35     666  kleio/reference_sources/paroquiais/obitos
# 36   80615          kleio/reference_sources/notariais
#
#                            modified              modified_iso  \
# 18 2024-09-05 14:01:50.153123+00:00 2024-09-05 14:01:50+00:00
# 24 2024-09-05 14:02:08.576784+00:00 2024-09-05 14:02:08+00:00
# 26 2024-02-08 06:21:39.121642+00:00 2024-02-08 06:21:39+00:00
# 27 2024-07-02 13:36:20.923357+00:00 2024-07-02 13:36:20+00:00
# 28 2024-09-05 14:02:15.166271+00:00 2024-09-05 14:02:15+00:00
# 29 2024-02-08 06:21:39.112058+00:00 2024-02-08 06:21:39+00:00
# 30 2024-02-08 06:21:39.112129+00:00 2024-02-08 06:21:39+00:00
# 32 2024-02-08 06:21:39.112838+00:00 2024-02-08 06:21:39+00:00
# 35 2024-02-08 06:21:39.113720+00:00 2024-02-08 06:21:39+00:00
# 36 2024-09-05 14:02:19.133053+00:00 2024-09-05 14:02:19+00:00
#
#         modified_string                     qtime         qtime_string  \
# 18  2024-09-05 14:01:50 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 24  2024-09-05 14:02:08 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 26  2024-02-08 06:21:39 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 27  2024-07-02 13:36:20 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 28  2024-09-05 14:02:15 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 29  2024-02-08 06:21:39 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 30  2024-02-08 06:21:39 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 32  2024-02-08 06:21:39 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 35  2024-02-08 06:21:39 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 36  2024-09-05 14:02:19 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
#
#                                            source_url  ...  \
# 18  /rest/sources/kleio/reference_sources/varia/el...  ...
# 24  /rest/sources/kleio/reference_sources/varia/mi...  ...
# 26  /rest/sources/kleio/reference_sources/varia/no...  ...
# 27  /rest/sources/kleio/reference_sources/notariai...  ...
# 28  /rest/sources/kleio/reference_sources/notariai...  ...
# 29  /rest/sources/kleio/reference_sources/paroquia...  ...
# 30  /rest/sources/kleio/reference_sources/paroquia...  ...
# 32  /rest/sources/kleio/reference_sources/paroquia...  ...
# 35  /rest/sources/kleio/reference_sources/paroquia...  ...
# 36  /rest/sources/kleio/reference_sources/notariai...  ...
#
#                                               version  \
# 18  KleioTranslator - server version 12.6 - build ...
# 24  KleioTranslator - server version 12.6 - build ...
# 26  KleioTranslator - server version 12.5 - build ...
# 27  KleioTranslator - server version 12.5 - build ...
# 28  KleioTranslator - server version 12.6 - build ...
# 29  KleioTranslator - server version 12.2 - build ...
# 30  KleioTranslator - server version 12.2 - build ...
# 32  KleioTranslator - server version 12.4 - build ...
# 35  KleioTranslator - server version 12.2 - build ...
# 36  KleioTranslator - server version 12.6 - build ...
#
#                                               rpt_url  \
# 18  /rest/reports/kleio/reference_sources/varia/el...
# 24  /rest/reports/kleio/reference_sources/varia/mi...
# 26  /rest/reports/kleio/reference_sources/varia/no...
# 27  /rest/reports/kleio/reference_sources/notariai...
# 28  /rest/reports/kleio/reference_sources/notariai...
# 29  /rest/reports/kleio/reference_sources/paroquia...
# 30  /rest/reports/kleio/reference_sources/paroquia...
# 32  /rest/reports/kleio/reference_sources/paroquia...
# 35  /rest/reports/kleio/reference_sources/paroquia...
# 36  /rest/reports/kleio/reference_sources/notariai...
#
#                                               xml_url  import_status  \
# 18  /rest/exports/kleio/reference_sources/varia/el...              E
# 24  /rest/exports/kleio/reference_sources/varia/mi...              E
# 26  /rest/exports/kleio/reference_sources/varia/no...              N
# 27  /rest/exports/kleio/reference_sources/notariai...              N
# 28  /rest/exports/kleio/reference_sources/notariai...              E
# 29  /rest/exports/kleio/reference_sources/paroquia...              N
# 30  /rest/exports/kleio/reference_sources/paroquia...              N
# 32  /rest/exports/kleio/reference_sources/paroquia...              N
# 35  /rest/exports/kleio/reference_sources/paroquia...              N
# 36  /rest/exports/kleio/reference_sources/notariai...              E
#
#     import_errors import_warnings  \
# 18             28              28
# 24             83              83
# 26              0               0
# 27              0               0
# 28             10              10
# 29              0               0
# 30              0               0
# 32              0               0
# 35              0               0
# 36             80              80
#
#                                      import_error_rpt import_warning_rpt  \
# 18  ERROR: eleicoes1.cli line 6 storing group amz$...        No warnings
# 24  ERROR: misMesa.cli line 6 storing group amz$am...        No warnings
# 26                                                  0                  0
# 27                                                  0                  0
# 28  ERROR: notlousa1.cli line 618 storing group ca...        No warnings
# 29                                                  0                  0
# 30                                                  0                  0
# 32                                                  0                  0
# 35                                                  0                  0
# 36  ERROR: perdoes.cli line 6 storing group cartap...        No warnings
#
#                       imported          imported_string
# 18  2024-09-05 14:08:58.722843  2024-09-05 14:08:58 UTC
# 24  2024-09-05 14:09:48.971480  2024-09-05 14:09:48 UTC
# 26                           0                        0
# 27                           0                        0
# 28  2024-09-05 14:10:01.093308  2024-09-05 14:10:01 UTC
# 29                           0                        0
# 30                           0                        0
# 32                           0                        0
# 35                           0                        0
# 36  2024-09-05 14:10:20.021564  2024-09-05 14:10:20 UTC
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Check the status of the files

# %% [markdown]
# Check the import status of the translated files
#
# * I: Imported
# * E: Imported with error
# * W: Imported with warnings no errors
# * N: Not imported
# * U: Translation updated need to reimport

# %%
imported_files_df = tlnb.get_import_status()
imported_files_df[["import_status","import_errors","import_warnings","name","errors","warnings","path"]].sort_values("name")
# Out:
#    import_status  import_errors  import_warnings  \
# 0              I              0                0
# 1              I              0                0
# 2              I              0                0
# 3              I              0                0
# 4              I              0                0
# 5              I              0                0
# 6              I              0                0
# 7              I              0                0
# 8              I              0                0
# 9              I              0                0
# 10             I              0                0
# 11             I              0                0
# 12             I              0                0
# 13             I              0                0
# 14             I              0                0
# 15             I              0                0
# 16             I              0                0
# 17             I              0                0
# 18             E             28               28
# 19             I              0                0
# 20             I              0                0
# 21             I              0                0
# 22             I              0                0
# 23             I              0                0
# 24             E             83               83
# 25             I              0                0
# 26             N              0                0
# 27             N              0                0
# 28             E             10               10
# 29             N              0                0
# 30             N              0                0
# 31             I              0                0
# 32             N              0                0
# 33             I              0                0
# 34             I              0                0
# 35             N              0                0
# 36             E             80               80
# 37             I              0                0
# 38             I              0                0
# 39             I              0                0
# 40             I              0                0
# 41             I              0                0
# 42             I              0                0
#
#                                          name  errors  warnings  \
# 0                               Devedores.cli       0         0
# 1                              EmpFAfonso.cli       0         2
# 2                              auc-alunos.cli       0         0
# 3                        auc_cartulario18.cli       0         0
# 4                     bap-com-celebrantes.cli       0         0
# 5                                bapt1714.cli       0         0
# 6                       bapteirasproblem1.cli       0         0
# 7                       bapteirasproblem2.cli       0         0
# 8             cas1714-1722-com-celebrante.cli       0         0
# 9                            cas1714-1722.cli       0         0
# 10                          coja-rol-1841.cli       0         0
# 11                             crisma1753.cli       0         0
# 12                             dehergne-a.cli       0         0
# 13                dehergne-locations-1644.cli       0         0
# 14                    docsregiospontepisc.cli       0         0
# 15                             eiras-rol1.cli       0         0
# 16                             eiras-rol2.cli       0         0
# 17                             eiras-rol3.cli       0         0
# 18                              eleicoes1.cli       0         0
# 19                         genealdiversas.cli       0         0
# 20                         glopes-lap1561.cli       0         3
# 21                                   ivcc.cli       0         0
# 22                            lrazao516pe.cli       0         0
# 23           mhk_identification_toliveira.cli       0         0
# 24                                misMesa.cli       0         0
# 25                 mp758-santiago-beduido.cli       0         0
# 26                                 nommiz.cli       1         3
# 27                             notarial80.cli       1         0
# 28                              notlousa1.cli       0         0
# 29                                 ob1688.cli       2         0
# 30                                ob1688b.cli       2         0
# 31                               obit1714.cli       0         0
# 32                       obiteirasproblem.cli      11         0
# 33                             obitoShort.cli       0         0
# 34                          obitoShort_id.cli       0         0
# 35                       obitoShort_id_id.cli       1         0
# 36                                perdoes.cli       0         0
# 37                                 quotes.cli       0         0
# 38            rogeriodomingos_bap_problem.cli       0         0
# 39  sourecoimbrabispcoimbra_apontamentosd.cli       0         0
# 40                       testeParentescos.cli       0         0
# 41                               vereacao.cli       0         0
# 42                    xpto_comuns_soure.kleio       0         0
#
#                                                  path
# 0         kleio/reference_sources/varia/Devedores.cli
# 1        kleio/reference_sources/varia/EmpFAfonso.cli
# 2        kleio/reference_sources/varia/auc-alunos.cli
# 3   kleio/reference_sources/varia/auc_cartulario18...
# 4   kleio/reference_sources/paroquiais/baptismos/b...
# 5   kleio/reference_sources/paroquiais/baptismos/b...
# 6   kleio/reference_sources/paroquiais/baptismos/b...
# 7   kleio/reference_sources/paroquiais/baptismos/b...
# 8   kleio/reference_sources/paroquiais/casamentos/...
# 9   kleio/reference_sources/paroquiais/casamentos/...
# 10  kleio/reference_sources/roisdeconfessados/coja...
# 11  kleio/reference_sources/paroquiais/crisma/cris...
# 12  kleio/reference_sources/linked_data/dehergne-a...
# 13  kleio/reference_sources/linked_data/dehergne-l...
# 14  kleio/reference_sources/notariais/docsregiospo...
# 15  kleio/reference_sources/roisdeconfessados/eira...
# 16  kleio/reference_sources/roisdeconfessados/eira...
# 17  kleio/reference_sources/roisdeconfessados/eira...
# 18        kleio/reference_sources/varia/eleicoes1.cli
# 19   kleio/reference_sources/varia/genealdiversas.cli
# 20   kleio/reference_sources/varia/glopes-lap1561.cli
# 21             kleio/reference_sources/varia/ivcc.cli
# 22      kleio/reference_sources/varia/lrazao516pe.cli
# 23   identifications/mhk_identification_toliveira.cli
# 24          kleio/reference_sources/varia/misMesa.cli
# 25  kleio/reference_sources/varia/mp758-santiago-b...
# 26           kleio/reference_sources/varia/nommiz.cli
# 27   kleio/reference_sources/notariais/notarial80.cli
# 28    kleio/reference_sources/notariais/notlousa1.cli
# 29  kleio/reference_sources/paroquiais/obitos/ob16...
# 30  kleio/reference_sources/paroquiais/obitos/ob16...
# 31  kleio/reference_sources/paroquiais/obitos/obit...
# 32  kleio/reference_sources/paroquiais/obitos/obit...
# 33  kleio/reference_sources/paroquiais/obitos/obit...
# 34  kleio/reference_sources/paroquiais/obitos/obit...
# 35  kleio/reference_sources/paroquiais/obitos/obit...
# 36      kleio/reference_sources/notariais/perdoes.cli
# 37           kleio/reference_sources/varia/quotes.cli
# 38  kleio/reference_sources/paroquiais/baptismos/r...
# 39  kleio/reference_sources/varia/sourecoimbrabisp...
# 40  kleio/reference_sources/paroquiais/obitos/test...
# 41         kleio/reference_sources/varia/vereacao.cli
# 42  kleio/reference_sources/varia/xpto_comuns_sour...

# %% [markdown]
# ### Check a translation report
#
# If needed to check for errors.

# %%
file_number=1
rpt = tlnb.get_translation_report(imported_files_df, file_number)
print(rpt)
# Out:
# KleioTranslator - server version 12.6 - build 574 2024-09-05 21:48:12
# 5-9-2024 14-1
#
# Processing data file EmpFAfonso.cli
# -------------------------------------------
# Generic Act translation module with geoentities (XML).
#      Joaquim Ramos de Carvalho (joaquim@uc.pt)
# ** New document: kleio
# =========================
# kleio translation started
# =========================
# Structure: gacto2.str
# Prefix: sj
# Autorel: sj
# Translation count: 5
# Obs:
# ** Processing source fonte$sj-avexplorfa
#
# WARNING: EmpFAfonso.cli line 3 * Warning: Filename should match source Id to avoid errors. File: EmpFAfonso Id: sj-avexplorfa.
# Near lines: 3
# Near lines: 4       escritura$cex1322.1/18/6/1322/emprazamento/fol=cx.6, mc.27, n.620/loc=coimbra, igreja de santa justa/sumario=martim peres, procurador do prior de santa justa, empraza a joao anes, albardeiro, e a maria simoes sua mulher, uma casa na rua de oleiros, por 4 libras/obs=perg., bom, gotico cursivo, sinal notarial.
#
#
# WARNING: EmpFAfonso.cli line 3 Element value exceeds database field length: loc=cx.5, mc.27, n.620;cx.4, mc.23, n.462;cx.2, mc.9, n.172;cx.1, mc.5, n.121;cx.1, mc.5, n.123;cx.4, mc.23, n.459;cx.1, mc.5, n.124;cx.4, mc.25, n.519;cx.6, mc.33, n.755;cx.4, mc.25, n.498;cx.1, mc.6, n.140;. Size:204 limit: 64
# Near lines: 3
# Near lines: 4       escritura$cex1322.1/18/6/1322/emprazamento/fol=cx.6, mc.27, n.620/loc=coimbra, igreja de santa justa/sumario=martim peres, procurador do prior de santa justa, empraza a joao anes, albardeiro, e a maria simoes sua mulher, uma casa na rua de oleiros, por 4 libras/obs=perg., bom, gotico cursivo, sinal notarial.
#
# 6: escritura$sj-cex1322.1
# 56: escritura$sj-cex1324.1
# 96: escritura$sj-cex1324.2
# 142: escritura$sj-cex1325.1
# 173: escritura$sj-cex1329.1
# 220: escritura$sj-cex1330.1
# 256: escritura$sj-cex1335.1
# 302: escritura$sj-cex1340.1
# 348: escritura$sj-cex1344.1
# 400: escritura$sj-cex1347.1
# 459: escritura$sj-cex1348.1
# *** End of File
#
#
# Structure file: /usr/local/timelink/clio/src/gacto2.str
# Structure processing report: /usr/local/timelink/clio/src/gacto2.srpt
# Structure in JSON: /usr/local/timelink/clio/src/gacto2.str.json
#
# Kleio file: /kleio-home/kleio/reference_sources/varia/EmpFAfonso.cli
# Original file: /kleio-home/kleio/reference_sources/varia/EmpFAfonso.org
# Previous version: /kleio-home/kleio/reference_sources/varia/EmpFAfonso.old
# Temp file with ids: /kleio-home/kleio/reference_sources/varia/EmpFAfonso.ids
# ** - /kleio-home/kleio/reference_sources/varia/EmpFAfonso.cli-renamed to- /kleio-home/kleio/reference_sources/varia/EmpFAfonso.old
# 0  errors.
# 2  warnings.
# Translation finished.

# %% [markdown]
# ### Get the import report for a file
#
# In case there are errors in the import phase check the import report.

# %%
rpt = tlnb.get_import_rpt(imported_files_df, rows=[0])
print(rpt)
# Out:
# auc-alunos.cli
# No errors
# No warnings
