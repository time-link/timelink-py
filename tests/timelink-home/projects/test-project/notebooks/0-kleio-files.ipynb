# %% [markdown]
# # Managing Kleio files

# %% [markdown]
# > First time use: follow instructions in the [README.md](README.md) file in this directory.

# %% [markdown]
# ## Initial setup
#
# Create a TimelinkNotebook object. This will be the interface for most of your interactions with Timelink.
#
# The first time you run this notebook, you will be prompted to install ìpykernel. This is required to run Timelink in a notebook.
#
# Note:
# * First time run takes a little time as the required Docker images are downloaded.
# * Timelink will default to using sqlite as the database, see [Receipts notebook for more control](1-receipts.ipynb)

# %%
# NBVAL_IGNORE_OUTPUT

from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook(kleio_image='kleio-server', kleio_version='12.6.575')
tlnb.print_info(show_token=True)
# Out:
# Timelink version: 1.1.13
# Project name: test-project
# Project home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project
# Database type: sqlite
# Database name: test_project
# Kleio image: kleio-server
# Kleio server token: 98Sctgm07QxIsK9tEKKJFAiWjaSbzZ73
# Kleio server URL: http://127.0.0.1:8088
# Kleio server home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project
# Kleio server container: adoring_germain
# Kleio version requested: 12.6.575
# Kleio server version: 12.6.575 (2024-09-06 14:08:58)
# SQLite directory: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project/database/sqlite
# Call print_info(show_password=True) to show the Postgres password
# TimelinkNotebook(project_name=test-project, project_home=/Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project, db_type=sqlite, db_name=test_project, kleio_image=kleio-server, kleio_version=12.6.575, postgres_image=postgres, postgres_version=latest)

# %% [markdown]
# TimelinkNotebook created a database to store data and a Kleio server to
# translate transcriptions in Kleio notation into data that can be imported
# into a database.
#
# To get information about the database and the Kleio server do ```tnlb.print_info()```

# %% [markdown]
# ### Database status
#
# Count the number of rows in each table in the database.

# %%
# NBVAL_IGNORE_OUTPUT

tlnb.table_row_count_df()
# Out:
#                table  count
# 0              actas      0
# 1               acts   2146
# 2        aforamentos    126
# 3         aregisters      1
# 4         attributes  40717
# 5             cartas      5
# 6   cartas_de_perdao      0
# 7   class_attributes    151
# 8            classes     26
# 9            dividas     52
# 10          entities  97230
# 11        escrituras    223
# 12           eventos     44
# 13          gelement   1552
# 14       geoentities    242
# 15             goods    238
# 16        households   1008
# 17             items      4
# 18        kleiofiles     76
# 19           objects   1399
# 20           perdoes      0
# 21           persons  20901
# 22         relations  30137
# 23         rentities     65
# 24      rgeoentities      0
# 25          robjects      0
# 26          rpersons     65
# 27             sizas      6
# 28           sources     44
# 29            syslog      0
# 30            syspar      0

# %% [markdown]
# ### Show the kleio files available

# %%
# NBVAL_IGNORE_OUTPUT

kleio_files = tlnb.get_kleio_files()
kleio_files
# Out:
#                                                  path  \
# 0       sources/reference_sources/varia/Devedores.cli
# 1      sources/reference_sources/varia/auc-alunos.cli
# 2   sources/reference_sources/varia/auc_cartulario...
# 3      sources/reference_sources/varia/avexplorfa.cli
# 4   sources/reference_sources/paroquiais/baptismos...
# 5   sources/reference_sources/paroquiais/baptismos...
# 6   sources/reference_sources/paroquiais/baptismos...
# 7   sources/reference_sources/paroquiais/baptismos...
# 8   sources/reference_sources/paroquiais/casamento...
# 9   sources/reference_sources/paroquiais/casamento...
# 10  sources/reference_sources/roisdeconfessados/co...
# 11  sources/reference_sources/paroquiais/crisma/cr...
# 12              sources/cronologias/crono-avulsos.cli
# 13  sources/reference_sources/linked_data/dehergne...
# 14  sources/reference_sources/linked_data/dehergne...
# 15  sources/reference_sources/notariais/docsregios...
# 16  sources/reference_sources/roisdeconfessados/ei...
# 17  sources/reference_sources/roisdeconfessados/ei...
# 18  sources/reference_sources/roisdeconfessados/ei...
# 19      sources/reference_sources/varia/eleicoes1.cli
# 20  sources/reference_sources/varia/genealdiversas...
# 21  sources/reference_sources/varia/glopes-lap1561...
# 22           sources/reference_sources/varia/ivcc.cli
# 23    sources/reference_sources/varia/lrazao516pe.cli
# 24   identifications/mhk_identification_toliveira.cli
# 25        sources/reference_sources/varia/misMesa.cli
# 26  sources/reference_sources/varia/mp758-santiago...
# 27         sources/reference_sources/varia/nommiz.cli
# 28  sources/reference_sources/notariais/notarial80...
# 29  sources/reference_sources/notariais/notlousa1.cli
# 30  sources/reference_sources/paroquiais/obitos/ob...
# 31  sources/reference_sources/paroquiais/obitos/ob...
# 32  sources/reference_sources/paroquiais/obitos/ob...
# 33  sources/reference_sources/paroquiais/obitos/ob...
# 34  sources/reference_sources/paroquiais/obitos/ob...
# 35  sources/reference_sources/paroquiais/obitos/ob...
# 36  sources/reference_sources/paroquiais/obitos/ob...
# 37    sources/reference_sources/notariais/perdoes.cli
# 38         sources/reference_sources/varia/quotes.cli
# 39  sources/reference_sources/paroquiais/baptismos...
# 40  sources/reference_sources/varia/sourecoimbrabi...
# 41  sources/reference_sources/paroquiais/obitos/te...
# 42       sources/reference_sources/varia/vereacao.cli
# 43  sources/reference_sources/varia/xpto_comuns_so...
#
#                                          name  \
# 0                               Devedores.cli
# 1                              auc-alunos.cli
# 2                        auc_cartulario18.cli
# 3                              avexplorfa.cli
# 4                     bap-com-celebrantes.cli
# 5                                bapt1714.cli
# 6                       bapteirasproblem1.cli
# 7                       bapteirasproblem2.cli
# 8             cas1714-1722-com-celebrante.cli
# 9                            cas1714-1722.cli
# 10                          coja-rol-1841.cli
# 11                             crisma1753.cli
# 12                          crono-avulsos.cli
# 13                             dehergne-a.cli
# 14                dehergne-locations-1644.cli
# 15                    docsregiospontepisc.cli
# 16                             eiras-rol1.cli
# 17                             eiras-rol2.cli
# 18                             eiras-rol3.cli
# 19                              eleicoes1.cli
# 20                         genealdiversas.cli
# 21                         glopes-lap1561.cli
# 22                                   ivcc.cli
# 23                            lrazao516pe.cli
# 24           mhk_identification_toliveira.cli
# 25                                misMesa.cli
# 26                 mp758-santiago-beduido.cli
# 27                                 nommiz.cli
# 28                             notarial80.cli
# 29                              notlousa1.cli
# 30                                 ob1688.cli
# 31                                ob1688b.cli
# 32                               obit1714.cli
# 33                       obiteirasproblem.cli
# 34                             obitoShort.cli
# 35                          obitoShort_id.cli
# 19  ERROR: eleicoes1.cli line 6 storing group amz$...        No warnings
# 20                                          No errors        No warnings
# 21                                                  0                  0
# 22                                          No errors        No warnings
# 23                                          No errors        No warnings
# 24                                          No errors        No warnings
# 25  ERROR: misMesa.cli line 6 storing group amz$am...        No warnings
# 26                                          No errors        No warnings
# 27                                                  0                  0
# 28                                          No errors        No warnings
# 29  ERROR: notlousa1.cli line 618 storing group ca...        No warnings
# 30                                          No errors        No warnings
# 31                                          No errors        No warnings
# 32                                          No errors        No warnings
# 33                                                  0                  0
# 34                                                  0                  0
# 35                                                  0                  0
# 36                                                  0                  0
# 37                                                  0                  0
# 38                                                  0                  0
# 39                                                  0                  0
# 40                                                  0                  0
# 41                                                  0                  0
# 42                                                  0                  0
# 43                                                  0                  0
#
#                       imported  \
# 0   2024-09-11 01:37:56.780964
# 1   2024-09-11 01:39:11.772703
# 2   2024-09-11 01:39:24.420112
# 3                            0
# 4   2024-09-11 01:39:26.078970
# 5   2024-09-11 01:39:35.297943
# 6   2024-09-11 01:39:56.161592
# 7   2024-09-11 01:40:24.114116
# 8   2024-09-11 01:40:25.721871
# 9   2024-09-11 01:40:46.781368
# 10  2024-09-11 01:41:35.642439
# 11  2024-09-11 01:41:37.086405
# 12                           0
# 13  2024-09-11 01:41:47.868891
# 14  2024-09-11 01:41:53.196622
# 15  2024-09-11 01:41:54.521711
# 16  2024-09-11 01:42:09.642466
# 17  2024-09-11 01:42:24.965287
# 18  2024-09-11 01:42:40.656437
# 19  2024-09-11 01:42:49.920958
# 20  2024-09-11 01:42:59.277966
# 21                           0
# 22  2024-09-11 01:43:03.741396
# 23  2024-09-11 01:43:23.887167
# 24  2024-09-11 01:43:25.499078
# 25  2024-09-11 01:43:37.731545
# 26  2024-09-11 01:43:39.246812
# 27                           0
# 28  2024-09-11 01:43:45.788755
# 29  2024-09-11 01:43:55.972414
# 30  2024-09-11 01:44:00.059773
# 31  2024-09-11 01:44:04.217582
# 32  2024-09-11 01:44:06.665948
# 33                           0
# 34                           0
# 35                           0
# 36                           0
# 37                           0
# 38                           0
# 39                           0
# 40                           0
# 41                           0
# 42                           0
# 43                           0
#
#                                               rpt_url  \
# 0   /rest/reports/sources/reference_sources/varia/...
# 1   /rest/reports/sources/reference_sources/varia/...
# 2   /rest/reports/sources/reference_sources/varia/...
# 3   /rest/reports/sources/reference_sources/varia/...
# 4   /rest/reports/sources/reference_sources/paroqu...
# 5   /rest/reports/sources/reference_sources/paroqu...
# 6   /rest/reports/sources/reference_sources/paroqu...
# 7   /rest/reports/sources/reference_sources/paroqu...
# 8   /rest/reports/sources/reference_sources/paroqu...
# 9   /rest/reports/sources/reference_sources/paroqu...
# 10  /rest/reports/sources/reference_sources/roisde...
# 11  /rest/reports/sources/reference_sources/paroqu...
# 12  /rest/reports/sources/cronologias/crono-avulso...
# 13  /rest/reports/sources/reference_sources/linked...
# 14  /rest/reports/sources/reference_sources/linked...
# 15  /rest/reports/sources/reference_sources/notari...
# 16  /rest/reports/sources/reference_sources/roisde...
# 17  /rest/reports/sources/reference_sources/roisde...
# 18  /rest/reports/sources/reference_sources/roisde...
# 19  /rest/reports/sources/reference_sources/varia/...
# 20  /rest/reports/sources/reference_sources/varia/...
# 21  /rest/reports/sources/reference_sources/varia/...
# 22  /rest/reports/sources/reference_sources/varia/...
# 23  /rest/reports/sources/reference_sources/varia/...
# 24  /rest/reports/identifications/mhk_identificati...
# 25  /rest/reports/sources/reference_sources/varia/...
# 26  /rest/reports/sources/reference_sources/varia/...
# 27  /rest/reports/sources/reference_sources/varia/...
# 28  /rest/reports/sources/reference_sources/notari...
# 29  /rest/reports/sources/reference_sources/notari...
# 30  /rest/reports/sources/reference_sources/paroqu...
# 31  /rest/reports/sources/reference_sources/paroqu...
# 32  /rest/reports/sources/reference_sources/paroqu...
# 33  /rest/reports/sources/reference_sources/paroqu...
# 34  /rest/reports/sources/reference_sources/paroqu...
# 35  /rest/reports/sources/reference_sources/paroqu...
# 36  /rest/reports/sources/reference_sources/paroqu...
# 37  /rest/reports/sources/reference_sources/notari...
# 38  /rest/reports/sources/reference_sources/varia/...
# 39  /rest/reports/sources/reference_sources/paroqu...
# 40  /rest/reports/sources/reference_sources/varia/...
# 41  /rest/reports/sources/reference_sources/paroqu...
# 42  /rest/reports/sources/reference_sources/varia/...
# 43  /rest/reports/sources/reference_sources/varia/...
#
#                                               xml_url
# 0   /rest/exports/sources/reference_sources/varia/...
# 1   /rest/exports/sources/reference_sources/varia/...
# 2   /rest/exports/sources/reference_sources/varia/...
# 3   /rest/exports/sources/reference_sources/varia/...
# 4   /rest/exports/sources/reference_sources/paroqu...
# 5   /rest/exports/sources/reference_sources/paroqu...
# 6   /rest/exports/sources/reference_sources/paroqu...
# 7   /rest/exports/sources/reference_sources/paroqu...
# 8   /rest/exports/sources/reference_sources/paroqu...
# 9   /rest/exports/sources/reference_sources/paroqu...
# 10  /rest/exports/sources/reference_sources/roisde...
# 11  /rest/exports/sources/reference_sources/paroqu...
# 12  /rest/exports/sources/cronologias/crono-avulso...
# 13  /rest/exports/sources/reference_sources/linked...
# 14  /rest/exports/sources/reference_sources/linked...
# 15  /rest/exports/sources/reference_sources/notari...
# 16  /rest/exports/sources/reference_sources/roisde...
# 17  /rest/exports/sources/reference_sources/roisde...
# 18  /rest/exports/sources/reference_sources/roisde...
# 19  /rest/exports/sources/reference_sources/varia/...
# 20  /rest/exports/sources/reference_sources/varia/...
# 21  /rest/exports/sources/reference_sources/varia/...
# 22  /rest/exports/sources/reference_sources/varia/...
# 23  /rest/exports/sources/reference_sources/varia/...
# 24  /rest/exports/identifications/mhk_identificati...
# 25  /rest/exports/sources/reference_sources/varia/...
# 26  /rest/exports/sources/reference_sources/varia/...
# 27  /rest/exports/sources/reference_sources/varia/...
# 28  /rest/exports/sources/reference_sources/notari...
# 29  /rest/exports/sources/reference_sources/notari...
# 30  /rest/exports/sources/reference_sources/paroqu...
# 31  /rest/exports/sources/reference_sources/paroqu...
# 32  /rest/exports/sources/reference_sources/paroqu...
# 33  /rest/exports/sources/reference_sources/paroqu...
# 34  /rest/exports/sources/reference_sources/paroqu...
# 35  /rest/exports/sources/reference_sources/paroqu...
# 36  /rest/exports/sources/reference_sources/paroqu...
# 37  /rest/exports/sources/reference_sources/notari...
# 38  /rest/exports/sources/reference_sources/varia/...
# 39  /rest/exports/sources/reference_sources/paroqu...
# 40  /rest/exports/sources/reference_sources/varia/...
# 41  /rest/exports/sources/reference_sources/paroqu...
# 42  /rest/exports/sources/reference_sources/varia/...
# 43  /rest/exports/sources/reference_sources/varia/...

# %% [markdown]
# ## Optionally clean translations

# %%
# NBVAL_IGNORE_OUTPUT

# tlnb.kleio_server.translation_clean("", recurse="yes")

# %% [markdown]
# # Update the database from Kleio sources.
#
# Updates source translations and imports into database sources with no errors.
#
# Only changed files since last import, or new files, will be processed.

# %%
# NBVAL_IGNORE_OUTPUT

import logging
logging.basicConfig(level=logging.INFO)

tlnb.update_from_sources()
# get the import status
import_status = tlnb.get_import_status()
# list those with import_error > 0 or error > 0
errors = import_status.query("import_errors > 0 or errors > 0")
if len(errors) > 0:
    print(errors)
# Out:
# INFO:root:Importing sources/cronologias/crono-avulsos.cli
#                                                  path                  name  \
# 19      sources/reference_sources/varia/eleicoes1.cli         eleicoes1.cli
# 25        sources/reference_sources/varia/misMesa.cli           misMesa.cli
# 29  sources/reference_sources/notariais/notlousa1.cli         notlousa1.cli
# 36  sources/reference_sources/paroquiais/obitos/ob...  obitoShort_id_id.cli
# 37    sources/reference_sources/notariais/perdoes.cli           perdoes.cli
#
#      size                                    directory  \
# 19  42582              sources/reference_sources/varia
# 25  70053              sources/reference_sources/varia
# 29  53260          sources/reference_sources/notariais
# 36    751  sources/reference_sources/paroquiais/obitos
# 37  80615          sources/reference_sources/notariais
#
#                            modified              modified_iso  \
# 19 2024-09-10 13:32:07.318267+00:00 2024-09-10 13:32:07+00:00
# 25 2024-09-10 13:32:23.166097+00:00 2024-09-10 13:32:23+00:00
# 29 2024-09-10 13:32:31.663148+00:00 2024-09-10 13:32:31+00:00
# 36 2024-09-10 13:32:36.646748+00:00 2024-09-10 13:32:36+00:00
# 37 2024-09-10 13:32:40.759103+00:00 2024-09-10 13:32:40+00:00
#
#         modified_string                     qtime         qtime_string  \
# 19  2024-09-10 13:32:07 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 25  2024-09-10 13:32:23 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 29  2024-09-10 13:32:31 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 36  2024-09-10 13:32:36 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
# 37  2024-09-10 13:32:40 1970-01-01 00:00:00+00:00  1970-01-01 00:00:00
#
#                                            source_url  ...  \
# 19  /rest/sources/sources/reference_sources/varia/...  ...
# 25  /rest/sources/sources/reference_sources/varia/...  ...
# 29  /rest/sources/sources/reference_sources/notari...  ...
# 36  /rest/sources/sources/reference_sources/paroqu...  ...
# 37  /rest/sources/sources/reference_sources/notari...  ...
#
#                                               version  \
# 19  KleioTranslator - server version 12.6 - build ...
# 25  KleioTranslator - server version 12.6 - build ...
# 29  KleioTranslator - server version 12.6 - build ...
# 36  KleioTranslator - server version 12.6 - build ...
# 37  KleioTranslator - server version 12.6 - build ...
#
#                                               rpt_url  \
# 19  /rest/reports/sources/reference_sources/varia/...
# 25  /rest/reports/sources/reference_sources/varia/...
# 29  /rest/reports/sources/reference_sources/notari...
# 36  /rest/reports/sources/reference_sources/paroqu...
# 37  /rest/reports/sources/reference_sources/notari...
#
#                                               xml_url  import_status  \
# 19  /rest/exports/sources/reference_sources/varia/...              E
# 25  /rest/exports/sources/reference_sources/varia/...              E
# 29  /rest/exports/sources/reference_sources/notari...              E
# 36  /rest/exports/sources/reference_sources/paroqu...              E
# 37  /rest/exports/sources/reference_sources/notari...              E
#
#     import_errors import_warnings  \
# 19             28              28
# 25             83              83
# 29             10              10
# 36              1               1
# 37             80              80
#
#                                      import_error_rpt import_warning_rpt  \
# 19  ERROR: eleicoes1.cli line 6 storing group amz$...        No warnings
# 25  ERROR: misMesa.cli line 6 storing group amz$am...        No warnings
# 29  ERROR: notlousa1.cli line 618 storing group ca...        No warnings
# 36  ERROR: obitoShort_id_id.cli line 4 ** integrit...        No warnings
# 37  ERROR: perdoes.cli line 6 storing group cartap...        No warnings
#
#                      imported          imported_string
# 19 2024-09-11 01:42:49.920958  2024-09-11 01:42:49 UTC
# 25 2024-09-11 01:43:37.731545  2024-09-11 01:43:37 UTC
# 29 2024-09-11 01:43:55.972414  2024-09-11 01:43:55 UTC
# 36 2024-09-11 01:59:55.113224  2024-09-11 01:59:55 UTC
# 37 2024-09-11 02:00:05.558240  2024-09-11 02:00:05 UTC
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Check the status of the files

# %% [markdown]
# Check the import status of the translated files
#
# * I: Imported
# * E: Imported with error
# * W: Imported with warnings no errors
# * N: Not imported
# * U: Translation updated need to reimport

# %%
# NBVAL_IGNORE_OUTPUT

imported_files_df = tlnb.get_import_status()
imported_files_df[["import_status","import_errors","import_warnings","name","errors","warnings","path"]].sort_values("name")
# Out:
#    import_status  import_errors  import_warnings  \
# 0              I              0                0
# 1              I              0                0
# 2              I              0                0
# 3              I              0                0
# 4              I              0                0
# 5              I              0                0
# 6              I              0                0
# 7              I              0                0
# 8              I              0                0
# 9              I              0                0
# 10             I              0                0
# 11             I              0                0
# 12             I              0                0
# 13             I              0                0
# 14             I              0                0
# 15             I              0                0
# 16             I              0                0
# 17             I              0                0
# 18             E             28               28
# 19             I              0                0
# 20             I              0                0
# 21             I              0                0
# 22             I              0                0
# 23             I              0                0
# 24             E             83               83
# 25             I              0                0
# 26             I              0                0
# 27             I              0                0
# 28             E             10               10
# 29             I              0                0
# 30             I              0                0
# 31             I              0                0
# 32             I              0                0
# 33             I              0                0
# 34             I              0                0
# 35             E              1                1
# 36             E             80               80
# 37             I              0                0
# 38             I              0                0
# 39             I              0                0
# 40             I              0                0
# 41             I              0                0
# 42             I              0                0
#
#                                          name  errors  warnings  \
# 0                               Devedores.cli       0         0
# 1                              auc-alunos.cli       0         0
# 2                        auc_cartulario18.cli       0         0
# 3                              avexplorfa.cli       0         1
# 4                     bap-com-celebrantes.cli       0         0
# 5                                bapt1714.cli       0         0
# 6                       bapteirasproblem1.cli       0         0
# 7                       bapteirasproblem2.cli       0         0
# 8             cas1714-1722-com-celebrante.cli       0         0
# 9                            cas1714-1722.cli       0         0
# 10                          coja-rol-1841.cli       0         0
# 11                             crisma1753.cli       0         0
# 12                             dehergne-a.cli       0         0
# 13                dehergne-locations-1644.cli       0         0
# 14                    docsregiospontepisc.cli       0         0
# 15                             eiras-rol1.cli       0         0
# 16                             eiras-rol2.cli       0         0
# 17                             eiras-rol3.cli       0         0
# 18                              eleicoes1.cli       0         0
# 19                         genealdiversas.cli       0         0
# 20                         glopes-lap1561.cli       0         3
# 21                                   ivcc.cli       0         0
# 22                            lrazao516pe.cli       0         0
# 23           mhk_identification_toliveira.cli       0         0
# 24                                misMesa.cli       0         0
# 25                 mp758-santiago-beduido.cli       0         0
# 26                                 nommiz.cli       0         1
# 27                             notarial80.cli       0         0
# 28                              notlousa1.cli       0         0
# 29                                 ob1688.cli       0         0
# 30                                ob1688b.cli       0         0
# 31                               obit1714.cli       0         0
# 32                       obiteirasproblem.cli       0         0
# 33                             obitoShort.cli       0         0
# 34                          obitoShort_id.cli       0         0
# 35                       obitoShort_id_id.cli       0         0
# 36                                perdoes.cli       0         0
# 37                                 quotes.cli       0         0
# 38            rogeriodomingos_bap_problem.cli       0         0
# 39  sourecoimbrabispcoimbra_apontamentosd.cli       0         0
# 40                       testeParentescos.cli       0         0
# 41                               vereacao.cli       0         0
# 42                    xpto_comuns_soure.kleio       0         0
#
#                                                  path
# 0         kleio/reference_sources/varia/Devedores.cli
# 1        kleio/reference_sources/varia/auc-alunos.cli
# 2   kleio/reference_sources/varia/auc_cartulario18...
# 3        kleio/reference_sources/varia/avexplorfa.cli
# 4   kleio/reference_sources/paroquiais/baptismos/b...
# 5   kleio/reference_sources/paroquiais/baptismos/b...
# 6   kleio/reference_sources/paroquiais/baptismos/b...
# 7   kleio/reference_sources/paroquiais/baptismos/b...
# 8   kleio/reference_sources/paroquiais/casamentos/...
# 9   kleio/reference_sources/paroquiais/casamentos/...
# 10  kleio/reference_sources/roisdeconfessados/coja...
# 11  kleio/reference_sources/paroquiais/crisma/cris...
# 12  kleio/reference_sources/linked_data/dehergne-a...
# 13  kleio/reference_sources/linked_data/dehergne-l...
# 14  kleio/reference_sources/notariais/docsregiospo...
# 15  kleio/reference_sources/roisdeconfessados/eira...
# 16  kleio/reference_sources/roisdeconfessados/eira...
# 17  kleio/reference_sources/roisdeconfessados/eira...
# 18        kleio/reference_sources/varia/eleicoes1.cli
# 19   kleio/reference_sources/varia/genealdiversas.cli
# 20   kleio/reference_sources/varia/glopes-lap1561.cli
# 21             kleio/reference_sources/varia/ivcc.cli
# 22      kleio/reference_sources/varia/lrazao516pe.cli
# 23   identifications/mhk_identification_toliveira.cli
# 24          kleio/reference_sources/varia/misMesa.cli
# 25  kleio/reference_sources/varia/mp758-santiago-b...
# 26           kleio/reference_sources/varia/nommiz.cli
# 27   kleio/reference_sources/notariais/notarial80.cli
# 28    kleio/reference_sources/notariais/notlousa1.cli
# 29  kleio/reference_sources/paroquiais/obitos/ob16...
# 30  kleio/reference_sources/paroquiais/obitos/ob16...
# 31  kleio/reference_sources/paroquiais/obitos/obit...
# 32  kleio/reference_sources/paroquiais/obitos/obit...
# 33  kleio/reference_sources/paroquiais/obitos/obit...
# 34  kleio/reference_sources/paroquiais/obitos/obit...
# 35  kleio/reference_sources/paroquiais/obitos/obit...
# 36      kleio/reference_sources/notariais/perdoes.cli
# 37           kleio/reference_sources/varia/quotes.cli
# 38  kleio/reference_sources/paroquiais/baptismos/r...
# 39  kleio/reference_sources/varia/sourecoimbrabisp...
# 40  kleio/reference_sources/paroquiais/obitos/test...
# 41         kleio/reference_sources/varia/vereacao.cli
# 42  kleio/reference_sources/varia/xpto_comuns_sour...

# %% [markdown]
# ### Check a translation report
#
# If needed to check for errors.

# %%
# NBVAL_IGNORE_OUTPUT

file_number=1
rpt = tlnb.get_translation_report(imported_files_df, file_number)
print(rpt)
# Out:
# KleioTranslator - server version 12.6 - build 575 2024-09-06 14:08:58
# 7-9-2024 12-51
#
# Processing data file auc-alunos.cli
# -------------------------------------------
# Generic Act translation module with geoentities (XML).
#      Joaquim Ramos de Carvalho (joaquim@uc.pt)
# ** New document: kleio
# =========================
# kleio translation started
# =========================
# Structure: gacto2.str
# Prefix:
# Autorel:
# Translation count: 10
# Obs:
# ** Processing source fonte$auc-alunos
# 30: lista$auc-alumni-A-140337-140771
# *** End of File
#
#
# Structure file: /usr/local/timelink/clio/src/gacto2.str
# Structure processing report: /usr/local/timelink/clio/src/gacto2.srpt
# Structure in JSON: /usr/local/timelink/clio/src/gacto2.str.json
#
# Kleio file: /kleio-home/kleio/reference_sources/varia/auc-alunos.cli
# Original file: /kleio-home/kleio/reference_sources/varia/auc-alunos.org
# Previous version: /kleio-home/kleio/reference_sources/varia/auc-alunos.old
# Temp file with ids: /kleio-home/kleio/reference_sources/varia/auc-alunos.ids
# ** - /kleio-home/kleio/reference_sources/varia/auc-alunos.cli-renamed to- /kleio-home/kleio/reference_sources/varia/auc-alunos.old
# 0  errors.
# 0  warnings.
# Translation finished.

# %% [markdown]
# ### Get the import report for a file
#
# In case there are errors in the import phase check the import report.

# %%
# NBVAL_IGNORE_OUTPUT

rpt = tlnb.get_import_rpt(imported_files_df, rows=[0])
print(rpt)
# Out:
# Devedores.cli
# No errors
# No warnings
