# %% [markdown]
# # Testing to_kleio() functions

# %%
# NBVAL_IGNORE_OUTPUT

from timelink.notebooks import TimelinkNotebook as TLN

tlnb = TLN(db_name='kleio_tests')
tlnb.print_info()
# Out:
# WARNING:root:Reusing existing container distracted_austin
# Timelink version: 1.1.26
# Project name: test-project
# Project home: /Users/jrc/develop/timelink-py-worktree/1.1.27/tests/timelink-home/projects/test-project
# Database type: sqlite
# Database name: kleio_tests
# Kleio image: timelinkserver/kleio-server
# Kleio server token: WqvpC...
# Kleio server URL: http://127.0.0.1:8089
# Kleio server home: /Users/jrc/develop/timelink-py-worktree/1.1.27/tests/timelink-home/projects/test-project
# Kleio server container: distracted_austin
# Kleio version requested: latest
# Kleio server version: 12.9.588 (2025-06-06 16:04:22)
# SQLite directory: /Users/jrc/develop/timelink-py-worktree/1.1.27/tests/timelink-home/projects/test-project/database/sqlite
# Database version: 6ccf1ef385a6
# Call print_info(show_token=True) to show the Kleio Server token
# Call print_info(show_password=True) to show the Postgres password
# TimelinkNotebook(project_name=test-project, project_home=/Users/jrc/develop/timelink-py-worktree/1.1.27/tests/timelink-home/projects/test-project, db_type=sqlite, db_name=kleio_tests, kleio_image=timelinkserver/kleio-server, kleio_version=latest, postgres_image=postgres, postgres_version=latest)

# %%
# NBVAL_IGNORE_OUTPUT

tlnb.update_from_sources(path='./sources/reference_sources/linked_data/dehergne-locations-1644.cli', force=False)
tlnb.update_from_sources(path='./sources/reference_sources/devassas/dev1692.cli', force=False)
# Out:
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/kleio/groups/kgroup.py:769: UserWarning: Created a KElement class for idcaso. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/kleio/groups/kgroup.py:769: UserWarning: Created a KElement class for literal. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/api/models/pom_som_mapper.py:698: UserWarning: Ambiguous mapping! more than one element of caso is mapped to column class type check mapping for this group
#   element: KElement = group.get_element_by_name_or_class(cattr.colclass)
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/kleio/groups/kgroup.py:769: UserWarning: Created a KElement class for origem. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/api/models/pom_som_mapper.py:698: UserWarning: Ambiguous mapping! more than one element of testo is mapped to column class sex check mapping for this group
#   element: KElement = group.get_element_by_name_or_class(cattr.colclass)
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/api/models/pom_som_mapper.py:698: UserWarning: Ambiguous mapping! more than one element of referido is mapped to column class sex check mapping for this group
#   element: KElement = group.get_element_by_name_or_class(cattr.colclass)
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/kleio/groups/kgroup.py:769: UserWarning: Created a KElement class for idcaso. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/kleio/groups/kgroup.py:769: UserWarning: Created a KElement class for literal. Better to create explicit or provide  synonyms= in group creation.
#   el = self.pack_as_kelement(arg, value)
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/api/models/pom_som_mapper.py:698: UserWarning: Ambiguous mapping! more than one element of acusado is mapped to column class sex check mapping for this group
#   element: KElement = group.get_element_by_name_or_class(cattr.colclass)
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/api/models/pom_som_mapper.py:698: UserWarning: Ambiguous mapping! more than one element of acusada is mapped to column class sex check mapping for this group
#   element: KElement = group.get_element_by_name_or_class(cattr.colclass)
# /Users/jrc/develop/timelink-py-worktree/1.1.27/.venv/lib/python3.12/site-packages/timelink/api/models/pom_som_mapper.py:698: UserWarning: Ambiguous mapping! more than one element of referida is mapped to column class sex check mapping for this group
#   element: KElement = group.get_element_by_name_or_class(cattr.colclass)

# %%
# NBVAL_IGNORE_OUTPUT

tlnb.table_row_count_df()
# Out:
#                table  count
# 0               acts      2
# 1          acusacoes    178
# 2    alembic_version      1
# 3         aregisters      0
# 4         attributes    858
# 5             blinks      0
# 6              casos     26
# 7   class_attributes     66
# 8            classes     12
# 9           entities   2244
# 10       geoentities    215
# 11        kleiofiles      2
# 12             links     22
# 13           objects    204
# 14           persons    192
# 15         relations    749
# 16         rentities     10
# 17           sources      2
# 18            syslog      0
# 19            syspar      0

# %%
from timelink.api.models import Source

with tlnb.db.session() as db:
    sources = db.query(Source.id).all()
    for source in sources:
        print(source)
# Out:
# ('dehergne-locations-1644',)
# ('dev1692',)

# %% [markdown]
# ### Show geodesc type source

# %%
with tlnb.db.session() as session:
    source1 = session.get(Source, sources[0])
    print(source1.to_kleio(show_function=False, show_inrels=False)[:9046])
# Out:
# fonte$dehergne-locations-1644/0/type=geoinformation/ref=None/loc=None/kleiofile="/kleio-home/sources/reference_sources/linked_data/dehergne-locations-1644.cli""/replaces=None/obs="""
#       Planche: Carte des Chrétientés Chinoises de la fin des Ming (1644).p. 353
#
#       _Diocèse_
#       Depuis 1514, l'évêché de Funchal (île de Madère)
#       s'étend jusqu'aux extrémi-
#       tés de l'Asie. Depuis le 3 nov. 1534 est
#       créé l'évêché de Goa, dont est déta-
#       ché, le 23 janv. 1576, le diocèse de
#       Macao, qui sera amputé, 14 février
#       1588, du Japon (évêché de Funai):
#       l'évêché de Macao comprend théori-
#       quement tout l'empire de Chine.
#
#       _Provinces Jésuites_
#
#       la vice-province du Japon (province en
#       1611); en 1623, la vice-province de Chine
#       indépendante du Japon en est déta-
#       chée; mais un visiteur jésuite contrôle
#       l'une et l'autre.
#
#       La Chine impériale distingue dans chaque province civile les _fou_, préfec-
#       tures ou villes de premier ordre, dont dépendent les _tcheou_ et les _hien_. D'au-
#       tres agglomérations importantes comme Tientsin (alors wei) ou encore Amoy
#       et Fatshan n'ont pas reçu le titre de hien. Dans notre tableau, les villes autres
#       que les fou sont mises en italiques, et la capitale de chaque province, en
#       majuscule. Sur la carte, nous mettons en lettres majuscules les seuls fou et
#       tcheou possédant une chrétienté (pour les tcheou, majuscules penchées); les
#       hien, en lettres ordinaires, et nous n'inscrivons (en petites lettres) que les
#       bourgs et demeures chrétiennes antérieures à la persécution de 1615.
#          Pour les jésuites de l'époque, le mot collège désigne une résidence prin-
#       cipale d'où dépendent (d'un point de vue économique beaucoup plus que juri-
#       dique), un certain nombre de petites résidences qui lui sont rattachées. La
#       carte, qui accompagne ces pages comme celle des résidences en 1701, est due au
#       Père Pierre Moreau, SJ., et nous lui exprimons ici nos remerciements.
#          Une résidence est une maison propriété de la mission: elle est soit occupée
#       par un ou plusieurs missionnaire (ici: R) ou cette anné-là, sans prêtre
#       à demeure (R'); tandis que le mot église s'applique à une chapelle, un oratoire
#       ou un temple plus important ; d'autres fois, le prêtre dit la messe chez des fidè-
#       les, dans leur propre maison. Toute résidence possède une église ou oratoire.
#       Sur la carte, les Résidences sont marquées par un cercle. Résidences et chré-
#       tientés sont, à l'époque, presque toutes aux Jésuites. Dans le cas contraire,
#       nous faisons suivre le nom de la localité de la mention de l'Ordre qui les pos-
#       sède: (OP), Dominicains; (OFM), Franciscains; (OESA), Augustins.
#          On observera que le cours du Fleuve Jaune n'était pas le même qu'actuel-
#       lement, et que les chrétientés se sont développées le long des grandes routes
#       (le fait est frappant pour la région du Kiangnan). Pour les chrétientés an-
#       ciennes des Ming voir aussi MS XVI, 1957 (avec carte en couleurs).
#
#       N.B. N.B. Pour compléter ce tableau des antiquités chrétiennes de la Chine, rap-
#       pelons qu'en Mongolie à Olon-Sume, ancienne capitale des Ongiit nestoriens,
#       il y eut, outre une église nestorienne, une église catholique de Giovanni de Mon-
#       tecorvino (1247-1328) « le plus ancien exemple de sanctuaire catholique en Ex-
#       trême-Orient » Egami, Namio dans Journal Asiatique, CCXL 1952, 155-167 cf NZM
#       1954, p. 56); du même, Découverte 'l'église romaine' établie au XIII' siècle
#       en Mongolie, Conferenze, Rome, 1955, 41-55; cf BernahdC-Maitrb], Henri, La dé-
#       couverte des Nestoriens Mongols aux Ordos et l'Histoire ancienne du Christia-
#       nisme en Extrême-Orient, Tientsin, 1935. — Les ruines de l'église franciscaine
#       de Nankin au XIV* siècle ont été décrites par Prip-Molleb dans la revue
#       danoise Artes; résumé dans Chinese Recorder, 1935, 654-656 et hors-texte 641.
#       Etc.
#
#       NOTA TRANSCRIÇÃO
#
#       "geo1$ = Provincia"
#       "geo2$ = fou (perfeitura ou cidade de 1ª ordem)"
#       "geo3$ = tcheou-hien"
#
#       Em cada entrada o formato é
#
#          "geoN$Nome geográfico/Tipo (província, fou, tcheou-hien)/id=deh-r1644-nome"
#
#       Exº
#          "geo1$Chekiang#Zhejiang/província/deh-r1644-chekiang"
#          "geo2$Hangchou#Hangzhou/capital provincial/deh-r1644-hangzhou"
#          "geo3$Fuyang/tchou-hien/deh-r1644-fuyang"
#
#       Nos locais onde há presença de missionários:
#
#          "atr$residencia-missao/Jesuíta/16110000 (onde aparece R)"
#          "atr$residencia-missao/Dominicanos%OP/16560000"
#                         (quando passa a residência de outra ordem
#                          ver abreviaturas na legenda do mapa, exº p.354 em Kinhua)
#          "atr$activa/sim/16110000"         (onde só aparece uma data)
#
#       edited by Skye
#       and Joaquim Carvalho
#       and Alicia
#       """
#   geodesc$deh-chre-1644/16440000/type=geodesc/ref=None/loc=None
#     geo1$Chekiang#hoje:Zhejiang, 浙江, @wikidata:Q16967%Tche-kiang/província
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q16967"#hoje:Zhejiang, 浙江, @wikidata:Q16967%Q16967/1644
#     geo1$Fukien#Fou-kien, hoje: Fujian, 福建, @wikidata:Q41705/província
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q41705"#Fou-kien, hoje: Fujian, 福建, @wikidata:Q41705%Q41705/1644
#     geo1$Honan#hoje:Henan, 河南, @wikidata:Q43684/província/obs=(12 ou 13 chrétientés en 1641)
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q43684"#hoje:Henan, 河南, @wikidata:Q43684%Q43684/1644
#     geo1$Hukwang#Huguang?, Hou-Quang, hoje:Huguang,湖广, @wikidata:Q2235155/região/obs=Former province of China, corresponding to modern-day Hubei and Hunan provinces
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q2235155"#Huguang?, Hou-Quang, hoje:Huguang,湖广, @wikidata:Q2235155%Q2235155/1644
#       atr$alternative-name@wikidata/"https://www.wikidata.org/wiki/Q46862"%Houpeh/1644
#       atr$alternative-name/Houpeh#Hou-pe, hoje:Hubei,湖北， @wikidata:Q46862/1644
#     geo1$Hunan#Hou-nan, hoje:Hunan, 湖南, @wikidata:Q45761/província
#       rel$geografica/pertence região/Hukwang/deh-r1644-hunan/1644
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q45761"#Hou-nan, hoje:Hunan, 湖南, @wikidata:Q45761%Q45761/1644
#     geo1$Kiangnan#Jiangnan?hoje:Jiangnan, 江南, @wikidata:Q11133842, former province of China, corresponding to modern-day Jiangsu and Anhui provinces%KIANGNAN ou NANKING/região
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q11133842"#Jiangnan?hoje:Jiangnan, 江南, @wikidata:Q11133842, former province of China, corresponding to modern-day Jiangsu and Anhui provinces%Q11133842/1644
#     geo1$Anhwei#Anhui, Ngon-hoei, hoje:Anhui, 安徽, @wikidata:Q40956/província
#       rel$geografica/pertence região/Kiangnan/deh-r1644-anhwei/1644
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q40956"#Anhui, Ngon-hoei, hoje:Anhui, 安徽, @wikidata:Q40956%Q40956/1644
#     geo1$Kiangsu#Jiangju, hoje: Jiangsu, 江苏, @wikidata:Q16963/província
#       rel$geografica/pertence região/Kiangnan/deh-r1644-kiangsu/1644
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q16963"#Jiangju, hoje: Jiangsu, 江苏, @wikidata:Q16963%Q16963/1644
#     geo1$Kiangsi#Jiangxi, Kiang-si, hoje: Jiangxi, 江西, @wikidata: Q57052/província
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q57052"#Jiangxi, Kiang-si, hoje: Jiangxi, 江西, @wikidata: Q57052%Q57052/1644
#     geo1$Kwangsi#Guangxi, Koang-si, hoje: Guangxi, 广西, @wikidata: Q15176/província
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q15176"#Guangxi, Koang-si, hoje: Guangxi, 广西, @wikidata: Q15176%Q15176/1644
#     geo1$Kwangtung#Guangdong, hoje:Guangdong, 广东, @wikidata: Q15175/província
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q15175"#Guangdong, hoje:Guangdong, 广东, @wikidata: Q15175%Q15175/1644
#     geo1$Kwichow#Koei-Tcheou, hoje: Guizhou, 贵州, @wikidata: Q47097/província/obs=nada
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q47097"#Koei-Tcheou, hoje: Guizhou, 贵州, @wikidata: Q47097%Q47097/1644
#     geo1$Pequim/província
#     geo1$Shansi#Chan-si, hoje: Shanxi, 山西, @wikidata: Q46913/província
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q46913"#Chan-si, hoje: Shanxi, 山西, @wikidata: Q46913%Q46913/1644
#     geo1$Shangtung#Chan-tong, Shandong, 山东, @wikidata: Q43407/província
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q43407"#Chan-tong, Shandong, 山东, @wikidata: Q43407%Q43407/1644
#     geo1$Shensi#Chen-si, hoje: Shaanxi, 陕西, hoje: Q47974, @wikidata:Q47974/província
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q47974"#Chen-si, hoje: Shaanxi, 陕西, hoje: Q47974, @wikidata:Q47974%Q47974/1644
#     geo1$Szechwan#Se-tch'oan, hoje: Sichuan, 四川, @wikidata: Q19770/província
#       atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q19770"#Se-tch'oan, hoje: Sichu

# %% [markdown]
# ### Show devasa type source

# %%
# NBVAL_IGNORE_OUTPUT
# we have to do this because there is a fluctuation in the rendering of acusa and caso
with tlnb.db.session() as session:
    source2 = session.get(Source, sources[1])
    print(source2.to_kleio(show_function=False, show_inrels=False)[:2048])
# Out:
# fonte$dev1692/0/type=devassa/ref=None/loc=auc III-d,5,2,135/kleiofile="/kleio-home/sources/reference_sources/devassas/dev1692.cli""/replaces=None
#   devassa$devass1692/16920410/type=devassa/ref=fol?/loc=None/obs="""
#
#       Pároco Luís Álvaro Pinto.
#       A visita e' feita na igreja da Misericórdia em vários dias.
#       Continua em 13 de Abril de 1692.
#       Continua em 15 de Abril de 1692 (a partir da testemunha 33 inc.).
#       Continua em 16 de Abril de 1692 (a partir da testemunha 45 inc.).
#       Continua em 17 de Abril de 1692 (a partir da testemunha 62 inc.).
#       Continua em 18 de Abril de 1692 (a partir da testemunha 74 inc.).
#       Continua em 19 de abril de 1692 (a partir da testemunha 83 inc.).
#       """
#     testo$jose machado/m/id=dev1692-per1
#       ls$ec/s/1692-04-10
#       ls$residencia/soure/1692-04-10
#       ls$idade/24/1692-04-10
#       ls$assina/b/1692-04-10
#       pai$manuel fernandes/m/id=dev1692-per1-per2
#         rel$parentesco/pai/jose machado/dev1692-per1-per2/1692-04-10
#         ls$alcunha/ratinho/1692-04-10
#       acusa$dev1692-per1-obj1-20/idcaso=c1692-antonio-cordeiro-alcouc/literal=alcouceiro e alcoviteiro de varias mulheres que levava a casa de alguns homens e as entregava em sua propria casa/id=dev1692-per1-obj1-20
#         caso$c1692-antonio-cordeiro-alcouc/obs=dava mulheres em casa. Margem: tirada de ambos 1.1.1691%1o. 8.bro 691/id=c1692-antonio-cordeiro-alcouc
#           acusado$antonio cordeiro/m/id=d1692-2003
#             rel$parentesco/marido/francisca nunes/d1692-2003/1692-04-10
#             rel$visita/alcov/maria simoes/d1692-2003/1692-04-10
#             rel$visita/alcov/domingas simoes/d1692-2003/1692-04-10
#             rel$visita/dava_mulheres/antonio correia/d1692-2003/1692-04-10
#             rel$visita/dava_mulheres/joao costa/d1692-2003/1692-04-10
#             rel$visita/dava_mulheres/jose cunha e sa/d1692-2003/1692-04-10
#             rel$visita/dava_mulheres/manuel homem de quadros/d1692-2003/1692-04-10
#             rel$visita/dava_mulheres/manuel fernandes nogueira/d1692-2003/1692-04-10

# %% [markdown]
# ## Test rendering in kleio of dynamic group

# %%
# NBVAL_IGNORE_OUTPUT
# currently need to ignore there is a problem with the kleio rendering fluctuating
from timelink.api.models import Entity, Person

# an accusation in a "devassa"
id = 'dev1692-per1-obj1-20'
with tlnb.db.session() as session:
    entity = session.get(Entity, id)
    print("Um grupo dinâmico convertido para str:")
    print(entity)
    print("--------------------")
    print("O mesmo grupo dinâmico convertido para kleio:")
    print(entity.to_kleio(show_inrels=False)[:2048])
    # Witness
    person = session.get(Person, 'dev1692-per12')
    print("--------------------")
    print("Uma pessoa que inclui o grupo dinâmico:")
    print()
    print(person.to_kleio(show_function=False, show_inrels=False)[:2048])
# Out:
# Um grupo dinâmico convertido para str:
# acusa$dev1692-per1-obj1-20/idcaso=c1692-antonio-cordeiro-alcouc/literal=alcouceiro e alcoviteiro de varias mulheres que levava a casa de alguns homens e as entregava em sua propria casa/id=dev1692-per1-obj1-20
# --------------------
# O mesmo grupo dinâmico convertido para kleio:
# acusa$dev1692-per1-obj1-20/idcaso=c1692-antonio-cordeiro-alcouc/literal=alcouceiro e alcoviteiro de varias mulheres que levava a casa de alguns homens e as entregava em sua propria casa/id=dev1692-per1-obj1-20
#   caso$c1692-antonio-cordeiro-alcouc/obs=dava mulheres em casa. Margem: tirada de ambos 1.1.1691%1o. 8.bro 691/id=c1692-antonio-cordeiro-alcouc
#     acusado$antonio cordeiro/m/id=d1692-2003
#       rel$parentesco/marido/francisca nunes/d1692-2003/1692-04-10
#       rel$visita/alcov/maria simoes/d1692-2003/1692-04-10
#       rel$visita/alcov/domingas simoes/d1692-2003/1692-04-10
#       rel$visita/dava_mulheres/antonio correia/d1692-2003/1692-04-10
#       rel$visita/dava_mulheres/joao costa/d1692-2003/1692-04-10
#       rel$visita/dava_mulheres/jose cunha e sa/d1692-2003/1692-04-10
#       rel$visita/dava_mulheres/manuel homem de quadros/d1692-2003/1692-04-10
#       rel$visita/dava_mulheres/manuel fernandes nogueira/d1692-2003/1692-04-10/obs=cf. test.a 84
#       rel$visita/alcov/maria esteva?/d1692-2003/1692-04-10/obs=segundo a testemunha Maria de Jesus
#       ls$alcunha/calhau/1692-04-10
#       ls$ec/c/1692-04-10
#       ls$profissao/sapateiro/1692-04-10
#       ls$residencia/soure/1692-04-10
#       ls$residencia/soure, rua do rossio/1692-04-10
#     acusada$francisca nunes#ou francisca simoes/f/id=d1692-2004
#       ls$nome/fancisca simoes/1692-04-10
#       ls$ec/c/1692-04-10
#       referida$maria simoes/f/id=d1692-2005/obs=era das mulheres que antonio cordeiro dava em sua casa
#         ls$nome/maria da silva/1692-04-10
#         ls$alcunha/ruiva/1692-04-10
#       referida$domingas simoes/f/id=d1692-2006/obs=era das mulheres que antonio cordeiro dava em sua casa
#         rel$parentesco/cunhada/antonio cordeiro/d1692-2006/1692-04-10
#         ls$ec/s/1692-04-10
#       referido$antonio correia/m/id=d1692-2007/obs=frequentava mulheres em casa de antonio cordeiro
#         ls$profissao/meirinho do tabaco?/1692-04-10
#       referido$joao costa/m/id=d1692-2008/obs=frequentava mulheres em casa de antonio cordeiro
#         ls$profissao/escrivao do tabaco
# --------------------
# Uma pessoa que inclui o grupo dinâmico:
#
# testo$manuel ferreira/f/id=dev1692-per12
#   ls$alcunha/moco/1692-04-10
#   ls$profissao/sapateiro/1692-04-10
#   ls$residencia/paleao/1692-04-10
#   ls$idade/31/1692-04-10
#   acusa$dev1692-per12-obj8-20/idcaso=c1692-manuel-pinto-domingas-roxa/id=dev1692-per12-obj8-20
#   acusa$dev1692-per12-obj9-20/idcaso=c1692-mateus-dias-curas/obs=muitos detalhes, diz que lhe rende bem o oficio/id=dev1692-per12-obj9-20
#   acusa$dev1692-per12-obj10-20/idcaso=c1692-manuel aires-domingas-luis/obs=sabe nome da mulher dele, e dizem que os dois vivem casas juntas/id=dev1692-per12-obj10-20
#   acusa$dev1692-per12-obj11-20/idcaso=c1692-antonio-gomes-maria/id=dev1692-per12-obj11-20
#   acusa$dev1692-per12-obj12-20/idcaso=c1692-catarina-gaspar-curas/id=dev1692-per12-obj12-20
#   referida$antonia rodrigues/f/id=d1692-2024
#     rel$parentesco/mulher/manuel aires/d1692-2024/1692-04-10/obs=primeira mulher
#     rel$parentesco/prima/domingas luis/d1692-2024/1692-04-10
#     ls$morta/antes#ja morta em 1692/1692-04-10
