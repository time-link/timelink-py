# %% [markdown]
# # Using Timelink in notebooks: tutorial

# %% [markdown]
# > First time use: follow instructions in the [README.md](README.md) file in this directory.

# %% [markdown]
# ## Initial setup
#
# Create a TimelinkNotebook object. This will be the interface for most of your interactions with Timelink.
#
# The first time you run this notebook, you will be prompted to install ìpykernel. This is required to run Timelink in a notebook.
#
# Note:
# * First time run takes a little time as the required Docker images are downloaded.
# * Timelink will default to using sqlite as the database, see [Receipts notebook for more control](1-receipts.ipynb)

# %%
from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook()

# %% [markdown]
# TimelinkNotebook created a database to store data and a Kleio server to
# translate transcriptions in Kleio notation into data that can be imported
# into a database.
#
# To get information about the database and the Kleio server do ```tnlb.print_info()```

# %%
tlnb.print_info()
# Out:
# Project name: tutorial
# Project home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial
# Database type: sqlite
# Database name: tutorial
# Kleio image: timelinkserver/kleio-server
# Kleio version: latest
# Kleio server token: yNEupdoWvbKkAfALXitPVuC0D9PXUkPa
# Kleio server URL: http://127.0.0.1:8089
# Kleio server home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial
# SQLite directory: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial/database/sqlite
# TimelinkNotebook(project_name=tutorial, project_home=/Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial, db_type=sqlite, db_name=tutorial, kleio_image=timelinkserver/kleio-server, kleio_version=latest, postgres_image=postgres, postgres_version=latest)

# %% [markdown]
# ### Database status
#
# Count the number of rows in each table in the database.

# %%
tlnb.table_row_count_df()
# Out:
#                table  count
# 0               acts      3
# 1         attributes  14680
# 2   class_attributes     63
# 3            classes     13
# 4           entities  17182
# 5        geoentities    215
# 6              goods      0
# 7         kleiofiles      3
# 8            objects      0
# 9            persons    873
# 10         relations   1395
# 11         rentities      0
# 12      rgeoentities      0
# 13          robjects      0
# 14          rpersons      0
# 15           sources      3
# 16            syslog      0
# 17            syspar      0

# %% [markdown]
# ### Show the sources imported into the database

# %%
imported_files = tlnb.get_imported_files()
if len(imported_files) > 0:
    imported_files[["name","imported","nerrors","nwarnings"]].head()
else:
    print("No imported files")
imported_files
# Out:
#                                             path                         name  \
# 0               /kleio-home/kleio/auc-alunos.cli               auc-alunos.cli
# 1  /kleio-home/kleio/dehergne-locations-1644.cli  dehergne-locations-1644.cli
# 2               /kleio-home/kleio/dehergne-a.cli               dehergne-a.cli
#
#                                  structure     translator    translation_date  \
# 0  /usr/local/timelink/clio/src/gacto2.str  gactoxml2.str 2024-02-04 08:37:10
# 1  /usr/local/timelink/clio/src/gacto2.str  gactoxml2.str 2024-02-04 08:40:20
# 2  /usr/local/timelink/clio/src/gacto2.str  gactoxml2.str 2024-02-04 14:08:26
#
#    nerrors  nwarnings  error_rpt  warning_rpt                   imported  \
# 0        0          0  No errors  No warnings 2024-02-04 08:38:54.291236
# 1        0          0  No errors  No warnings 2024-02-04 08:40:24.149131
# 2        0          0  No errors  No warnings 2024-02-04 14:08:36.475775
#
#            imported_string
# 0  2024-02-04 08:38:54 UTC
# 1  2024-02-04 08:40:24 UTC
# 2  2024-02-04 14:08:36 UTC

# %% [markdown]
# # Update the database from Kleio sources.
#
# Updates source translations and imports into database sources with no errors.
#
# Only changed files since last import, or new files, will be processed.

# %%
import logging
logging.basicConfig(level=logging.INFO)

tlnb.update_from_sources()

# %% [markdown]
# ## Check the status of the files

# %% [markdown]
# Check the import status of the translated files
#
# I: Imported
#
# E: Imported with error
#
# W: Imported with warnings no errors
#
# N: Not imported
#
# U: Translation updated need to reimport

# %%
imported_files_df = tlnb.get_import_status()
imported_files_df[["import_status","import_errors","import_warnings","name","errors","warnings","path"]].sort_values("name")
# Out:
#   import_status  import_errors  import_warnings                         name  \
# 0             I              0                0               auc-alunos.cli
# 1             I              0                0               dehergne-a.cli
# 2             I              0                0  dehergne-locations-1644.cli
#
#    errors  warnings                               path
# 0       0         0               kleio/auc-alunos.cli
# 1       0         0               kleio/dehergne-a.cli
# 2       0         0  kleio/dehergne-locations-1644.cli

# %% [markdown]
# ### Check the translation report

# %%
rpt = tlnb.get_translation_report(imported_files_df, 1)
print(rpt)
# Out:
# KleioTranslator - server version 12.2 - build 560 2024-01-08 08:18:15
# 4-2-2024 14-8
#
# Processing data file dehergne-a.cli
# -------------------------------------------
# Generic Act translation module with geoentities (XML).
#      Joaquim Ramos de Carvalho (joaquim@uc.pt)
# ** New document: kleio
# =========================
# kleio translation started
# =========================
# Structure: gacto2.str
# Prefix:
# Autorel:
# Translation count: 178
# Obs:
# ** Processing source fonte$dehergne-a
# 7: lista$dehergne-notices-a
# *** End of File
#
# Line 541 "SAME AS" TO EXTERNAL REFERENCE EXPORTED (deh-belchior-miguel-carneiro-leitao) CHECK IF IT EXISTS BEFORE IMPORTING THIS FILE.
# Line 814 "SAME AS" TO EXTERNAL REFERENCE EXPORTED (deh-jean-regis-lieou) CHECK IF IT EXISTS BEFORE IMPORTING THIS FILE.
# Line 876 "SAME AS" TO EXTERNAL REFERENCE EXPORTED (deh-alessandro-cicero) CHECK IF IT EXISTS BEFORE IMPORTING THIS FILE.
#
# Structure file: /usr/local/timelink/clio/src/gacto2.str
# Structure processing report: /usr/local/timelink/clio/src/gacto2.srpt
# Structure in JSON: /usr/local/timelink/clio/src/gacto2.str.json
#
# Kleio file: /kleio-home/kleio/dehergne-a.cli
# Original file: /kleio-home/kleio/dehergne-a.org
# Previous version: /kleio-home/kleio/dehergne-a.old
# Temp file with ids: /kleio-home/kleio/dehergne-a.ids
# ** - /kleio-home/kleio/dehergne-a.cli-renamed to- /kleio-home/kleio/dehergne-a.old
# 0  errors.
# 0  warnings.
# Translation finished.

# %% [markdown]
# ### Get the import report for a file
#
# In case there are errors in the import phase check the import report.

# %%
rpt = tlnb.get_import_rpt(imported_files_df, rows=[0])
print(rpt)
# Out:
# No errors
# No warnings

# %% [markdown]
# ## Todo

# %% [markdown]
# This as data frame in a single function
# * TimelinkNotebook.translate([files_df,paths=List[str], rows=List[int],status="T"])
# * TimelinkNotebook.import([files_df,paths=List[str], rows=List[int],status="V"])

# %% [markdown]
# # Obter dados
# ---
#
# # Getting data

# %% [markdown]
# ### Procurar pessoa, mostrar em notação Kleio
#
# ---
# ### Search for people, show in Kleio notation

# %%
from timelink.api.models import Person

show_only=10

with tlnb.db.session() as session:
    persons = session.query(Person).filter(Person.name.like('%Abegão')).all()

    for person in persons[:show_only]:
        print(person.to_kleio())
        print()
# Out:
# n$Estevão de Matos Abegão/m/id=140338/obs="""
#       """
#
#                   Id: 140338
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000002
#
#                   Nome        : Estevão de Matos Abegão
#                   Data inicial: 1728-10-01
#                   Data final  : 1733-07-03
#                   Filiação: Lourenço de Matos Pereira
#                   Naturalidade: Elvas
#                   Faculdade: Cânones
#
#                   Matrícula(s): 01.10.1729
#                   01.10.1730
#                   01.10.1732
#
#                   Instituta: 01.10.1728
#
#                   Bacharel: 03.07.1733
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000002""/2021-05-17
#   atr$data-do-registo/2021-05-17/2021-05-17
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140338""/2021-05-17
#   ls$uc.entrada/1728-10-01/1728-10-01
#   ls$uc.saida/1733-07-03/1733-07-03
#   ls$uc.entrada.ano/1728/1728-10-01
#   ls$uc.saida.ano/1733/1733-07-03
#   ls$nome/Estevão de Matos Abegão/1728-10-01
#   ls$nome.primeiro/Estevão/1728-10-01
#   ls$nome.apelido/Matos Abegão/1728-10-01
#   ls$nome.apelido/Abegão/1728-10-01
#   ls$naturalidade/Elvas/1728-10-01
#   ls$naturalidade.ano/Elvas.1728/1728-10-01
#   ls$nome-geografico/Elvas/1728-10-01
#   ls$nome-geografico.ano/Elvas.1728/1728-10-01
#   ls$faculdade/Cânones/1728-10-01
#   ls$faculdade.ano/Cânones.1728/1728-10-01
#   ls$matricula/Cânones/1729-10-01/obs=01.10.1729
#   ls$matricula.ano/Cânones.1729/1729-10-01/obs=01.10.1729
#   ls$matricula/Cânones/1730-10-01/obs=01.10.1730
#   ls$matricula.ano/Cânones.1730/1730-10-01/obs=01.10.1730
#   ls$matricula/Cânones/1732-10-01/obs=01.10.1732
#   ls$matricula.ano/Cânones.1732/1732-10-01/obs=01.10.1732
#   ls$grau/Bacharel/1733-07-03/obs=03.07.1733
#   ls$grau.ano/Bacharel.1733/1733-07-03/obs=03.07.1733
#   ls$instituta/1728-10-01/1728-10-01/obs=01.10.1728 1728-10-01
#   ls$instituta.ano/1728/1728-10-01/obs=01.10.1728 1728-10-01
#   pai$Lourenço de Matos Pereira/m/id=140338-pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211
#
# n$Jerónimo Rodrigues Abegão/m/id=140339/obs="""
#       """
#
#                   Id: 140339
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000003
#
#                   Nome        : Jerónimo Rodrigues Abegão
#                   Data inicial: 1732-10-01
#                   Data final  : 1746-06-15
#                   Filiação: Jerónimo Rodrigues Abegão
#                   Naturalidade: Portalegre
#                   Faculdade: Cânones
#
#                   Matrícula(s): 01.10.1733
#                   01.10.1734
#                   01.10.1735
#                   01.10.1736
#                   01.10.1737
#                   01.10.1738
#                   01.10.1741
#                   01.10.1745
#                   Instituta: 01.10.1732
#                   Bacharel: 12.04.1742, Atos e Graus 80, fl. 104 v.
#                   Formatura: 15.06.1746
#
#                   Outras informações: Tirou as cartas com o nome Jerónimo de Faria Vidal, Atos e Graus 80, fl. 104 v.
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000003""/2021-05-17
#   atr$data-do-registo/2021-05-17/2021-05-17
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140339""/2021-05-17
#   ls$uc.entrada/1732-10-01/1732-10-01
#   ls$uc.saida/1746-06-15/1746-06-15
#   ls$uc.entrada.ano/1732/1732-10-01
#   ls$uc.saida.ano/1746/1746-06-15
#   ls$nome/Jerónimo Rodrigues Abegão/1732-10-01
#   ls$nome.primeiro/Jerónimo/1732-10-01
#   ls$nome.apelido/Rodrigues Abegão/1732-10-01
#   ls$nome.apelido/Abegão/1732-10-01
#   ls$naturalidade/Portalegre/1732-10-01
#   ls$naturalidade.ano/Portalegre.1732/1732-10-01
#   ls$nome-geografico/Portalegre/1732-10-01
#   ls$nome-geografico.ano/Portalegre.1732/1732-10-01
#   ls$faculdade/Cânones/1732-10-01
#   ls$faculdade.ano/Cânones.1732/1732-10-01
#   ls$matricula/Cânones/1733-10-01/obs=01.10.1733
#   ls$matricula.ano/Cânones.1733/1733-10-01/obs=01.10.1733
#   ls$matricula/Cânones/1734-10-01/obs=01.10.1734
#   ls$matricula.ano/Cânones.1734/1734-10-01/obs=01.10.1734
#   ls$matricula/Cânones/1735-10-01/obs=01.10.1735
#   ls$matricula.ano/Cânones.1735/1735-10-01/obs=01.10.1735
#   ls$matricula/Cânones/1736-10-01/obs=01.10.1736
#   ls$matricula.ano/Cânones.1736/1736-10-01/obs=01.10.1736
#   ls$matricula/Cânones/1737-10-01/obs=01.10.1737
#   ls$matricula.ano/Cânones.1737/1737-10-01/obs=01.10.1737
#   ls$matricula/Cânones/1738-10-01/obs=01.10.1738
#   ls$matricula.ano/Cânones.1738/1738-10-01/obs=01.10.1738
#   ls$matricula/Cânones/1741-10-01/obs=01.10.1741
#   ls$matricula.ano/Cânones.1741/1741-10-01/obs=01.10.1741
#   ls$matricula/Cânones/1745-10-01/obs=01.10.1745
#   ls$matricula.ano/Cânones.1745/1745-10-01/obs=01.10.1745
#   ls$matricula/Cânones/1732-10-01/obs=01.10.1732
#   ls$matricula.ano/Cânones.1732/1732-10-01/obs=01.10.1732
#   ls$matricula/Cânones/1746-06-15/obs=15.06.1746
#   ls$matricula.ano/Cânones.1746/1746-06-15/obs=15.06.1746
#   ls$grau/Bacharel/1742-04-12/obs=12.04.1742, Atos e Graus 80, fl. 104 v.
#   ls$grau.ano/Bacharel.1742/1742-04-12/obs=12.04.1742, Atos e Graus 80, fl. 104 v.
#   ls$grau/Formatura/1746-06-15/obs=15.06.1746
#   ls$grau.ano/Formatura.1746/1746-06-15/obs=15.06.1746
#   ls$instituta/1732-10-01/1732-10-01/obs=01.10.1732 1732-10-01
#   ls$instituta.ano/1732/1732-10-01/obs=01.10.1732 1732-10-01
#   pai$Jerónimo Rodrigues Abegão/m/id=140339-pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211
#
# pai$Jerónimo Rodrigues Abegão/m/id=140339-pai
#   rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211

# %%
from sqlalchemy import select, and_
from sqlalchemy.orm import joinedload
from timelink.api.models import Person, Attribute

show_only=10

with tlnb.db.session() as session:
    stmt = select(Person).join(Person.attributes.and_(Attribute.the_type == 'naturalidade',
                                                      Attribute.the_value.like('Coimbra')))
    persons = session.execute(stmt).scalars().all()

    for person in persons[:show_only]:
        p = session.query(Person).filter(Person.id == person.id).options(joinedload(Person.attributes)).one()
        print(p.to_kleio())
# Out:
# 140349
# n$António de Aboim/m/id=140349/obs="""
#       """
#
#                   Id: 140349
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000015
#
#                   Nome        : António de Aboim
#                   Data inicial: 1566-12-20
#                   Data final  : 1574-07-24
#                   Filiação: Heitor Fernandes
#
#                   Naturalidade: Coimbra
#                   Faculdade: Cânones
#
#                   Matrícula(s): 07.10.1573
#                   Instituta:
#                   Bacharel: 20.07.1571
#                   Formatura: 24.07.1574
#                   Licenciado:
#                   Doutor:
#
#                   Outras informações:
#                   Provas de curso: Cânones: 20.12.1566 até 02.06.1567
#                   01.12.1567 até 15.05.1568
#                   01.10.1568 até 31.06.1569
#                   01.11.1569 até 31.07.1570
#                   01.10.1570 até 18.06.1571
#                   02.10.1572 até 30.06.1573
#                   01.10.1573 até 10.07.1574
#                   Conclusões: 10.05.1570
#                   Exame e Grau de Bacharel em Cânones: 20.07.1571
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000015""/2021-05-17
#   atr$data-do-registo/2021-05-17/2021-05-17
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140349""/2021-05-17
#   ls$uc.entrada/1566-12-20/1566-12-20
#   ls$uc.saida/1574-07-24/1574-07-24
#   ls$uc.entrada.ano/1566/1566-12-20
#   ls$uc.saida.ano/1574/1574-07-24
#   ls$nome/António de Aboim/1566-12-20
#   ls$nome.primeiro/António/1566-12-20
#   ls$nome.apelido/Aboim/1566-12-20
#   ls$naturalidade/Coimbra/1566-12-20
#   ls$naturalidade.ano/Coimbra.1566/1566-12-20
#   ls$nome-geografico/Coimbra/1566-12-20
#   ls$nome-geografico.ano/Coimbra.1566/1566-12-20
#   ls$faculdade/Cânones/1566-12-20
#   ls$faculdade.ano/Cânones.1566/1566-12-20
#   ls$matricula/Cânones/1573-10-07/obs=07.10.1573
#   ls$matricula.ano/Cânones.1573/1573-10-07/obs=07.10.1573
#   ls$matricula/Cânones/1571-07-20/obs=20.07.1571
#   ls$matricula.ano/Cânones.1571/1571-07-20/obs=20.07.1571
#   ls$matricula/Cânones/1574-07-24/obs=24.07.1574
#   ls$matricula.ano/Cânones.1574/1574-07-24/obs=24.07.1574
#   ls$grau/Bacharel/1571-07-20/obs=20.07.1571
#   ls$grau.ano/Bacharel.1571/1571-07-20/obs=20.07.1571
#   ls$grau/Formatura/1574-07-24/obs=24.07.1574
#   ls$grau.ano/Formatura.1574/1574-07-24/obs=24.07.1574
#   ls$exame/Exame e Grau de Bacharel em Cânones:/1571-07-20
#   pai$Heitor Fernandes/m/id=140349-pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211
# 140367
# n$Manuel de Vargas de Aboim/m/id=140367/obs="""
#       """
#
#                   Id: 140367
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000037
#
#                   Nome        : Manuel de Vargas de Aboim
#                   Data inicial:
#                   Data final  :
#                   Filiação: António de Aboim
#
#                   Naturalidade: Coimbra
#                   Faculdade: Cânones
#
#                   Matrícula(s):
#                   Instituta: .
#                   Bacharel:
#                   Formatura:
#                   Licenciado:
#                   Doutor:
#
#                   Outras informações:
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000037""/2021-05-17
#   atr$data-do-registo/2021-05-17/2021-05-17
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140367""/2021-05-17
#   ls$uc.entrada/0000-00-00/20200211
#   ls$uc.saida/0000-00-00/20200211
#   ls$nome/Manuel de Vargas de Aboim/20200211
#   ls$nome.primeiro/Manuel/20200211
#   ls$nome.apelido/Vargas de Aboim/20200211
#   ls$nome.apelido/Aboim/20200211
#   ls$naturalidade/Coimbra/20200211
#   ls$naturalidade.ano/Coimbra.0000/20200211
#   ls$nome-geografico/Coimbra/20200211
#   ls$faculdade/Cânones/20200211
#   ls$faculdade.ano/Cânones.0000/20200211
#   ls$matricula/Cânones/20200211
#   ls$matricula.ano/Cânones.0000/20200211
#   pai$António de Aboim/m/id=140367-pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211
# 140380
# n$António de Abranches/m/id=140380/obs="""
#       """
#
#                   Id: 140380
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000052
#
#                   Nome        : António de Abranches
#                   Data inicial: 1733-10-01
#                   Data final  : 1733-10-01
#                   Filiação:
#                   Naturalidade:  Coimbra
#                   Faculdade: Medicina
#
#                   Matrícula(s): 01.10.1733
#
#                   Bacharel em Artes: 14.04.1733
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000052""/2021-05-17
#   atr$data-do-registo/2021-05-17/2021-05-17
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140380""/2021-05-17
#   ls$uc.entrada/1733-10-01/1733-10-01
#   ls$uc.saida/1733-10-01/1733-10-01
#   ls$uc.entrada.ano/1733/1733-10-01
#   ls$uc.saida.ano/1733/1733-10-01
#   ls$nome/António de Abranches/1733-10-01
#   ls$nome.primeiro/António/1733-10-01
#   ls$nome.apelido/Abranches/1733-10-01
#   ls$naturalidade/Coimbra/1733-10-01
#   ls$naturalidade.ano/Coimbra.1733/1733-10-01
#   ls$nome-geografico/Coimbra/1733-10-01
#   ls$nome-geografico.ano/Coimbra.1733/1733-10-01
#   ls$faculdade/Medicina/1733-10-01
#   ls$faculdade.ano/Medicina.1733/1733-10-01
#   ls$matricula/Medicina/1733-10-01/obs=01.10.1733
#   ls$matricula.ano/Medicina.1733/1733-10-01/obs=01.10.1733
#   ls$grau/Bacharel em Artes/1733-04-14/obs=14.04.1733
#   ls$grau.ano/Bacharel em Artes.1733/1733-04-14/obs=14.04.1733
# 140538
# n$António de Abreu/m/id=140538/obs="""
#       """
#
#                   Id: 140538
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000233
#
#                   Nome        : António de Abreu
#                   Data inicial: 1670-10-01
#                   Data final  : 1679-07-19
#                   Filiação: António de Abreu
#
#                   Naturalidade: Coimbra
#                   Faculdade: Medicina
#
#                   Matrícula(s): 01.10.1670
#                   01.10.1671
#                   01.10.1672
#                   15.10.1673
#                   01.10.1674
#                   01.10.1675
#                   15.10.1676
#                   15.10.1677
#                   01.11.1678
#                   Instituta:
#                   Bacharel em Artes: 20.03.1671
#                   Formatura: 18.05.1675
#                   Licenciado: 15.08.1671
#                   Doutor: 09.07.1679
#
#                   Outras informações:
#                   1ª tentativa: 02.05.1674
#                   2ª tentativa: 26.05.1674
#                   Aprovação: 03.06.1676
#                   Suficiência: 05.06.1677
#                   2ª Suficiência: 28.06.1677
#                   Quodlibetus: 07.05.1678
#                   Acto Régio: 18.06.1678
#                   Exame Privado e Licenciado: 19.07.1678
#                   Vésperas: 08.07.1679
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000233""/2021-04-23
#   atr$data-do-registo/2021-04-23/2021-04-23
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=
#   ls$matricula/Cânones/1762-10-01/obs=01.10.1762
#   ls$matricula.ano/Cânones.1762/1762-10-01/obs=01.10.1762
#   ls$matricula/Cânones/1763-10-01/obs=01.10.1763
#   ls$matricula.ano/Cânones.1763/1763-10-01/obs=01.10.1763
#   ls$matricula/Cânones/1764-10-01/obs=01.10.1764
#   ls$matricula.ano/Cânones.1764/1764-10-01/obs=01.10.1764
#   ls$matricula/Cânones/1765-10-01/obs=01.10.1765
#   ls$matricula.ano/Cânones.1765/1765-10-01/obs=01.10.1765
#   ls$matricula/Cânones/1766-10-01/obs=01.10.1766
#   ls$matricula.ano/Cânones.1766/1766-10-01/obs=01.10.1766
#   ls$grau/Bacharel/1766-07-24/obs=24.07.1766, Atos 100, fl. 105
#   ls$grau.ano/Bacharel.1766/1766-07-24/obs=24.07.1766, Atos 100, fl. 105
#   ls$grau/Formatura/1767-05-24/obs=24.05.1767, Atos 101, fl. 60
#   ls$grau.ano/Formatura.1767/1767-05-24/obs=24.05.1767, Atos 101, fl. 60
#   ls$grau/Licenciado/1767-07-18/obs=Exame Privado e Grau de Licenciado: 18.07.1767, Atos 101, fl. 29
#   ls$grau.ano/Licenciado.1767/1767-07-18/obs=Exame Privado e Grau de Licenciado: 18.07.1767, Atos 101, fl. 29
#   ls$grau/Doutor/1767-07-27/obs=27.07.1767
#   ls$grau.ano/Doutor.1767/1767-07-27/obs=27.07.1767
#   ls$exame/Exame Privado e Grau de Licenciado:/1767-07-18/obs=Atos 101, fl. 29
#   pai$Gaspar de Abreu/m/id=140585-pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211
# 140626
# n$Augusto Cesário Vasconcelos Abreu/m/id=140626/obs="""
#       """
#
#                   Id: 140626
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000337
#
#                   Nome        : Augusto Cesário Vasconcelos Abreu
#                   Data inicial: 1868-10-02
#                   Data final  : 1872-10-03
#                   Filiação:
#
#                   Naturalidade: Coimbra
#                   Faculdade: Matemática#29;
#
#                   Matrícula(s): 1868/10/02 (obrigado)
#                   Filosofia: 1868/10/02 (ordinário)
#                   Medicina: 1872/10/03
#                   Instituta:
#                   Bacharel:
#                   Formatura:
#                   Licenciado:
#                   Doutor:
#
#                   Outras informações:
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000337""/2021-04-23
#   atr$data-do-registo/2021-04-23/2021-04-23
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140626""/2021-04-23
#   ls$uc.entrada/1868-10-02/1868-10-02
#   ls$uc.saida/1872-10-03/1872-10-03
#   ls$uc.entrada.ano/1868/1868-10-02
#   ls$uc.saida.ano/1872/1872-10-03
#   ls$nome/Augusto Cesário Vasconcelos Abreu/1868-10-02
#   ls$nome.primeiro/Augusto/1868-10-02
#   ls$nome.apelido/Cesário Vasconcelos Abreu/1868-10-02
#   ls$nome.apelido/Vasconcelos Abreu/1868-10-02
#   ls$nome.apelido/Abreu/1868-10-02
#   ls$naturalidade/Coimbra/1868-10-02
#   ls$naturalidade.ano/Coimbra.1868/1868-10-02
#   ls$nome-geografico/Coimbra/1868-10-02
#   ls$nome-geografico.ano/Coimbra.1868/1868-10-02
#   ls$faculdade/Matemática/1868-10-02/obs=""Matemática#29""
#   ls$matricula/Medicina/1761-10-01/obs=01.10.1761
#   ls$matricula.ano/Medicina.1761/1761-10-01/obs=01.10.1761
#   ls$matricula/Medicina/1762-10-01/obs=01.10.1762
#   ls$matricula.ano/Medicina.1762/1762-10-01/obs=01.10.1762
#   ls$matricula/Medicina/1763-10-01/obs=01.10.1763
#   ls$matricula.ano/Medicina.1763/1763-10-01/obs=01.10.1763
#   ls$matricula/Medicina/1764-10-01/obs=01.10.1764
#   ls$matricula.ano/Medicina.1764/1764-10-01/obs=01.10.1764
#   ls$grau/Bacharel em Artes/1758-04-08/obs=08.04.1758
#   ls$grau.ano/Bacharel em Artes.1758/1758-04-08/obs=08.04.1758
#   ls$grau/Licenciado/1760-06-08/obs=08.06.1760
#   ls$grau.ano/Licenciado.1760/1760-06-08/obs=08.06.1760
#   ls$grau/Formatura/1764-05-23/obs=23.05.1764, Atos 98, fl. 178
#   ls$grau.ano/Formatura.1764/1764-05-23/obs=23.05.1764, Atos 98, fl. 178
#   ls$instituta/1754-12-04/1754-12-04/obs=04.12.1754 1754-12-04
#   ls$instituta.ano/1754/1754-12-04/obs=04.12.1754 1754-12-04
#   pai$António de Abreu/m/id=140642-pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211

# %% [markdown]
# ###  Obter um dataframe a partir de atributos
#
# ---
#
#
# ###  Get a Dataframe from attributes

# %% [markdown]
# #### Exemplo: Faculdade, data de entrada e data de saída e grau dos naturais de Coimbra

# %%
from timelink.pandas import entities_with_attribute


# Get list of people with with a certain value in a specific attribute
df = entities_with_attribute(
                    the_type='naturalidade',
                    the_value='Coimbra',
                    person_info=True,
                    more_cols=['faculdade','uc.entrada','uc.saida','grau','grau.date'],
                    db=tlnb.db,
                    sql_echo=False)
df.info()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 from timelink.pandas import entities_with_attribute
#       4 # Get list of people with with a certain value in a specific attribute
#       5 df = entities_with_attribute(
#       6                     the_type='naturalidade',
#       7                     the_value='Coimbra',
#    (...)
#      10                     db=tlnb.db,
#      11                     sql_echo=False)
#
# File ~/develop/timelink-py/timelink/pandas/__init__.py:22
#      20 from .attribute_values import attribute_values  # noqa: F401
#      21 from .group_attributes import group_attributes  # noqa: F401
# ---> 22 from .styles import category_palette, category_colors  # noqa: F401
#
# ImportError: cannot import name 'category_colors' from 'timelink.pandas.styles' (/Users/jrc/develop/timelink-py/timelink/pandas/styles.py)

# %%
df.head(5)
# Out:
#                              name sex naturalidade naturalidade.date  \
# id
# 140349           António de Aboim   m      Coimbra          20200211
# 140349           António de Aboim   m      Coimbra          20200211
# 140367  Manuel de Vargas de Aboim   m      Coimbra          20200211
# 140380       António de Abranches   m      Coimbra          20200211
# 140538           António de Abreu   m      Coimbra          20200211
#
#        naturalidade.obs faculdade faculdade.date faculdade.obs  uc.entrada  \
# id
# 140349             None   Cânones       20200211          None  1566-12-20
# 140349             None   Cânones       20200211          None  1566-12-20
# 140367             None   Cânones       20200211          None  0000-00-00
# 140380             None  Medicina       20200211          None  1733-10-01
# 140538             None  Medicina       20200211          None  1670-10-01
#
#        uc.entrada.date uc.entrada.obs    uc.saida uc.saida.date uc.saida.obs  \
# id
# 140349        20200211           None  1574-07-24      20200211         None
# 140349        20200211           None  1574-07-24      20200211         None
# 140367        20200211           None  0000-00-00      20200211         None
# 140380        20200211           None  1733-10-01      20200211         None
# 140538        20200211           None  1679-07-19      20200211         None
#
#                      grau grau.date    grau.obs
# id
# 140349           Bacharel      None  20.07.1571
# 140349          Formatura      None  24.07.1574
# 140367                NaN      None         NaN
# 140380  Bacharel em Artes      None  14.04.1733
# 140538  Bacharel em Artes      None  20.03.1671

# %% [markdown]
# ###  Remover colunas sem valores
#
# ---
#
#
#
# ###  Remove empty columns

# %%
df.dropna(how='all', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 140349 to c1716-34-per1
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               33 non-null     object
#  1   sex                33 non-null     object
#  2   naturalidade       33 non-null     object
#  3   naturalidade.date  33 non-null     object
#  4   faculdade          26 non-null     object
#  5   faculdade.date     26 non-null     object
#  6   faculdade.obs      1 non-null      object
#  7   uc.entrada         26 non-null     object
#  8   uc.entrada.date    26 non-null     object
#  9   uc.saida           26 non-null     object
#  10  uc.saida.date      26 non-null     object
#  11  grau               19 non-null     object
#  12  grau.obs           18 non-null     object
#  13  id                 33 non-null     object
# dtypes: object(14)
# memory usage: 3.9+ KB

# %%
df.head(5)
# Out:
#                              name sex naturalidade naturalidade.date  \
# id
# 140349           António de Aboim   m      Coimbra          20200211
# 140349           António de Aboim   m      Coimbra          20200211
# 140367  Manuel de Vargas de Aboim   m      Coimbra          20200211
# 140380       António de Abranches   m      Coimbra          20200211
# 140538           António de Abreu   m      Coimbra          20200211
#
#        faculdade faculdade.date faculdade.obs  uc.entrada uc.entrada.date  \
# id
# 140349   Cânones       20200211          None  1566-12-20        20200211
# 140349   Cânones       20200211          None  1566-12-20        20200211
# 140367   Cânones       20200211          None  0000-00-00        20200211
# 140380  Medicina       20200211          None  1733-10-01        20200211
# 140538  Medicina       20200211          None  1670-10-01        20200211
#
#           uc.saida uc.saida.date               grau    grau.obs      id
# id
# 140349  1574-07-24      20200211           Bacharel  20.07.1571  140349
# 140349  1574-07-24      20200211          Formatura  24.07.1574  140349
# 140367  0000-00-00      20200211                NaN         NaN  140367
# 140380  1733-10-01      20200211  Bacharel em Artes  14.04.1733  140380
# 140538  1679-07-19      20200211  Bacharel em Artes  20.03.1671  140538

# %% [markdown]
# ###  Remover as remissivas
# ---
#
# ###  Remove cross-references

# %%
no_crossref = df['uc.entrada'] != '0000-00-00'
df = df[no_crossref]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, 140349 to c1716-34-per1
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               32 non-null     object
#  1   sex                32 non-null     object
#  2   naturalidade       32 non-null     object
#  3   naturalidade.date  32 non-null     object
#  4   faculdade          25 non-null     object
#  5   faculdade.date     25 non-null     object
#  6   faculdade.obs      1 non-null      object
#  7   uc.entrada         25 non-null     object
#  8   uc.entrada.date    25 non-null     object
#  9   uc.saida           25 non-null     object
#  10  uc.saida.date      25 non-null     object
#  11  grau               19 non-null     object
#  12  grau.obs           18 non-null     object
#  13  id                 32 non-null     object
# dtypes: object(14)
# memory usage: 3.8+ KB

# %%
view_cols = ['name','naturalidade','faculdade','grau','uc.entrada','uc.saida']
df[view_cols].head(10)
# Out:
#                                      name naturalidade faculdade  \
# id
# 140349                   António de Aboim      Coimbra   Cânones
# 140349                   António de Aboim      Coimbra   Cânones
# 140380               António de Abranches      Coimbra  Medicina
# 140538                   António de Abreu      Coimbra  Medicina
# 140538                   António de Abreu      Coimbra  Medicina
# 140538                   António de Abreu      Coimbra  Medicina
# 140538                   António de Abreu      Coimbra  Medicina
# 140573  António Dionísio Pereira de Abreu      Coimbra  Medicina
# 140573  António Dionísio Pereira de Abreu      Coimbra  Medicina
# 140573  António Dionísio Pereira de Abreu      Coimbra  Medicina
#
#                      grau  uc.entrada    uc.saida
# id
# 140349           Bacharel  1566-12-20  1574-07-24
# 140349          Formatura  1566-12-20  1574-07-24
# 140380  Bacharel em Artes  1733-10-01  1733-10-01
# 140538  Bacharel em Artes  1670-10-01  1679-07-19
# 140538          Formatura  1670-10-01  1679-07-19
# 140538         Licenciado  1670-10-01  1679-07-19
# 140538             Doutor  1670-10-01  1679-07-19
# 140573  Bacharel em Artes  1762-12-01  1771-07-31
# 140573             Mestre  1762-12-01  1771-07-31
# 140573          Formatura  1762-12-01  1771-07-31

# %% [markdown]
# ## Contagens
#
# ---
#
# ## Counting

# %% [markdown]
# ###  Contagem de atributos a partir de uma tabela em memória
#
# ---
#
# ###  Count attributes from an existing dataframe

# %%
# create a column with the index values which are the id numbers
df['id'] = df.index.values

col = 'faculdade' # subotal by this column

# Use pandas groupby and specify unique value count for id
df_totals = df.groupby(col).agg({'id':'nunique',
                                                  'uc.entrada':'min',
                                                  'uc.saida':'max'})

df_totals.sort_values('id',ascending= False).head(30)
# Out:
# /var/folders/x7/qzytnd752559g0w475rfwkx00000gn/T/ipykernel_91143/3590605853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['id'] = df.index.values
#             id  uc.entrada    uc.saida
# faculdade
# Cânones      6  1566-12-20  1767-07-27
# Medicina     5  1670-10-01  1823-10-20
# Direito      1  1748-10-19  1748-10-19
# Matemática   1  1868-10-02  1872-10-03

# %% [markdown]
# ### Contagens na base de dados
#
# Quando o atributo tem muitos valores e não é necessário
# ter todas as pessoas em memória: contagem feita na base de dados
#
# ---
#
# ### Counting directly in the database
# When there are many values and it is not
# necessary to have all the people in memory:
# count directly in the database.

# %%
from timelink.pandas import attribute_values

df_totals = attribute_values('grau',db=db)

# %%
df_totals.head(10)
# Out:
#                      count  date_min  date_max
# value
# Bacharel               171  20200211  20200211
# Formatura              153  20200211  20200211
# Licenciado              33  20200211  20200211
# Bacharel em Artes       25  20200211  20200211
# Doutor                  11  20200211  20200211
# Licenciado em Artes      5  20200211  20200211
# Mestre                   2  20200211  20200211

# %% [markdown]
# #### Filtrar por datas
#
# Para evitar remissivas com data zero
#
# ---
#
# #### Filter by dates
#
# Avoid cross-references with zero date

# %% [markdown]
# ##ERROR

# %%
df_totals = attribute_values('grau',dates_between=('1535','1919'),db=db)

# %%
df_totals.head(10)
# Out:
#       value count date_min date_max
# value   NaN   NaN      NaN      NaN

# %% [markdown]
# ## Visualizar registos
#
# ---
#
# ## View records

# %% [markdown]
# ### Visualizar uma pessoa
#
# ---
#
# ### View a person

# %% [markdown]
# #### Atributos de uma pessoa numa tabela, uma linha por attributo
#
# ---
#
# #### Person attributes in a dataframe, one line per attribute

# %%
import pandas as pd
from timelink.pandas import group_attributes as person_attributes

pd.set_option('display.max_rows',1000)

id = '140349'
pdf = person_attributes([id],db=db)  # note id in a list
pdf[['date','type','value','attr_obs']].sort_values(['date','type'])
# Out:
#             date                  type  \
# id
# 140349  20200211  código-de-referência
# 140349  20200211       data-do-registo
# 140349  20200211                 exame
# 140349  20200211             faculdade
# 140349  20200211         faculdade.ano
# 140349  20200211                  grau
# 140349  20200211                  grau
# 140349  20200211              grau.ano
# 140349  20200211              grau.ano
# 140349  20200211             matricula
# 140349  20200211             matricula
# 140349  20200211             matricula
# 140349  20200211         matricula.ano
# 140349  20200211         matricula.ano
# 140349  20200211         matricula.ano
# 140349  20200211          naturalidade
# 140349  20200211      naturalidade.ano
# 140349  20200211                  nome
# 140349  20200211       nome-geografico
# 140349  20200211   nome-geografico.ano
# 140349  20200211          nome.apelido
# 140349  20200211         nome.primeiro
# 140349  20200211            uc.entrada
# 140349  20200211        uc.entrada.ano
# 140349  20200211              uc.saida
# 140349  20200211          uc.saida.ano
# 140349  20200211                   url
#
#                                                  value    attr_obs
# id
# 140349          "PT/AUC/ELU/UC-AUC/B/001-001/A/000015"        None
# 140349                                      2021-05-17        None
# 140349            Exame e Grau de Bacharel em Cânones:        None
# 140349                                         Cânones        None
# 140349                                    Cânones.1566        None
# 140349                                        Bacharel  20.07.1571
# 140349                                       Formatura  24.07.1574
# 140349                                   Bacharel.1571  20.07.1571
# 140349                                  Formatura.1574  24.07.1574
# 140349                                         Cânones  07.10.1573
# 140349                                         Cânones  20.07.1571
# 140349                                         Cânones  24.07.1574
# 140349                                    Cânones.1573  07.10.1573
# 140349                                    Cânones.1571  20.07.1571
# 140349                                    Cânones.1574  24.07.1574
# 140349                                         Coimbra        None
# 140349                                    Coimbra.1566        None
# 140349                                António de Aboim        None
# 140349                                         Coimbra        None
# 140349                                    Coimbra.1566        None
# 140349                                           Aboim        None
# 140349                                         António        None
# 140349                                      1566-12-20        None
# 140349                                            1566        None
# 140349                                      1574-07-24        None
# 140349                                            1574        None
# 140349  "https://pesquisa.auc.uc.pt/details?id=140349"        None

# %% [markdown]
# #### Atributos de uma pessoa numa tabela, attributos em colunas
#
# ---
#
# #### Person attributes in a dataframe, attributes in columns

# %%
# Get list of people with with a certain value in a specific attribute

id = '316297'  # João Pedro Ribeiro
# id = '234295'  # Alexandre Metelo de Sousa
df = attribute_to_df(
                    the_type='uc-entrada',  # we need a base attribute
                    person_info=True,
                    more_cols=['instituta','matricula-faculdade','matricula-classe'],
                    filter_by=[id],
                    sql_echo=False)
view_cols = ['name','matricula-classe.date','matricula-classe','matricula-classe.obs']
df[view_cols].sort_values('matricula-classe.date')
# Out:
#                       name matricula-classe.date        matricula-classe  \
# id
# 316297  João Pedro Ribeiro            1774-11-15  Curso jurídico, 1º ano
# 316297  João Pedro Ribeiro            1774-11-15  Curso jurídico, 1º ano
# 316297       Vol IX, L. 3, fl. 73
# 316297       Vol IX, L. 3, fl. 73
# 316297       Vol IX, L. 3, fl. 73
# 316297       Vol IX, L. 3, fl. 73
# 316297       Vol IX, L. 3, fl. 73

# %% [markdown]
# #### Examinar potenciais duplicados
#
# ---
#
# #### Examine potentital duplicates

# %%
from timelink.notebooks.pandas import display_group_attributes
pd.set_option('display.max_rows',250)

no_show=['código-de-referência','data-do-registo','url','faculdade.ano','naturalidade.ano',
         'matricula-faculdade.ano','nome-apelido','nome-primeiro','nome-geografico.ano',
         'grau.ano','matricula-outra.ano','nome-geografico','instituta.ano']

dup_ids = ['234295','234710',]  # Alexandre Metelo de

display_group_attributes(dup_ids,
                             header_cols=['uc-entrada','naturalidade','faculdade','nome-pai'],
                             exclude_attributes=no_show,
                             sort_attributes=['date','type','value'],
                             cmap_name='Pastel1')
# Out:
# <style type="text/css">
# #T_de85d_row0_col0, #T_de85d_row0_col1, #T_de85d_row0_col2, #T_de85d_row0_col3, #T_de85d_row0_col4 {
#   background-color: #fbb4ae;
# }
# #T_de85d_row1_col0, #T_de85d_row1_col1, #T_de85d_row1_col2, #T_de85d_row1_col3, #T_de85d_row1_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_de85d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de85d_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_de85d_level0_col1" class="col_heading level0 col1" >uc-entrada</th>
#       <th id="T_de85d_level0_col2" class="col_heading level0 col2" >naturalidade</th>
#       <th id="T_de85d_level0_col3" class="col_heading level0 col3" >faculdade</th>
#       <th id="T_de85d_level0_col4" class="col_heading level0 col4" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de85d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de85d_row0_col0" class="data row0 col0" >234295</td>
#       <td id="T_de85d_row0_col1" class="data row0 col1" >1704-11-07</td>
#       <td id="T_de85d_row0_col2" class="data row0 col2" >Marialva</td>
#       <td id="T_de85d_row0_col3" class="data row0 col3" >Cânones</td>
#       <td id="T_de85d_row0_col4" class="data row0 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_de85d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_de85d_row1_col0" class="data row1 col0" >234710</td>
#       <td id="T_de85d_row1_col1" class="data row1 col1" >1705-10-24</td>
#       <td id="T_de85d_row1_col2" class="data row1 col2" >Marialva</td>
#       <td id="T_de85d_row1_col3" class="data row1 col3" >Matemática</td>
#       <td id="T_de85d_row1_col4" class="data row1 col4" >Manuel Cardoso Metelo</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_41e12_row0_col0, #T_41e12_row0_col1, #T_41e12_row0_col2, #T_41e12_row0_col3, #T_41e12_row0_col4, #T_41e12_row1_col0, #T_41e12_row1_col1, #T_41e12_row1_col2, #T_41e12_row1_col3, #T_41e12_row1_col4, #T_41e12_row2_col0, #T_41e12_row2_col1, #T_41e12_row2_col2, #T_41e12_row2_col3, #T_41e12_row2_col4, #T_41e12_row3_col0, #T_41e12_row3_col1, #T_41e12_row3_col2, #T_41e12_row3_col3, #T_41e12_row3_col4, #T_41e12_row4_col0, #T_41e12_row4_col1, #T_41e12_row4_col2, #T_41e12_row4_col3, #T_41e12_row4_col4, #T_41e12_row5_col0, #T_41e12_row5_col1, #T_41e12_row5_col2, #T_41e12_row5_col3, #T_41e12_row5_col4, #T_41e12_row7_col0, #T_41e12_row7_col1, #T_41e12_row7_col2, #T_41e12_row7_col3, #T_41e12_row7_col4, #T_41e12_row14_col0, #T_41e12_row14_col1, #T_41e12_row14_col2, #T_41e12_row14_col3, #T_41e12_row14_col4, #T_41e12_row15_col0, #T_41e12_row15_col1, #T_41e12_row15_col2, #T_41e12_row15_col3, #T_41e12_row15_col4, #T_41e12_row16_col0, #T_41e12_row16_col1, #T_41e12_row16_col2, #T_41e12_row16_col3, #T_41e12_row16_col4 {
#   background-color: #fbb4ae;
# }
# #T_41e12_row6_col0, #T_41e12_row6_col1, #T_41e12_row6_col2, #T_41e12_row6_col3, #T_41e12_row6_col4, #T_41e12_row8_col0, #T_41e12_row8_col1, #T_41e12_row8_col2, #T_41e12_row8_col3, #T_41e12_row8_col4, #T_41e12_row9_col0, #T_41e12_row9_col1, #T_41e12_row9_col2, #T_41e12_row9_col3, #T_41e12_row9_col4, #T_41e12_row10_col0, #T_41e12_row10_col1, #T_41e12_row10_col2, #T_41e12_row10_col3, #T_41e12_row10_col4, #T_41e12_row11_col0, #T_41e12_row11_col1, #T_41e12_row11_col2, #T_41e12_row11_col3, #T_41e12_row11_col4, #T_41e12_row12_col0, #T_41e12_row12_col1, #T_41e12_row12_col2, #T_41e12_row12_col3, #T_41e12_row12_col4, #T_41e12_row13_col0, #T_41e12_row13_col1, #T_41e12_row13_col2, #T_41e12_row13_col3, #T_41e12_row13_col4, #T_41e12_row17_col0, #T_41e12_row17_col1, #T_41e12_row17_col2, #T_41e12_row17_col3, #T_41e12_row17_col4, #T_41e12_row18_col0, #T_41e12_row18_col1, #T_41e12_row18_col2, #T_41e12_row18_col3, #T_41e12_row18_col4, #T_41e12_row19_col0, #T_41e12_row19_col1, #T_41e12_row19_col2, #T_41e12_row19_col3, #T_41e12_row19_col4, #T_41e12_row20_col0, #T_41e12_row20_col1, #T_41e12_row20_col2, #T_41e12_row20_col3, #T_41e12_row20_col4, #T_41e12_row21_col0, #T_41e12_row21_col1, #T_41e12_row21_col2, #T_41e12_row21_col3, #T_41e12_row21_col4, #T_41e12_row22_col0, #T_41e12_row22_col1, #T_41e12_row22_col2, #T_41e12_row22_col3, #T_41e12_row22_col4, #T_41e12_row23_col0, #T_41e12_row23_col1, #T_41e12_row23_col2, #T_41e12_row23_col3, #T_41e12_row23_col4, #T_41e12_row24_col0, #T_41e12_row24_col1, #T_41e12_row24_col2, #T_41e12_row24_col3, #T_41e12_row24_col4, #T_41e12_row25_col0, #T_41e12_row25_col1, #T_41e12_row25_col2, #T_41e12_row25_col3, #T_41e12_row25_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_41e12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41e12_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_41e12_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_41e12_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_41e12_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_41e12_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41e12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41e12_row0_col0" class="data row0 col0" >1704-11-07</td>
#       <td id="T_41e12_row0_col1" class="data row0 col1" >234295</td>
#       <td id="T_41e12_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_41e12_row0_col3" class="data row0 col3" >Cânones</td>
#       <td id="T_41e12_row0_col4" class="data row0 col4" >Cânones </td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41e12_row1_col0" class="data row1 col0" >1704-11-07</td>
#       <td id="T_41e12_row1_col1" class="data row1 col1" >234295</td>
#       <td id="T_41e12_row1_col2" class="data row1 col2" >instituta</td>
#       <td id="T_41e12_row1_col3" class="data row1 col3" >1704-11-07</td>
#       <td id="T_41e12_row1_col4" class="data row1 col4" >07.11.1704 1704-11-07</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41e12_row2_col0" class="data row2 col0" >1704-11-07</td>
#       <td id="T_41e12_row2_col1" class="data row2 col1" >234295</td>
#       <td id="T_41e12_row2_col2" class="data row2 col2" >naturalidade</td>
#       <td id="T_41e12_row2_col3" class="data row2 col3" >Marialva</td>
#       <td id="T_41e12_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_41e12_row3_col0" class="data row3 col0" >1704-11-07</td>
#       <td id="T_41e12_row3_col1" class="data row3 col1" >234295</td>
#       <td id="T_41e12_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_41e12_row3_col3" class="data row3 col3" >Alexandre Metelo de Sousa</td>
#       <td id="T_41e12_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_41e12_row4_col0" class="data row4 col0" >1704-11-07</td>
#       <td id="T_41e12_row4_col1" class="data row4 col1" >234295</td>
#       <td id="T_41e12_row4_col2" class="data row4 col2" >uc-entrada</td>
#       <td id="T_41e12_row4_col3" class="data row4 col3" >1704-11-07</td>
#       <td id="T_41e12_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_41e12_row5_col0" class="data row5 col0" >1704-11-07</td>
#       <td id="T_41e12_row5_col1" class="data row5 col1" >234295</td>
#       <td id="T_41e12_row5_col2" class="data row5 col2" >uc-entrada.ano</td>
#       <td id="T_41e12_row5_col3" class="data row5 col3" >1704</td>
#       <td id="T_41e12_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_41e12_row6_col0" class="data row6 col0" >1705-10-24</td>
#       <td id="T_41e12_row6_col1" class="data row6 col1" >234710</td>
#       <td id="T_41e12_row6_col2" class="data row6 col2" >faculdade</td>
#       <td id="T_41e12_row6_col3" class="data row6 col3" >Matemática</td>
#       <td id="T_41e12_row6_col4" class="data row6 col4" >Matemática </td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_41e12_row7_col0" class="data row7 col0" >1705-10-24</td>
#       <td id="T_41e12_row7_col1" class="data row7 col1" >234295</td>
#       <td id="T_41e12_row7_col2" class="data row7 col2" >matricula-faculdade</td>
#       <td id="T_41e12_row7_col3" class="data row7 col3" >Cânones</td>
#       <td id="T_41e12_row7_col4" class="data row7 col4" >24.10.1705</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_41e12_row8_col0" class="data row8 col0" >1705-10-24</td>
#       <td id="T_41e12_row8_col1" class="data row8 col1" >234710</td>
#       <td id="T_41e12_row8_col2" class="data row8 col2" >matricula-faculdade</td>
#       <td id="T_41e12_row8_col3" class="data row8 col3" >Matemática</td>
#       <td id="T_41e12_row8_col4" class="data row8 col4" >24.10.1705</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_41e12_row9_col0" class="data row9 col0" >1705-10-24</td>
#       <td id="T_41e12_row9_col1" class="data row9 col1" >234710</td>
#       <td id="T_41e12_row9_col2" class="data row9 col2" >naturalidade</td>
#       <td id="T_41e12_row9_col3" class="data row9 col3" >Marialva</td>
#       <td id="T_41e12_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_41e12_row10_col0" class="data row10 col0" >1705-10-24</td>
#       <

# %% [markdown]
# #### Notação Kleio
#
# Ver [Kleio notation](README_kleio.md) [EN]
#
# ---
#
# #### Kleio notation
#
# See [Kleio notation](README_kleio.md)

# %%
from ucalumni.aluno import get_and_process_aluno
from ucalumni.mapping import map_aluno_kperson

from ucalumni.extractors import get_extractors

get_extractors()

id =  '234295'  #'316297'

aluno = get_and_process_aluno(id,db)
kaluno = map_aluno_kperson(aluno)
kleio = kaluno.to_kleio()

print(kleio)
# Out:
# n$Alexandre Metelo de Sousa/m/id=234295/obs="""
#
#       Id: 234295
#       Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/S/010952
#
#       Nome        : Alexandre Metelo de Sousa
#       Data inicial: 1704-11-07
#       Data final  : 1706-10-01
#       Filiação:
#       Naturalidade: Marialva
#       Faculdade: Cânones
#
#       Matrícula(s): 24.10.1705
#       01.10.1706
#
#       Instituta: 07.11.1704
#   """
#  atr$código-de-referência/"PT/AUC/ELU/UC-AUC/B/001-001/S/010952"/2022-06-08
#  atr$data-do-registo/2022-06-08/2022-06-08
#  atr$url/"http://pesquisa.auc.uc.pt/details?id=234295"/2022-06-08
#  ls$uc-entrada/1704-11-07/1704-11-07
#  ls$uc-saida/1706-10-01/1706-10-01
#  ls$uc-entrada.ano/1704/1704-11-07
#  ls$uc-saida.ano/1706/1706-10-01
#  ls$nome/Alexandre Metelo de Sousa/1704-11-07
#  ls$nome-primeiro/Alexandre/1704-11-07
#  ls$nome-apelido/Metelo de Sousa/1704-11-07
#  ls$nome-apelido/Sousa/1704-11-07
#  ls$nome-geografico/Marialva/1704-11-07
#  ls$nome-geografico.ano/Marialva.1704/1704-11-07
#  ls$naturalidade/Marialva/1704-11-07
#  ls$naturalidade.ano/Marialva.1704/1704-11-07
#  ls$faculdade/Cânones/1704-11-07/obs=Cânones
#  ls$faculdade.ano/Cânones.1704/1704-11-07/obs=Cânones
#  ls$matricula-faculdade/Cânones/1705-10-24/obs=24.10.1705
#  ls$matricula-faculdade.ano/Cânones.1705/1705-10-24/obs=24.10.1705
#  ls$matricula-faculdade/Cânones/1706-10-01/obs=01.10.1706
#  ls$matricula-faculdade.ano/Cânones.1706/1706-10-01/obs=01.10.1706
#  ls$instituta/1704-11-07/1704-11-07/obs=07.11.1704 1704-11-07
#  ls$instituta.ano/1704/1704-11-07/obs=07.11.1704 1704-11-07

# %% [markdown]
# #### Notação Kleio directamente da base de dados
#
# Ver [Kleio notation](README_kleio.md) [EN]
#
# ---
#
# #### Kleio notation directly from database
#
# See [Kleio notation](README_kleio.md)

# %%
from ucalumni.config import Session
from timelink.mhk.models.person import Person

with Session(bind=db.get_engine()) as session:

    p: Person = session.query(Person).order_by(Person.id).first()
    k = p.to_kleio()
    print(p.to_kleio())
# Out:
# n$Manuel Barreto Cabaça/m/id=127764/obs="""
#
#       Id: 127764
#       Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/C/000001
#
#       Nome        : Manuel Barreto Cabaça
#       Data inicial: 1690-10-01
#       Data final  : 1697-10-01
#       Filiação: Manuel Barreto
#       Naturalidade: Portalegre
#
#       Faculdade: Cânones
#       Instituta:01.10.1690
#       Matrícula(s): 01.10.1690
#       01.10.1691
#       01.10.1692
#       01.10.1693
#       01.10.1694
#       01.10.1695
#       01.10.1696
#       01.10.1697
#
#       Bacharel - 26.05.1696
#       Formatura - 20.11.1697
#   """
#   rel$parentesco/filho/Manuel Barreto/127764-pai/1690-10-01
#   rel$function-in-act/n/C/
#   atr$código-de-referência/"PT/AUC/ELU/UC-AUC/B/001-001/C/000001"/2021-05-13
#   atr$data-do-registo/2021-05-13/2021-05-13
#   atr$url/"https://pesquisa.auc.uc.pt/details?id=127764"/2021-05-13
#   ls$uc-entrada/1690-10-01/1690-10-01
#   ls$uc-saida/1697-10-01/1697-10-01
#   ls$uc-entrada.ano/1690/1690-10-01
#   ls$uc-saida.ano/1697/1697-10-01
#   ls$nome/Manuel Barreto Cabaça/1690-10-01
#   ls$nome-primeiro/Manuel/1690-10-01
#   ls$nome-apelido/Barreto Cabaça/1690-10-01
#   ls$nome-apelido/Cabaça/1690-10-01
#   ls$nome-pai/Manuel Barreto/1690-10-01
#   ls$nome-geografico/Portalegre/1690-10-01
#   ls$nome-geografico.ano/Portalegre.1690/1690-10-01
#   ls$naturalidade/Portalegre/1690-10-01
#   ls$naturalidade.ano/Portalegre.1690/1690-10-01
#   ls$faculdade/Cânones/1690-10-01/obs=Cânones
#   ls$faculdade.ano/Cânones.1690/1690-10-01/obs=Cânones
#   ls$matricula-faculdade/Cânones/1690-10-01/obs=01.10.1690
#   ls$matricula-faculdade.ano/Cânones.1690/1690-10-01/obs=01.10.1690
#   ls$matricula-faculdade/Cânones/1691-10-01/obs=01.10.1691
#   ls$matricula-faculdade.ano/Cânones.1691/1691-10-01/obs=01.10.1691
#   ls$matricula-faculdade/Cânones/1692-10-01/obs=01.10.1692
#   ls$matricula-faculdade.ano/Cânones.1692/1692-10-01/obs=01.10.1692
#   ls$matricula-faculdade/Cânones/1693-10-01/obs=01.10.1693
#   ls$matricula-faculdade.ano/Cânones.1693/1693-10-01/obs=01.10.1693
#   ls$matricula-faculdade/Cânones/1694-10-01/obs=01.10.1694
#   ls$matricula-faculdade.ano/Cânones.1694/1694-10-01/obs=01.10.1694
#   ls$matricula-faculdade/Cânones/1695-10-01/obs=01.10.1695
#   ls$matricula-faculdade.ano/Cânones.1695/1695-10-01/obs=01.10.1695
#   ls$matricula-faculdade/Cânones/1696-10-01/obs=01.10.1696
#   ls$matricula-faculdade.ano/Cânones.1696/1696-10-01/obs=01.10.1696
#   ls$matricula-faculdade/Cânones/1697-10-01/obs=01.10.1697
#   ls$matricula-faculdade.ano/Cânones.1697/1697-10-01/obs=01.10.1697
#   ls$grau/Bacharel em Cânones/1696-05-26/obs=26.05.1696
#   ls$grau.ano/Bacharel em Cânones.1696/1696-05-26/obs=26.05.1696
#   ls$grau/Formatura em Cânones/1697-11-20/obs=20.11.1697
#   ls$grau.ano/Formatura em Cânones.1697/1697-11-20/obs=20.11.1697
#   ls$instituta/1690-10-01/1690-10-01/obs=01.10.1690 1690-10-01
#   ls$instituta.ano/1690/1690-10-01/obs=01.10.1690 1690-10-01
#   referido$Manuel Barreto/None/id=127764-pai

# %% [markdown]
# # Debug

# %%
import requests

kurl2 = f"{url}/rest/exports/reference_sources/varia/auc-alunos-264605-A-140337-140771.xml"

print(kurl2)
headers = {"Authorization": f"Bearer {token}"}

response = requests.get(kurl2, headers=headers)
if response.status_code == 200:
    xml_string = response.text
    print(xml_string[0:2048])
else:
    print(f"Error: {response.status_code} - {response.reason}")
# Out:
# http://127.0.0.1:8090/rest/exports/reference_sources/varia/auc-alunos-264605-A-140337-140771.xml
# <?xml version='1.0'?>
# <KLEIO STRUCTURE="/usr/local/timelink/clio/src/gacto2.str" SOURCE="/kleio-home/reference_sources/varia/auc-alunos-264605-A-140337-140771.cli" TRANSLATOR="gactoxml2.str" WHEN="2023-10-17 4:28:16" OBS="" SPACE="">
# <CLASS NAME="source" SUPER="entity" TABLE="sources" GROUP="fonte">
#      <ATTRIBUTE NAME="id" COLUMN="id" CLASS="id" TYPE="varchar" SIZE="64" PRECISION="0" PKEY="1" ></ATTRIBUTE>
#      <ATTRIBUTE NAME="date" COLUMN="the_date" CLASS="date" TYPE="varchar" SIZE="24" PRECISION="0" PKEY="0" ></ATTRIBUTE>
#      <ATTRIBUTE NAME="type" COLUMN="the_type" CLASS="type" TYPE="varchar" SIZE="32" PRECISION="0" PKEY="0" ></ATTRIBUTE>
#      <ATTRIBUTE NAME="value" COLUMN="the_value" CLASS="value" TYPE="varchar" SIZE="254" PRECISION="0" PKEY="0" ></ATTRIBUTE>
#      <ATTRIBUTE NAME="loc" COLUMN="loc" CLASS="loc" TYPE="varchar" SIZE="64" PRECISION="0" PKEY="0" ></ATTRIBUTE>
#      <ATTRIBUTE NAME="ref" COLUMN="ref" CLASS="ref" TYPE="varchar" SIZE="64" PRECISION="0" PKEY="0" ></ATTRIBUTE>
#      <ATTRIBUTE NAME="kleiofile" COLUMN="kleiofile" CLASS="kleiofile" TYPE="varchar" SIZE="512" PRECISION="0" PKEY="0" ></ATTRIBUTE>
#      <ATTRIBUTE NAME="obs" COLUMN="obs" CLASS="obs" TYPE="varchar" SIZE="16654" PRECISION="0" PKEY="0" ></ATTRIBUTE>
#      <ATTRIBUTE NAME="replace" COLUMN="replaces" CLASS="replace" TYPE="varchar" SIZE="254" PRECISION="0" PKEY="0" ></ATTRIBUTE>
# </CLASS>
#
# <GROUP ID="auc-alunos-264605-A-140337-140771" NAME="fonte" CLASS="source" ORDER="1" LEVEL="1" LINE="28">
#     <ELEMENT NAME="line" CLASS="line"><core>28</core></ELEMENT>
#     <ELEMENT NAME="id" CLASS="id"><core>auc-alunos-264605-A-140337-140771</core></ELEMENT>
#     <ELEMENT NAME="groupname" CLASS="groupname"><core>fonte</core></ELEMENT>
#    <ELEMENT NAME="inside" CLASS="inside"><core>root</core></ELEMENT>
#    <ELEMENT NAME="class" CLASS="class"><core>source</core></ELEMENT>
#     <ELEMENT NAME="order" CLASS="order"><core>1</core></ELEMENT>
#     <ELEMENT NAME="level" CLASS="level"><core>1</core></ELEMENT>
#    <ELEMENT NAME="year" CLASS="undef">

# %%
from timelink.kleio.importer import import_from_xml

file = "https://raw.githubusercontent.com/time-link/timelink-py/f76007cb7b98b39b22be8b70b3b2a62e7ae0c12f/tests/xml_data/b1685.xml"  # noqa

with db.session() as session:
    stats = import_from_xml(file, session=session,options={"return_stats": True})
stats
# Out:
# Storing 2 postponed relations
# {'datetime': 1697549928.160403,
#  'machine': 'jrc-air-m2.local',
#  'database': sqlite:////Users/jrc/develop/timelink-py/tests/timelink-home/sources/test-project/database/sqlite/timelink.db.sqlite,
#  'file': 'https://raw.githubusercontent.com/time-link/timelink-py/f76007cb7b98b39b22be8b70b3b2a62e7ae0c12f/tests/xml_data/b1685.xml',
#  'import_time_seconds': 2.4436087608337402,
#  'entities_processed': 747,
#  'entity_rate': 305.69541735688057,
#  'person_rate': 78.98154692085402,
#  'nerrors': 0,
#  'errors': []}
