# %% [markdown]
# # Using Timelink in notebooks: tutorial

# %% [markdown]
# > First time use: follow instructions in the [README.md](README.md) file in this directory.

# %% [markdown]
# ## Initial setup
#
# Create a TimelinkNotebook object. This will be the interface for most of your interactions with Timelink.
#
# The first time you run this notebook, you will be prompted to install ìpykernel. This is required to run Timelink in a notebook.
#
# Note:
# * First time run takes a little time as the required Docker images are downloaded.
# * Timelink will default to using sqlite as the database, see [Receipts notebook for more control](1-receipts.ipynb)

# %%
from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook()

# %% [markdown]
# TimelinkNotebook created a database to store data and a Kleio server to
# translate transcriptions in Kleio notation into data that can be imported
# into a database.
#
# To get information about the database and the Kleio server do ```tnlb.print_info()```

# %%
tlnb.print_info()
# Out:
# Project name: tutorial
# Project home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial
# Database type: sqlite
# Database name: tutorial
# Kleio image: timelinkserver/kleio-server
# Kleio version: latest
# Kleio server token: yNEupdoWvbKkAfALXitPVuC0D9PXUkPa
# Kleio server URL: http://127.0.0.1:8089
# Kleio server home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial
# SQLite directory: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial/database/sqlite
# TimelinkNotebook(project_name=tutorial, project_home=/Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial, db_type=sqlite, db_name=tutorial, kleio_image=timelinkserver/kleio-server, kleio_version=latest, postgres_image=postgres, postgres_version=latest)

# %% [markdown]
# ### Database status
#
# Count the number of rows in each table in the database.

# %%
tlnb.table_row_count_df()
# Out:
#                table  count
# 0               acts      3
# 1         attributes  14680
# 2   class_attributes     63
# 3            classes     13
# 4           entities  17182
# 5        geoentities    215
# 6              goods      0
# 7         kleiofiles      3
# 8            objects      0
# 9            persons    873
# 10         relations   1395
# 11         rentities      0
# 12      rgeoentities      0
# 13          robjects      0
# 14          rpersons      0
# 15           sources      3
# 16            syslog      0
# 17            syspar      0

# %% [markdown]
# ### Show the kleio files available

# %%
kleio_files = tlnb.get_kleio_files()
kleio_files
# Out:
#                                 path                         name  \
# 0               kleio/auc-alunos.cli               auc-alunos.cli
# 1               kleio/dehergne-a.cli               dehergne-a.cli
# 2  kleio/dehergne-locations-1644.cli  dehergne-locations-1644.cli
#
#                           modified status                translated  errors  \
# 0 2024-02-04 08:38:20.975128+00:00      V 2024-02-04 08:38:00+00:00       0
# 1 2024-02-04 14:08:29.476407+00:00      V 2024-02-04 14:08:00+00:00       0
# 2 2024-02-04 08:40:21.505312+00:00      V 2024-02-04 08:40:00+00:00       0
#
#    warnings import_status  import_errors  import_warnings import_error_rpt  \
# 0         0             I              0                0        No errors
# 1         0             I              0                0        No errors
# 2         0             I              0                0        No errors
#
#   import_warning_rpt                   imported  \
# 0        No warnings 2024-02-04 08:38:54.291236
# 1        No warnings 2024-02-04 14:08:36.475775
# 2        No warnings 2024-02-04 08:40:24.149131
#
#                                            rpt_url  \
# 0               /rest/reports/kleio/auc-alunos.rpt
# 1               /rest/reports/kleio/dehergne-a.rpt
# 2  /rest/reports/kleio/dehergne-locations-1644.rpt
#
#                                            xml_url
# 0               /rest/exports/kleio/auc-alunos.xml
# 1               /rest/exports/kleio/dehergne-a.xml
# 2  /rest/exports/kleio/dehergne-locations-1644.xml

# %% [markdown]
# # Update the database from Kleio sources.
#
# Updates source translations and imports into database sources with no errors.
#
# Only changed files since last import, or new files, will be processed.

# %%
import logging
logging.basicConfig(level=logging.INFO)

tlnb.update_from_sources()

# %% [markdown]
# ## Check the status of the files

# %% [markdown]
# Check the import status of the translated files
#
# I: Imported
#
# E: Imported with error
#
# W: Imported with warnings no errors
#
# N: Not imported
#
# U: Translation updated need to reimport

# %%
imported_files_df = tlnb.get_import_status()
imported_files_df[["import_status","import_errors","import_warnings","name","errors","warnings","path"]].sort_values("name")
# Out:
#   import_status  import_errors  import_warnings                         name  \
# 0             I              0                0               auc-alunos.cli
# 1             I              0                0               dehergne-a.cli
# 2             I              0                0  dehergne-locations-1644.cli
#
#    errors  warnings                               path
# 0       0         0               kleio/auc-alunos.cli
# 1       0         0               kleio/dehergne-a.cli
# 2       0         0  kleio/dehergne-locations-1644.cli

# %% [markdown]
# ### Check the translation report

# %%
rpt = tlnb.get_translation_report(imported_files_df, 1)
print(rpt)
# Out:
# KleioTranslator - server version 12.2 - build 560 2024-01-08 08:18:15
# 4-2-2024 14-8
#
# Processing data file dehergne-a.cli
# -------------------------------------------
# Generic Act translation module with geoentities (XML).
#      Joaquim Ramos de Carvalho (joaquim@uc.pt)
# ** New document: kleio
# =========================
# kleio translation started
# =========================
# Structure: gacto2.str
# Prefix:
# Autorel:
# Translation count: 178
# Obs:
# ** Processing source fonte$dehergne-a
# 7: lista$dehergne-notices-a
# *** End of File
#
# Line 541 "SAME AS" TO EXTERNAL REFERENCE EXPORTED (deh-belchior-miguel-carneiro-leitao) CHECK IF IT EXISTS BEFORE IMPORTING THIS FILE.
# Line 814 "SAME AS" TO EXTERNAL REFERENCE EXPORTED (deh-jean-regis-lieou) CHECK IF IT EXISTS BEFORE IMPORTING THIS FILE.
# Line 876 "SAME AS" TO EXTERNAL REFERENCE EXPORTED (deh-alessandro-cicero) CHECK IF IT EXISTS BEFORE IMPORTING THIS FILE.
#
# Structure file: /usr/local/timelink/clio/src/gacto2.str
# Structure processing report: /usr/local/timelink/clio/src/gacto2.srpt
# Structure in JSON: /usr/local/timelink/clio/src/gacto2.str.json
#
# Kleio file: /kleio-home/kleio/dehergne-a.cli
# Original file: /kleio-home/kleio/dehergne-a.org
# Previous version: /kleio-home/kleio/dehergne-a.old
# Temp file with ids: /kleio-home/kleio/dehergne-a.ids
# ** - /kleio-home/kleio/dehergne-a.cli-renamed to- /kleio-home/kleio/dehergne-a.old
# 0  errors.
# 0  warnings.
# Translation finished.

# %% [markdown]
# ### Get the import report for a file
#
# In case there are errors in the import phase check the import report.

# %%
rpt = tlnb.get_import_rpt(imported_files_df, rows=[0])
print(rpt)
# Out:
# No errors
# No warnings

# %% [markdown]
# ## Todo

# %% [markdown]
# This as data frame in a single function
# * TimelinkNotebook.translate([files_df,paths=List[str], rows=List[int],status="T"])
# * TimelinkNotebook.import([files_df,paths=List[str], rows=List[int],status="V"])

# %% [markdown]
# # Obter dados
# ---
#
# # Getting data

# %% [markdown]
# ### Procurar pessoa, mostrar em notação Kleio
#
# ---
# ### Search for people, show in Kleio notation

# %%
from timelink.api.models import Person

show_only=10

with tlnb.db.session() as session:
    persons = session.query(Person).filter(Person.name.like('%Abegão')).all()

    for person in persons[:show_only]:
        print(person.to_kleio())
        print()
# Out:
# n$Estevão de Matos Abegão/m/id=140338/obs="""
#       """
#
#                   Id: 140338
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000002
#
#                   Nome        : Estevão de Matos Abegão
#                   Data inicial: 1728-10-01
#                   Data final  : 1733-07-03
#                   Filiação: Lourenço de Matos Pereira
#                   Naturalidade: Elvas
#                   Faculdade: Cânones
#
#                   Matrícula(s): 01.10.1729
#                   01.10.1730
#                   01.10.1732
#
#                   Instituta: 01.10.1728
#
#                   Bacharel: 03.07.1733
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000002""/2021-05-17
#   atr$data-do-registo/2021-05-17/2021-05-17
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140338""/2021-05-17
#   ls$uc.entrada/1728-10-01/1728-10-01
#   ls$uc.saida/1733-07-03/1733-07-03
#   ls$uc.entrada.ano/1728/1728-10-01
#   ls$uc.saida.ano/1733/1733-07-03
#   ls$nome/Estevão de Matos Abegão/1728-10-01
#   ls$nome.primeiro/Estevão/1728-10-01
#   ls$nome.apelido/Matos Abegão/1728-10-01
#   ls$nome.apelido/Abegão/1728-10-01
#   ls$naturalidade/Elvas/1728-10-01
#   ls$naturalidade.ano/Elvas.1728/1728-10-01
#   ls$nome-geografico/Elvas/1728-10-01
#   ls$nome-geografico.ano/Elvas.1728/1728-10-01
#   ls$faculdade/Cânones/1728-10-01
#   ls$faculdade.ano/Cânones.1728/1728-10-01
#   ls$matricula/Cânones/1729-10-01/obs=01.10.1729
#   ls$matricula.ano/Cânones.1729/1729-10-01/obs=01.10.1729
#   ls$matricula/Cânones/1730-10-01/obs=01.10.1730
#   ls$matricula.ano/Cânones.1730/1730-10-01/obs=01.10.1730
#   ls$matricula/Cânones/1732-10-01/obs=01.10.1732
#   ls$matricula.ano/Cânones.1732/1732-10-01/obs=01.10.1732
#   ls$grau/Bacharel/1733-07-03/obs=03.07.1733
#   ls$grau.ano/Bacharel.1733/1733-07-03/obs=03.07.1733
#   ls$instituta/1728-10-01/1728-10-01/obs=01.10.1728 1728-10-01
#   ls$instituta.ano/1728/1728-10-01/obs=01.10.1728 1728-10-01
#   pai$Lourenço de Matos Pereira/m/id=140338-pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211
#
# n$Jerónimo Rodrigues Abegão/m/id=140339/obs="""
#       """
#
#                   Id: 140339
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000003
#
#                   Nome        : Jerónimo Rodrigues Abegão
#                   Data inicial: 1732-10-01
#                   Data final  : 1746-06-15
#                   Filiação: Jerónimo Rodrigues Abegão
#                   Naturalidade: Portalegre
#                   Faculdade: Cânones
#
#                   Matrícula(s): 01.10.1733
#                   01.10.1734
#                   01.10.1735
#                   01.10.1736
#                   01.10.1737
#                   01.10.1738
#                   01.10.1741
#                   01.10.1745
#                   Instituta: 01.10.1732
#                   Bacharel: 12.04.1742, Atos e Graus 80, fl. 104 v.
#                   Formatura: 15.06.1746
#
#                   Outras informações: Tirou as cartas com o nome Jerónimo de Faria Vidal, Atos e Graus 80, fl. 104 v.
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/
el$function-in-act/pai/auc-alumni-A-140337-140771/20200211

# %%
from sqlalchemy import select, and_
from sqlalchemy.orm import joinedload
from timelink.api.models import Person, Attribute

show_only=10

with tlnb.db.session() as session:
    stmt = select(Person).join(Person.attributes.and_(Attribute.the_type == 'naturalidade',
                                                      Attribute.the_value.like('Lisboa')))
    print(stmt)
    persons = session.execute(stmt).scalars().all()

    for person in persons[:show_only]:
        p = tlnb.db.get_person(person.id)
        print(p.to_kleio())
# Out:
# SELECT persons.id, entities.id AS id_1, entities.class, entities.inside, entities.the_order, entities.the_level, entities.the_line, entities.groupname, entities.updated, entities.indexed, persons.name, persons.sex, persons.obs
# FROM entities JOIN persons ON entities.id = persons.id JOIN (entities AS entities_1 JOIN attributes AS attributes_1 ON attributes_1.id = entities_1.id) ON entities.id = attributes_1.entity AND attributes_1.the_type = :the_type_1 AND attributes_1.the_value LIKE :the_value_1
# n$Diogo Pereira de Melo e Aboim/m/id=140354/obs="""
#       """
#
#                   Id: 140354
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000020
#
#                   Nome        : Diogo Pereira de Melo e Aboim
#                   Data inicial: 1768-10-01
#                   Data final  : 1768-10-01
#                   Filiação:
#
#                   Naturalidade:  Lisboa
#                   Faculdade: Cânones
#
#                   Matrícula(s): 01.10.1768
#                   Instituta:
#                   Bacharel:
#                   Formatura:
#                   Licenciado:
#                   Doutor:
#
#                   Outras informações:
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000020""/2021-05-17
#   atr$data-do-registo/2021-05-17/2021-05-17
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140354""/2021-05-17
#   ls$uc.entrada/1768-10-01/1768-10-01
#   ls$uc.saida/1768-10-01/1768-10-01
#   ls$uc.entrada.ano/1768/1768-10-01
#   ls$uc.saida.ano/1768/1768-10-01
#   ls$nome/Diogo Pereira de Melo e Aboim/1768-10-01
#   ls$nome.primeiro/Diogo/1768-10-01
#   ls$nome.apelido/Pereira de Melo e Aboim/1768-10-01
#   ls$nome.apelido/Melo e Aboim/1768-10-01
#   ls$nome.apelido/Aboim/1768-10-01
#   ls$naturalidade/Lisboa/1768-10-01
#   ls$naturalidade.ano/Lisboa.1768/1768-10-01
#   ls$nome-geografico/Lisboa/1768-10-01
#   ls$nome-geografico.ano/Lisboa.1768/1768-10-01
#   ls$faculdade/Cânones/1768-10-01
#   ls$faculdade.ano/Cânones.1768/1768-10-01
#   ls$matricula/Cânones/1768-10-01/obs=01.10.1768
#   ls$matricula.ano/Cânones.1768/1768-10-01/obs=01.10.1768
# n$Lourenço Correia Manuel de Aboim/m/id=140364/obs="""
#       """
#
#                   Id: 140364
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000033
#
#                   Nome        : Lourenço Correia Manuel de Aboim
#                   Data inicial: 1729-10-01
#                   Data final  : 1731-10-01
#                   Filiação:
#
#                   Naturalidade: Lisboa
#                   Faculdade: Cânones
#
#                   Matrícula(s): 01.10.1730
#                   01.10.1731
#                   Instituta: 01.10.1729
#                   Bacharel:
#                   Formatura:
#                   Licenciado:
#                   Doutor:
#
#                   Outras informações:
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000033""/2021-05-17
#   atr$data-do-registo/2021-05-17/2021-05-17
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=
pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211
# n$António Ribeiro de Abranches/m/id=140394/obs="""
#       """
#
#                   Id: 140394
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000067
#
#                   Nome        : António Ribeiro de Abranches
#                   Data inicial: 1848-10-21
#                   Data final  : 1848-10-21
#                   Filiação:
#
#                   Naturalidade: Lisboa
#                   Faculdade: Direito
#
#                   Matrícula(s): 21.10.1848
#                   Instituta:
#                   Bacharel:
#                   Formatura:
#                   Licenciado:
#                   Doutor:
#
#                   Outras informações:
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000067""/2021-05-17
#   atr$data-do-registo/2021-05-17/2021-05-17
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140394""/2021-05-17
#   ls$uc.entrada/1848-10-21/1848-10-21
#   ls$uc.saida/1848-10-21/1848-10-21
#   ls$uc.entrada.ano/1848/1848-10-21
#   ls$uc.saida.ano/1848/1848-10-21
#   ls$nome/António Ribeiro de Abranches/1848-10-21
#   ls$nome.primeiro/António/1848-10-21
#   ls$nome.apelido/Ribeiro de Abranches/1848-10-21
#   ls$nome.apelido/Abranches/1848-10-21
#   ls$naturalidade/Lisboa/1848-10-21
#   ls$naturalidade.ano/Lisboa.1848/1848-10-21
#   ls$nome-geografico/Lisboa/1848-10-21
#   ls$nome-geografico.ano/Lisboa.1848/1848-10-21
#   ls$faculdade/Direito/1848-10-21
#   ls$faculdade.ano/Direito.1848/1848-10-21
#   ls$matricula/Direito/1848-10-21/obs=21.10.1848
#   ls$matricula.ano/Direito.1848/1848-10-21/obs=21.10.1848
# n$João Pais de Vasconcelos Abranches/m/id=140426/obs="""
#       """
#
#                   Id: 140426
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000105
#
#                   Nome        : João Pais de Vasconcelos Abranches
#                   Data inicial: 1875-10-15
#                   Data final  : 1880-07-03
#                   Filiação: Bernardo Francisco de Abranches
#                   Naturalidade: Lisboa
#                   Faculdade: Direito
#
#                   Matrícula(s): 15.10.1875
#
#                   Exames: 3º: 09.07.1878, Aprovado Nemine Discrepante, Atos n.º 27, fl. 38
#                   4º Grau e  Bacharel: 21.06.1879, Aprovado Nemine Discrepante, Atos n.º 27, fl. 144 v.
#                   Formatura: 03.07.1880, Aprovado Nemine Discrepante, Atos n.º 27, fl. 256
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000105""/2021-05-12
#   atr$data-do-registo/2021-05-12/2021-05-12
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140426""/2021-05-12
#   ls$uc.entrada/1875-10-15/1875-10-15
#   ls$uc.saida/1880-07-03/1880-07-03
#   ls$uc.entrada.ano/1875/1875-10-15
#   ls$uc.saida.ano/1880/1880-07-03
#   ls$nome/João Pais de Vasconcelos Abranches/1875-10-15
#   ls$nome.primeiro/João/1875-10-15
#   ls$nome.apelido/Pais de Vasconcelos Abranches/1875-10-15
#   ls$nome.apelido/Vasconcelos Abranches/1875-10-15
#   ls$nome.apelido/Abranches/1875-10-15
#   ls$naturalidade/Lisboa/1875-10-15
#   ls$naturalidade.ano/Lisboa.1875/1875-10-15
#   ls$nome-geografico/Lisboa/1875-10-15
#   ls$nome-geografico.ano/Lisboa.1875/1875-10-15
#   ls$faculdade/Direito/1875-10-15
#   ls$faculdade.ano/Direito.1875/1875-10-15
#   ls$matricula/Direito/1875-10-15/obs=15.10.1875
#   ls$matricula.ano/Direito.1875/1875-10-15/obs=15.10.1875
#   ls$grau/Bacharel/1879-06-21/obs=4º Grau e Bacharel: 21.06.1879, Aprovado Nemine Discrepante, Atos n.º 27, fl. 144 v.
#   ls$grau.ano/Bacharel.1879/1879-06-21/obs=4º Grau e Bacharel: 21.06.1879, Aprovado Nemine Discrepante, Atos n.º 27, fl. 144 v.
#   ls$grau/Formatura/1880-07-03/obs=03.07.1880, Aprovado Nemine Discrepante, Atos n.º 27, fl. 256
#   ls$grau.ano/Formatura.1880/1880-07-03/obs=03.07.1880, Aprovado Nemine Discrepante, Atos n.º 27, fl. 256
#   ls$exame/3º/1878-07-09/obs=Aprovado Nemine Discrepante, Atos n.º 27, fl. 38
#   ls$exame/4º/1879-06-21/obs=Aprovado Nemine Discrepante, Atos n.º 27, fl. 144 v
#   ls$exame/Formatura/1880-07-03/obs=Aprovado Nemine Discrepante, Atos n.º 27, fl. 256
#   pai$Bernardo Francisco de Abranches/m/id=140426-pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211
# n$João Teodoro de Abreu/m/id=268861/obs="""
#       """
#
#                   Id: 268861
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000189
#
#                   Nome        : João Teodoro de Abreu (colegial do Celégio dos Militares)
#                   Data inicial: 1747-05-20
#                   Data final  : 1749-03-27
#                   Filiação:
#
#                   Naturalidade: Lisboa
#                   Faculdade: Cânones
#
#                   Exames: Bacharel: 20.05.1747
#                   Formatura: 02.11.1747
#                   Exame Privado e Grau de Licenciado: 27.03.1749, Atos 83, fl. 102 v.
#
#                   Outras informações:
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000189""/2021-04-23
#   atr$data-do-registo/2021-04-23/2021-04-23
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=268861""/2021-04-23
#   ls$uc.entrada/1747-05-20/1747-05-20
#   ls$uc.saida/1749-03-27/1749-03-27
#   ls$uc.entrada.ano/1747/1747-05-20
#   ls$uc.saida.ano/1749/1749-03-27
#   ls$nome.nota/colegial do Celégio dos Militares/1747-05-20
#   ls$colegio/Colégio das Ordens Militares/1747-05-20/obs=colegial do Celégio dos Militares
#   ls$nome/João Teodoro de Abreu/1747-05-20
#   ls$nome.primeiro/João/1747-05-20
#   ls$nome.apelido/Teodoro de Abreu/1747-05-20
#   ls$nome.apelido/Abreu/1747-05-20
#   ls$naturalidade/Lisboa/1747-05-20
#   ls$naturalidade.ano/Lisboa.1747/1747-05-20
#   ls$nome-geografico/Lisboa/1747-05-20
#   ls$nome-geografico.ano/Lisboa.1747/1747-05-20
#   ls$faculdade/Cânones/1747-05-20
#   ls$faculdade.ano/Cânones.1747/1747-05-20
#   ls$grau/Bacharel/1747-05-20/obs=20.05.1747
#   ls$grau.ano/Bacharel.1747/1747-05-20/obs=20.05.1747
#   ls$grau/Formatura/1747-11-02/obs=02.11.1747
#   ls$grau.ano/Formatura.1747/1747-11-02/obs=02.11.1747
#   ls$grau/Licenciado/1749-03-27/obs=Exame Privado e Grau de Licenciado: 27.03.1749, Atos 83, fl. 102 v.
#   ls$grau.ano/Licenciado.1749/1749-03-27/obs=Exame Privado e Grau de Licenciado: 27.03.1749, Atos 83, fl. 102 v.
#   ls$exame/Bacharel/1747-05-20/obs= 20.05.1747
#   ls$exame/Formatura/1747-11-02/obs= 02.11.1747
#   ls$exame/Exame Privado e Grau de Licenciado:/1749-03-27/obs=Atos 83, fl. 102 v
# n$Alexandre José Coelho de Abreu/m/id=140520/obs="""
#       """
#
#                   Id: 140520
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000212
#
#                   Nome        : Alexandre José Coelho de Abreu
#                   Data inicial: 1838-10-15
#                   Data final  : 1845-05-29
#                   Filiação: João Coelho de Abreu
#                   Naturalidade: Lisboa
#                   Faculdade: Direito
#
#                   Matrícula(s): Matemática 15.10.1838 (obrigado)
#                   Filosofia: 15.10.1838 (obrigado)
#                   Direito: 31.10.1840
#
#                   Exames: 3º: 24.05.1843, Aprovado Nemine Discrepante, Atos n.º 13, fl. 47 v.
#                   4º e Grau de Bacharel: 26.06.1844, Aprovado Nemine Discrepante, Atos n.º 19, fl. 103 v.
#                   Formatura: 29.05.1845, Aprovado Nemine Discrepante, Atos n.º 19, fl. 233 v.
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000212""/2021-04-29
#   atr$data-do-registo/2021-04-29/2021-04-29
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140520""/2021-04-29
#   ls$uc.entrada/1838-10-15/1838-10-15
#   ls$uc.saida/1845-05-29/1845-05-29
#   ls$uc.entrada.ano/1838/1838-10-15
#   ls$uc.saida.ano/1845/1845-05-29
#   ls$nome/Alexandre José Coelho de Abreu/1838-10-15
#   ls$nome.primeiro/Alexandre/1838-10-15
#   ls$nome.apelido/José Coelho de Abreu/1838-10-15
#   ls$nome.apelido/Coelho de Abreu/1838-10-15
#   ls$nome.apelido/Abreu/1838-10-15
#   ls$naturalidade/Lisboa/1838-10-15
#   ls$naturalidade.ano/Lisboa.1838/1838-10-15
#   ls$nome-geografico/Lisboa/1838-10-15
#   ls$nome-geografico.ano/Lisboa.1838/1838-10-15
#   ls$faculdade/Direito/1838-10-15
#   ls$faculdade.ano/Direito.1838/1838-10-15
#   ls$matricula/Matemática/1838-10-15
#   ls$matricula.ano/Matemática.1838/1838-10-15
#   ls$matricula/Filosofia/1838-10-15
#   ls$matricula.ano/Filosofia.1838/1838-10-15
#   ls$matricula/Direito/1840-10-31/obs=31.10.1840
#   ls$matricula.ano/Direito.1840/1840-10-31/obs=31.10.1840
#   ls$grau/Bacharel/1844-06-26/obs=4º e Grau de Bacharel: 26.06.1844, Aprovado Nemine Discrepante, Atos n.º 19, fl. 103 v.
#   ls$grau.ano/Bacharel.1844/1844-06-26/obs=4º e Grau de Bacharel: 26.06.1844, Aprovado Nemine Discrepante, Atos n.º 19, fl. 103 v.
#   ls$grau/Formatura/1845-05-29/obs=29.05.1845, Aprovado Nemine Discrepante, Atos n.º 19, fl. 233 v.
#   ls$grau.ano/Formatura.1845/1845-05-29/obs=29.05.1845, Aprovado Nemine Discrepante, Atos n.º 19, fl. 233 v.
#   ls$exame/3º/1843-05-24/obs=Aprovado Nemine Discrepante, Atos n.º 13, fl. 47 v
#   ls$exame/4º/1844-06-26/obs=Aprovado Nemine Discrepante, Atos n.º 19, fl. 103 v
#   ls$exame/Formatura/1845-05-29/obs=Aprovado Nemine Discrepante, Atos n.º 19, fl. 233 v
#   pai$João Coelho de Abreu/m/id=140520-pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211
# n$Amaro Correia de Abreu/m/id=140527/obs="""
#       """
#
#                   Id: 140527
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000220
#
#                   Nome        : Amaro Correia de Abreu
#                   Data inicial: 1667-11-15
#                   Data final  : 1667-11-15
#                   Filiação:
#
#                   Naturalidade: Lisboa
#                   Faculdade: Cânones
#
#                   Matrícula(s): 15.11.1667
#                   Instituta:
#                   Bacharel:
#                   Formatura:
#                   Licenciado:
#                   Doutor:
#
#                   Outras informações:
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000220""/2021-04-23
#   atr$data-do-registo/2021-04-23/2021-04-23
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140527""/2021-04-23
#   ls$uc.entrada/1667-11-15/1667-11-15
#   ls$uc.saida/1667-11-15/1667-11-15
#   ls$uc.entrada.ano/1667/1667-11-15
#   ls$uc.saida.ano/1667/1667-11-15
#   ls$nome/Amaro Correia de Abreu/1667-11-15
#   ls$nome.primeiro/Amaro/1667-11-15
#   ls$nome.apelido/Correia de Abreu/1667-11-15
#   ls$nome.apelido/Abreu/1667-11-15
#   ls$naturalidade/Lisboa/1667-11-15
#   ls$naturalidade.ano/Lisboa.1667/1667-11-15
#   ls$nome-geografico/Lisboa/1667-11-15
#   ls$nome-geografico.ano/Lisboa.1667/1667-11-15
#   ls$faculdade/Cânones/1667-11-15
#   ls$faculdade.ano/Cânones.1667/1667-11-15
#   ls$matricula/Cânones/1667-11-15/obs=15.11.1667
#   ls$matricula.ano/Cânones.1667/1667-11-15/obs=15.11.1667
# n$Amaro José Nobre de Abreu/m/id=140528/obs="""
#       """
#
#                   Id: 140528
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000222
#
#                   Nome        : Amaro José Nobre de Abreu
#                   Data inicial: 1760-12-01
#                   Data final  : 1765-10-01
#                   Filiação:
#
#                   Naturalidade: Lisboa
#                   Faculdade: Cânones
#
#                   Matrícula(s): 01.12.1760
#                   01.10.1761
#                   01.10.1762
#                   01.10.1763
#                   01.10.1764
#                   01.10.1765
#                   Instituta:
#                   Bacharel:
#                   Formatura:
#                   Licenciado:
#                   Doutor:
#
#                   Outras informações:
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000222""/2021-04-23
#   atr$data-do-registo/2021-04-23/2021-04-23
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140528""/2021-04-23
#   ls$uc.entrada/1760-12-01/1760-12-01
#   ls$uc.saida/1765-10-01/1765-10-01
#   ls$uc.entrada.ano/1760/1760-12-01
#   ls$uc.saida.ano/1765/1765-10-01
#   ls$nome/Amaro José Nobre de Abreu/1760-12-01
#   ls$nome.primeiro/Amaro/1760-12-01
#   ls$nome.apelido/José Nobre de Abreu/1760-12-01
#   ls$nome.apelido/Nobre de Abreu/1760-12-01
#   ls$nome.apelido/Abreu/1760-12-01
#   ls$naturalidade/Lisboa/1760-12-01
#   ls$naturalidade.ano/Lisboa.1760/1760-12-01
#   ls$nome-geografico/Lisboa/1760-12-01
#   ls$nome-geografico.ano/Lisboa.1760/1760-12-01
#   ls$faculdade/Cânones/1760-12-01
pai
#     rel$function-in-act/pai/auc-alumni-A-140337-140771/20200211
# /var/folders/x7/qzytnd752559g0w475rfwkx00000gn/T/ipykernel_34991/2573349682.py:10: SAWarning: An alias is being generated automatically against joined entity Mapper[Attribute(attributes)] due to overlapping tables.  This is a legacy pattern which may be deprecated in a later release.  Use the aliased(<entity>, flat=True) construct explicitly, see the linked example. (Background on this warning at: https://sqlalche.me/e/20/xaj2)
#   print(stmt)

# %% [markdown]
# ###  Obter um dataframe a partir de atributos
#
# ---
#
#
# ###  Get a Dataframe from attributes

# %% [markdown]
# #### Exemplo: Faculdade, data de entrada e data de saída e grau dos naturais de Coimbra

# %%
from timelink.pandas import entities_with_attribute


# Get list of people with with a certain value in a specific attribute
df = entities_with_attribute(
                    entity_type='person',
                    the_type='naturalidade',
                    the_value='Coimbra',
                    more_info=['name'],
                    more_cols=['faculdade','uc.entrada','uc.saida'],
                    db=tlnb.db,
                    sql_echo=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 140349 to 140367
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               14 non-null     object
#  1   naturalidade       14 non-null     object
#  2   naturalidade.date  14 non-null     object
#  3   naturalidade.obs   0 non-null      object
#  4   faculdade          14 non-null     object
#  5   faculdade.date     14 non-null     object
#  6   faculdade.obs      1 non-null      object
#  7   uc.entrada         14 non-null     object
#  8   uc.entrada.date    14 non-null     object
#  9   uc.entrada.obs     0 non-null      object
#  10  uc.saida           14 non-null     object
#  11  uc.saida.date      14 non-null     object
#  12  uc.saida.obs       0 non-null      object
# dtypes: object(13)
# memory usage: 2.1+ KB

# %%
df.head(5)
# Out:
#                        name naturalidade naturalidade.date naturalidade.obs  \
# id
# 140349     António de Aboim      Coimbra        1566-12-20             None
# 140671       Diogo de Abreu      Coimbra        1604-10-11             None
# 140643    Bernardo de Abreu      Coimbra        1612-10-15             None
# 140629  Bartolomeu de Abreu      Coimbra        1627-10-19             None
# 140662   Cristóvão de Abreu      Coimbra        1660-01-08             None
#
#        faculdade faculdade.date faculdade.obs  uc.entrada uc.entrada.date  \
# id
# 140349   Cânones     1566-12-20          None  1566-12-20      1566-12-20
# 140671   Cânones     1604-10-11          None  1604-10-11      1604-10-11
# 140643   Cânones     1612-10-15          None  1612-10-15      1612-10-15
# 140629   Cânones     1627-10-19          None  1627-10-19      1627-10-19
# 140662   Cânones     1660-01-08          None  1660-01-08      1660-01-08
#
#        uc.entrada.obs    uc.saida uc.saida.date uc.saida.obs
# id
# 140349           None  1574-07-24    1574-07-24         None
# 140671           None  1604-10-11    1604-10-11         None
# 140643           None  1616-10-19    1616-10-19         None
# 140629           None  1638-10-11    1638-10-11         None
# 140662           None  1662-10-22    1662-10-22         None

# %% [markdown]
# ###  Remover colunas sem valores
#
# ---
#
#
#
# ###  Remove empty columns

# %%
df.dropna(how='all', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 140349 to 140367
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               14 non-null     object
#  1   naturalidade       14 non-null     object
#  2   naturalidade.date  14 non-null     object
#  3   faculdade          14 non-null     object
#  4   faculdade.date     14 non-null     object
#  5   faculdade.obs      1 non-null      object
#  6   uc.entrada         14 non-null     object
#  7   uc.entrada.date    14 non-null     object
#  8   uc.saida           14 non-null     object
#  9   uc.saida.date      14 non-null     object
# dtypes: object(10)
# memory usage: 1.7+ KB

# %%
df.head(5)
# Out:
#                        name naturalidade naturalidade.date faculdade  \
# id
# 140349     António de Aboim      Coimbra        1566-12-20   Cânones
# 140671       Diogo de Abreu      Coimbra        1604-10-11   Cânones
# 140643    Bernardo de Abreu      Coimbra        1612-10-15   Cânones
# 140629  Bartolomeu de Abreu      Coimbra        1627-10-19   Cânones
# 140662   Cristóvão de Abreu      Coimbra        1660-01-08   Cânones
#
#        faculdade.date faculdade.obs  uc.entrada uc.entrada.date    uc.saida  \
# id
# 140349     1566-12-20          None  1566-12-20      1566-12-20  1574-07-24
# 140671     1604-10-11          None  1604-10-11      1604-10-11  1604-10-11
# 140643     1612-10-15          None  1612-10-15      1612-10-15  1616-10-19
# 140629     1627-10-19          None  1627-10-19      1627-10-19  1638-10-11
# 140662     1660-01-08          None  1660-01-08      1660-01-08  1662-10-22
#
#        uc.saida.date
# id
# 140349    1574-07-24
# 140671    1604-10-11
# 140643    1616-10-19
# 140629    1638-10-11
# 140662    1662-10-22

# %% [markdown]
# ## Contagens
#
# ---
#
# ## Counting

# %% [markdown]
# ###  Contagem de atributos a partir de uma tabela em memória
#
# ---
#
# ###  Count attributes from an existing dataframe

# %%
# create a column with the index values which are the id numbers
df['id'] = df.index.values

col = 'faculdade' # subotal by this column

# Use pandas groupby and specify unique value count for id
df_totals = df.groupby(col).agg({'id':'nunique',
                                                  'uc.entrada':'min',
                                                  'uc.saida':'max'})

df_totals.sort_values('id',ascending= False).head(30)
# Out:
#             id  uc.entrada    uc.saida
# faculdade
# Cânones      7  0000-00-00  1767-07-27
# Medicina     5  1670-10-01  1823-10-20
# Direito      1  1748-10-19  1748-10-19
# Matemática   1  1868-10-02  1872-10-03

# %% [markdown]
# ### Contagens na base de dados
#
# Quando o atributo tem muitos valores e não é necessário
# ter todas as pessoas em memória: contagem feita na base de dados
#
# ---
#
# ### Counting directly in the database
# When there are many values and it is not
# necessary to have all the people in memory:
# count directly in the database.

# %%
from timelink.pandas import attribute_values

df_totals = attribute_values('jesuita-entrada',db=tlnb.db)

# %%
df_totals.head(10)
# Out:
#                    count  date_min  date_max
# value
# ?                     31  15550000  17581126
# Coimbra                6  15420000  16770701
# Goa                    3  15480502  16660000
# Lisboa                 3  16680000  17460223
# Avignon                2  17350731  17370927
# Paris                  2  16700926  16771029
# Saragoça               2  16740613  16771115
# Évora                  2  15710304  17230000
# Alcalá de Henares      1  15580413  15580413
# Bolonha                1  17250728  17250728

# %% [markdown]
# #### Filtrar por datas
#
# ---
#
# #### Filter by dates

# %%
df_totals = attribute_values('grau',dates_between=('1535','1600'),db=tlnb.db)

# %%
df_totals.head(10)
# Out:
#                      count    date_min    date_max
# value
# Bacharel                 9  1554-07-19  1593-06-09
# Formatura                6  1574-07-24  1593-05-12
# Bacharel em Artes        3  1574-03-14  1588-03-12
# Licenciado               3  1574-06-03  1597-05-06
# Doutor                   2  1560-12-22  1589-10-27
# Licenciado em Artes      2  1574-05-15  1589-01-13

# %% [markdown]
# ## Visualizar registos
#
# ---
#
# ## View records

# %% [markdown]
# ### Visualizar uma pessoa
#
# ---
#
# ### View a person

# %% [markdown]
# #### Atributos de uma pessoa numa tabela, uma linha por attributo
#
# ---
#
# #### Person attributes in a dataframe, one line per attribute

# %%
import pandas as pd
from timelink.pandas import group_attributes as person_attributes

pd.set_option('display.max_rows',1000)

id = '140687'
pdf = person_attributes([id],db=tlnb.db)  # note id in a list
pdf[['date','type','value','attr_obs']].sort_values(['date','type'])
# Out:
#               date                  type  \
# id
# 140687  1821-10-31             faculdade
# 140687  1821-10-31         faculdade.ano
# 140687  1821-10-31             matricula
# 140687  1821-10-31         matricula.ano
# 140687  1821-10-31          naturalidade
# 140687  1821-10-31      naturalidade.ano
# 140687  1821-10-31                  nome
# 140687  1821-10-31       nome-geografico
# 140687  1821-10-31   nome-geografico.ano
# 140687  1821-10-31          nome.apelido
# 140687  1821-10-31          nome.apelido
# 140687  1821-10-31          nome.apelido
# 140687  1821-10-31         nome.primeiro
# 140687  1821-10-31            uc.entrada
# 140687  1821-10-31        uc.entrada.ano
# 140687  1821-11-05             matricula
# 140687  1821-11-05         matricula.ano
# 140687  1821-11-05              uc.saida
# 140687  1821-11-05          uc.saida.ano
# 140687  2021-04-23  código-de-referência
# 140687  2021-04-23       data-do-registo
# 140687  2021-04-23                   url
#
#                                                  value attr_obs
# id
# 140687                                           "#29"     None
# 140687                                      "#29.1821"     None
# 140687                                       Filosofia     None
# 140687                                  Filosofia.1821     None
# 140687                                  Vilar de Veiga     None
# 140687                             Vilar de Veiga.1821     None
# 140687                    Domingos José da Cunha Abreu     None
# 140687                                  Vilar de Veiga     None
# 140687                             Vilar de Veiga.1821     None
# 140687                             José da Cunha Abreu     None
# 140687                                     Cunha Abreu     None
# 140687                                           Abreu     None
# 140687                                        Domingos     None
# 140687                                      1821-10-31     None
# 140687                                            1821     None
# 140687                                      Matemática     None
# 140687                                 Matemática.1821     None
# 140687                                      1821-11-05     None
# 140687                                            1821     None
# 140687          "PT/AUC/ELU/UC-AUC/B/001-001/A/000404"     None
# 140687                                      2021-04-23     None
# 140687  "https://pesquisa.auc.uc.pt/details?id=140687"     None

# %%
p = tlnb.db.get_person(id)
print(p.to_kleio())
# Out:
# n$Domingos José da Cunha Abreu/m/id=140687/obs="""
#       """
#
#                   Id: 140687
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000404
#
#                   Nome        : Domingos José da Cunha Abreu
#                   Data inicial: 1821-10-31
#                   Data final  : 1821-11-05
#                   Filiação:
#
#                   Naturalidade: Vilar de Veiga
#                   Faculdade: #29;Matemática
#
#                   Matrícula(s): Filosofia: 1821/10/31 (obrigado)
#                   Matemática: 1821/11/05 (obrigado)
#                   Instituta:
#                   Bacharel:
#                   Formatura:
#                   Licenciado:
#                   Doutor:
#
#                   Outras informações:
#               """
#   """
#   rel$function-in-act/n/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000404""/2021-04-23
#   atr$data-do-registo/2021-04-23/2021-04-23
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140687""/2021-04-23
#   ls$uc.entrada/1821-10-31/1821-10-31
#   ls$uc.saida/1821-11-05/1821-11-05
#   ls$uc.entrada.ano/1821/1821-10-31
#   ls$uc.saida.ano/1821/1821-11-05
#   ls$nome/Domingos José da Cunha Abreu/1821-10-31
#   ls$nome.primeiro/Domingos/1821-10-31
#   ls$nome.apelido/José da Cunha Abreu/1821-10-31
#   ls$nome.apelido/Cunha Abreu/1821-10-31
#   ls$nome.apelido/Abreu/1821-10-31
#   ls$naturalidade/Vilar de Veiga/1821-10-31
#   ls$naturalidade.ano/Vilar de Veiga.1821/1821-10-31
#   ls$nome-geografico/Vilar de Veiga/1821-10-31
#   ls$nome-geografico.ano/Vilar de Veiga.1821/1821-10-31
#   ls$faculdade/""#29""/1821-10-31
#   ls$faculdade.ano/""#29.1821""/1821-10-31
#   ls$matricula/Filosofia/1821-10-31
#   ls$matricula.ano/Filosofia.1821/1821-10-31
#   ls$matricula/Matemática/1821-11-05
#   ls$matricula.ano/Matemática.1821/1821-11-05

# %% [markdown]
# #### Atributos de uma pessoa numa tabela, attributos em colunas
#
# ---
#
# #### Person attributes in a dataframe, attributes in columns

# %%
# Get list of people with with a certain value in a specific attribute

id = '316297'  # João Pedro Ribeiro
# id = '234295'  # Alexandre Metelo de Sousa
df = entities_with_attribute(
                    entity_type='person',
                    the_type='uc.entrada',  # we need a base attribute
                    more_info=['name'],
                    more_cols=['instituta','faculdade'],
                    db=tlnb.db,
                    sql_echo=False)
view_cols = ['name','faculdade','faculdade.date','faculdade.obs']
df.info()
df[view_cols].sort_values('faculdade.date')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 503 entries, 140337 to 269364
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             503 non-null    object
#  1   uc.entrada       503 non-null    object
#  2   uc.entrada.date  503 non-null    object
#  3   uc.entrada.obs   0 non-null      object
#  4   instituta        205 non-null    object
#  5   instituta.date   205 non-null    object
#  6   instituta.obs    205 non-null    object
#  7   faculdade        447 non-null    object
#  8   faculdade.date   447 non-null    object
#  9   faculdade.obs    29 non-null     object
# dtypes: object(10)
# memory usage: 43.2+ KB
#                                                      name   faculdade  \
# id
# 140345                                    Jorge Abenajado    Medicina
# 140669                                     Diogo de Abreu        Leis
# 140347                                    Adrião de Aboim        Leis
# 140708                                    Filipe de Abreu     Cânones
# 140541                                   António de Abreu     Cânones
# 140358                                      João de Aboim     Cânones
# 140670                                     Diogo de Abreu        Leis
# 140695                                    Duarte de Abreu     Cânones
# 140349                                   António de Aboim     Cânones
# 140742                                 Francisco de Abreu    Medicina
# 140715                                    Fernão de Abreu     Cânones
# 140721                                 Francisco de Abreu     Cânones
# 140741                                 Francisco de Abreu        Leis
# 140681                          Domingos Antunes de Abreu     Cânones
# 140544                                   António de Abreu       "#29"
# 140571                              António Dias de Abreu        Leis
# 140664                                 Cristóvão de Abreu     Cânones
# 140737                                 Francisco de Abreu     Cânones
# 140517                                    Aleixo de Abreu    Medicina
# 140696                                    Duarte de Abreu       "#29"
# 140631                                Bartolomeu de Abreu     Cânones
# 140636                                  Belchior de Abreu     Cânones
# 140672                                     Diogo de Abreu        Leis
# 140736                                 Francisco de Abreu    Medicina
# 140740                                 Francisco de Abreu     Cânones
# 140556                                   António de Abreu     Cânones
# 140722                                 Francisco de Abreu     Cânones
# 140719                                    Filipe de Abreu    Teologia
# 140535                                   António de Abreu       Artes
# 140513                 Agnelo de São Jorge Mendia e Abreu     Direito
# 140627                    Augusto Óscar de Oliveira Abreu     Direito
# 140744                           Francisco Aires de Abreu  Matemática
# 140565                    António Cordeiro Gomes de Abreu     Direito
# 140658                         Carlos Sousa de Melo Abreu   Filosofia
# 140412                 Francisco Amadeu Proença Abranches  Matemática
# 140446                     Júlio Newton Proença Abranches  Matemática
# 140352                         David Vaz da Fonseca Aboim   Filosofia
# 140623                             Armando Aires de Abreu   Filosofia
# 269364                 Luís Monteiro Soares de Albergaria     Direito
# 269344                  João Soares de Sousa e Albergaria        Leis
# 140367                          Manuel de Vargas de Aboim     Cânones
# 140725                                 Francisco de Abreu     Cânones
# 269318                                 Pedro Barba Alardo        Leis
# 269289                    António Militã de Sousa Aimbere        Leis
# 269145                       José Luís Ferreira de Aguiar    Teologia
# 140524                             Álvaro Leitão de Abreu     Cânones
# 140682                        Domingos de Chaves de Abreu        Leis
# 269357                    José Roque Soares de Albergaria        Leis
# 140735                                 Francisco de Abreu     Cânones
# 269005                                    Jacinto de Adão     Direito
# 140406                              Domingos de Abranches     Cânones
# 268985               Mateus José Lobo de Mesquita e Abreu        Leis
# 140678                               Diogo Velho de Abreu     Cânones
# 140459       Manuel Corte-Real Abranches, vide Corte-Real     Cânones
# 268763                             Bernardo José de Abreu     Cânones
# 140351            António Pestana Guerreiro Camacho Aboim     Cânones
# 268908                       José de Oliva de Sousa Abreu        Leis
# 269130                     José António Machado de Aguiar     Cânones
# 140613                         António Rodrigues de Abreu     Cânones
# 140355                          Filipe Guerreiro de Aboim         NaN
# 140357                                   Gonçalo de Aboim         NaN
# 140376                                   Álvaro Abranches         NaN
# 140377                        André de Sequeira Abranches         NaN
# 140404                        Diogo Pessanha de Abranches         NaN
# 140405                              Domingos de Abranches         NaN
# 140410                             Francisco de Abranches         NaN
# 140461              Manuel Inácio de Figueiredo Abranches         NaN
# 140465                         Manuel Simões de Abranches         NaN
# 140472                                António de Abrantes         NaN
# 140474                                António de Abrantes         NaN
# 140477                             Bartolomeu de Abrantes         NaN
# 140484                                   José de Abrantes         NaN
# 140485                                   José de Abrantes         NaN
# 140489                                   Luís de Abrantes         NaN
# 140491                                 Manuel de Abrantes         NaN
# 140515                            Agostinho José de Abreu         NaN
# 140531                                     André de Abreu         NaN
# 140546                                   António de Abreu         NaN
# 140557                                   António de Abreu         NaN
# 140598                   António Manuel Nogueira de Abreu         NaN
# 140606                            António Rebelo de Abreu         NaN
# 140616                             António de Sousa Abreu         NaN
# 140619                               António Vaz de Abreu         NaN
# 140632                                Bartolomeu de Abreu         NaN
# 140633                       Bartolomeu da Silva de Abreu         NaN
# 140639                                     Bento de Abreu         NaN
# 140648                                      Brás de Abreu         NaN
# 140674                               Diogo Gomes de Abreu         NaN
# 140689                            Domingos Lopes de Abreu         NaN
# 140710                                  Fernando de Abreu         NaN
# 140713                                    Fernão de Abreu         NaN
# 140728                                 Francisco de Abreu         NaN
# 140748                        Francisco Caldeira de Abreu         NaN
# 268800            NaN                                                NaN
# 268820            NaN                                                NaN
# 268857            NaN                                                NaN
# 268864            NaN                                                NaN
# 268873            NaN                                                NaN
# 268891            NaN                                                NaN
# 268898            NaN                                                NaN
# 268956            NaN                                                NaN
# 268989            NaN                                                NaN
# 269001            NaN                                                NaN
# 269003            NaN                                                NaN
# 269060            NaN                                                NaN
# 269211            NaN                                                NaN
# 269262            NaN                                                NaN
# 269341            NaN                                                NaN

# %% [markdown]
# #### Examinar potenciais duplicados
#
# ---
#
# #### Examine potentital duplicates

# %%
from timelink.pandas import display_group_attributes
pd.set_option('display.max_rows',250)

no_show=['código-de-referência','data-do-registo','url','faculdade.ano','naturalidade.ano',
         'matricula-faculdade.ano','nome-apelido','nome-primeiro','nome-geografico.ano',
         'grau.ano','matricula-outra.ano','nome-geografico','instituta.ano']

dup_ids = ['234295','234710',]  # Alexandre Metelo de

display_group_attributes(dup_ids,
                             header_cols=['uc-entrada','naturalidade','faculdade','nome-pai'],
                             exclude_attributes=no_show,
                             sort_attributes=['date','type','value'],
                             cmap_name='Pastel1')
# Out:
# <style type="text/css">
# #T_de85d_row0_col0, #T_de85d_row0_col1, #T_de85d_row0_col2, #T_de85d_row0_col3, #T_de85d_row0_col4 {
#   background-color: #fbb4ae;
# }
# #T_de85d_row1_col0, #T_de85d_row1_col1, #T_de85d_row1_col2, #T_de85d_row1_col3, #T_de85d_row1_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_de85d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_de85d_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_de85d_level0_col1" class="col_heading level0 col1" >uc-entrada</th>
#       <th id="T_de85d_level0_col2" class="col_heading level0 col2" >naturalidade</th>
#       <th id="T_de85d_level0_col3" class="col_heading level0 col3" >faculdade</th>
#       <th id="T_de85d_level0_col4" class="col_heading level0 col4" >nome-pai</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de85d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_de85d_row0_col0" class="data row0 col0" >234295</td>
#       <td id="T_de85d_row0_col1" class="data row0 col1" >1704-11-07</td>
#       <td id="T_de85d_row0_col2" class="data row0 col2" >Marialva</td>
#       <td id="T_de85d_row0_col3" class="data row0 col3" >Cânones</td>
#       <td id="T_de85d_row0_col4" class="data row0 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_de85d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_de85d_row1_col0" class="data row1 col0" >234710</td>
#       <td id="T_de85d_row1_col1" class="data row1 col1" >1705-10-24</td>
#       <td id="T_de85d_row1_col2" class="data row1 col2" >Marialva</td>
#       <td id="T_de85d_row1_col3" class="data row1 col3" >Matemática</td>
#       <td id="T_de85d_row1_col4" class="data row1 col4" >Manuel Cardoso Metelo</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_41e12_row0_col0, #T_41e12_row0_col1, #T_41e12_row0_col2, #T_41e12_row0_col3, #T_41e12_row0_col4, #T_41e12_row1_col0, #T_41e12_row1_col1, #T_41e12_row1_col2, #T_41e12_row1_col3, #T_41e12_row1_col4, #T_41e12_row2_col0, #T_41e12_row2_col1, #T_41e12_row2_col2, #T_41e12_row2_col3, #T_41e12_row2_col4, #T_41e12_row3_col0, #T_41e12_row3_col1, #T_41e12_row3_col2, #T_41e12_row3_col3, #T_41e12_row3_col4, #T_41e12_row4_col0, #T_41e12_row4_col1, #T_41e12_row4_col2, #T_41e12_row4_col3, #T_41e12_row4_col4, #T_41e12_row5_col0, #T_41e12_row5_col1, #T_41e12_row5_col2, #T_41e12_row5_col3, #T_41e12_row5_col4, #T_41e12_row7_col0, #T_41e12_row7_col1, #T_41e12_row7_col2, #T_41e12_row7_col3, #T_41e12_row7_col4, #T_41e12_row14_col0, #T_41e12_row14_col1, #T_41e12_row14_col2, #T_41e12_row14_col3, #T_41e12_row14_col4, #T_41e12_row15_col0, #T_41e12_row15_col1, #T_41e12_row15_col2, #T_41e12_row15_col3, #T_41e12_row15_col4, #T_41e12_row16_col0, #T_41e12_row16_col1, #T_41e12_row16_col2, #T_41e12_row16_col3, #T_41e12_row16_col4 {
#   background-color: #fbb4ae;
# }
# #T_41e12_row6_col0, #T_41e12_row6_col1, #T_41e12_row6_col2, #T_41e12_row6_col3, #T_41e12_row6_col4, #T_41e12_row8_col0, #T_41e12_row8_col1, #T_41e12_row8_col2, #T_41e12_row8_col3, #T_41e12_row8_col4, #T_41e12_row9_col0, #T_41e12_row9_col1, #T_41e12_row9_col2, #T_41e12_row9_col3, #T_41e12_row9_col4, #T_41e12_row10_col0, #T_41e12_row10_col1, #T_41e12_row10_col2, #T_41e12_row10_col3, #T_41e12_row10_col4, #T_41e12_row11_col0, #T_41e12_row11_col1, #T_41e12_row11_col2, #T_41e12_row11_col3, #T_41e12_row11_col4, #T_41e12_row12_col0, #T_41e12_row12_col1, #T_41e12_row12_col2, #T_41e12_row12_col3, #T_41e12_row12_col4, #T_41e12_row13_col0, #T_41e12_row13_col1, #T_41e12_row13_col2, #T_41e12_row13_col3, #T_41e12_row13_col4, #T_41e12_row17_col0, #T_41e12_row17_col1, #T_41e12_row17_col2, #T_41e12_row17_col3, #T_41e12_row17_col4, #T_41e12_row18_col0, #T_41e12_row18_col1, #T_41e12_row18_col2, #T_41e12_row18_col3, #T_41e12_row18_col4, #T_41e12_row19_col0, #T_41e12_row19_col1, #T_41e12_row19_col2, #T_41e12_row19_col3, #T_41e12_row19_col4, #T_41e12_row20_col0, #T_41e12_row20_col1, #T_41e12_row20_col2, #T_41e12_row20_col3, #T_41e12_row20_col4, #T_41e12_row21_col0, #T_41e12_row21_col1, #T_41e12_row21_col2, #T_41e12_row21_col3, #T_41e12_row21_col4, #T_41e12_row22_col0, #T_41e12_row22_col1, #T_41e12_row22_col2, #T_41e12_row22_col3, #T_41e12_row22_col4, #T_41e12_row23_col0, #T_41e12_row23_col1, #T_41e12_row23_col2, #T_41e12_row23_col3, #T_41e12_row23_col4, #T_41e12_row24_col0, #T_41e12_row24_col1, #T_41e12_row24_col2, #T_41e12_row24_col3, #T_41e12_row24_col4, #T_41e12_row25_col0, #T_41e12_row25_col1, #T_41e12_row25_col2, #T_41e12_row25_col3, #T_41e12_row25_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_41e12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41e12_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_41e12_level0_col1" class="col_heading level0 col1" >id</th>
#       <th id="T_41e12_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_41e12_level0_col3" class="col_heading level0 col3" >value</th>
#       <th id="T_41e12_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41e12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41e12_row0_col0" class="data row0 col0" >1704-11-07</td>
#       <td id="T_41e12_row0_col1" class="data row0 col1" >234295</td>
#       <td id="T_41e12_row0_col2" class="data row0 col2" >faculdade</td>
#       <td id="T_41e12_row0_col3" class="data row0 col3" >Cânones</td>
#       <td id="T_41e12_row0_col4" class="data row0 col4" >Cânones </td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41e12_row1_col0" class="data row1 col0" >1704-11-07</td>
#       <td id="T_41e12_row1_col1" class="data row1 col1" >234295</td>
#       <td id="T_41e12_row1_col2" class="data row1 col2" >instituta</td>
#       <td id="T_41e12_row1_col3" class="data row1 col3" >1704-11-07</td>
#       <td id="T_41e12_row1_col4" class="data row1 col4" >07.11.1704 1704-11-07</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41e12_row2_col0" class="data row2 col0" >1704-11-07</td>
#       <td id="T_41e12_row2_col1" class="data row2 col1" >234295</td>
#       <td id="T_41e12_row2_col2" class="data row2 col2" >naturalidade</td>
#       <td id="T_41e12_row2_col3" class="data row2 col3" >Marialva</td>
#       <td id="T_41e12_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_41e12_row3_col0" class="data row3 col0" >1704-11-07</td>
#       <td id="T_41e12_row3_col1" class="data row3 col1" >234295</td>
#       <td id="T_41e12_row3_col2" class="data row3 col2" >nome</td>
#       <td id="T_41e12_row3_col3" class="data row3 col3" >Alexandre Metelo de Sousa</td>
#       <td id="T_41e12_row3_col4" class="data row3 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_41e12_row4_col0" class="data row4 col0" >1704-11-07</td>
#       <td id="T_41e12_row4_col1" class="data row4 col1" >234295</td>
#       <td id="T_41e12_row4_col2" class="data row4 col2" >uc-entrada</td>
#       <td id="T_41e12_row4_col3" class="data row4 col3" >1704-11-07</td>
#       <td id="T_41e12_row4_col4" class="data row4 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_41e12_row5_col0" class="data row5 col0" >1704-11-07</td>
#       <td id="T_41e12_row5_col1" class="data row5 col1" >234295</td>
#       <td id="T_41e12_row5_col2" class="data row5 col2" >uc-entrada.ano</td>
#       <td id="T_41e12_row5_col3" class="data row5 col3" >1704</td>
#       <td id="T_41e12_row5_col4" class="data row5 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_41e12_row6_col0" class="data row6 col0" >1705-10-24</td>
#       <td id="T_41e12_row6_col1" class="data row6 col1" >234710</td>
#       <td id="T_41e12_row6_col2" class="data row6 col2" >faculdade</td>
#       <td id="T_41e12_row6_col3" class="data row6 col3" >Matemática</td>
#       <td id="T_41e12_row6_col4" class="data row6 col4" >Matemática </td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_41e12_row7_col0" class="data row7 col0" >1705-10-24</td>
#       <td id="T_41e12_row7_col1" class="data row7 col1" >234295</td>
#       <td id="T_41e12_row7_col2" class="data row7 col2" >matricula-faculdade</td>
#       <td id="T_41e12_row7_col3" class="data row7 col3" >Cânones</td>
#       <td id="T_41e12_row7_col4" class="data row7 col4" >24.10.1705</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_41e12_row8_col0" class="data row8 col0" >1705-10-24</td>
#       <td id="T_41e12_row8_col1" class="data row8 col1" >234710</td>
#       <td id="T_41e12_row8_col2" class="data row8 col2" >matricula-faculdade</td>
#       <td id="T_41e12_row8_col3" class="data row8 col3" >Matemática</td>
#       <td id="T_41e12_row8_col4" class="data row8 col4" >24.10.1705</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_41e12_row9_col0" class="data row9 col0" >1705-10-24</td>
#       <td id="T_41e12_row9_col1" class="data row9 col1" >234710</td>
#       <td id="T_41e12_row9_col2" class="data row9 col2" >naturalidade</td>
#       <td id="T_41e12_row9_col3" class="data row9 col3" >Marialva</td>
#       <td id="T_41e12_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_41e12_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_41e12_row10_col0" class="data row10 col0" >1705-10-24</td>
#       <
