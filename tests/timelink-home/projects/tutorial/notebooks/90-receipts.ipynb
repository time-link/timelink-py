# %% [markdown]
# > First time use: follow instructions in the README.md file in this directory.

# %%
import timelink
timelink.version
# Out:
# '1.1.18'

# %% [markdown]
# # Receitas / Recipes
#
# Várias receitas para usar Timelink com notebooks
#
#
# ---
#
#
# Recipes for using Timelink with notebooks

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Minimal

# %% [markdown]
# Create a `TimelinkNotebook` instance.
#
# Default values will create a sqlite database.
#
# First time run takes a while because auxiliary software will be downloaded

# %%
from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook(db_name='tutorial2')

# to use postgresql do instead:
# tlnb = TimelinkNotebook(db_type='postgres')

# %% [markdown]
# ### Changing the default values

# %% [markdown]
# When called with no parameters `TimelinkNotebook`
# assumes a certain directory layout containing the notebook
# and from that layout autoconfigures various parameters.
#
# The default layout:
#
# * **project-directory**
#     * **database** (database related filed)
#     * **notebooks**  _(directory with the current notebook)_
#     * **kleio**  (source files in kleio format)
#     * **identifications** (files with identification information)
#
# Based on this layout `TimelinkNotebook` assumes a few default values:
#
# * **database name**
#     * the name of the *project directory* is used as the **database name**, sanitized to produce a valid database name
#       (hifens and spaces are replaced with _ ).
# * **database type**
#   * the type of the database is assumed to be **sqlite**  and a **sqlite** database is created in
#       *database/sqlite*
#     * the `db_type` parameter can be used to set the database to `postgres`.
# * **Kleio server home**, working directory for the _Kleio server_ is assumed to be the **project directory**
#   * The _Kleio server_ is an application
#     that processes transcriptions of historical _Kleio_ notation and generates data in a format
#     that can be imported to the database.
#
# These default values can be changed with parameters when creating the `TimelinkNotebook`  instance:
#
# ```python
# tlnb = TimelinkNotebook(
#     project_name="my-project",
#     project_home="~/projects/m-project",
#     db_type="postgres",
#     db_name="my_project_db",
#     kleio_image="timelinkserver/kleio-server",
#     kleio_version="12.0.0",
#     postgres_image="postgres",
#     postgres_version="latest",
#     sqlite_dir="~/databases",
#     sql_echo=True
# )
# ```

# %% [markdown]
# ### Examining the current configuration

# %%
tlnb.print_info()
# to see tokens and postgres password do:
# tlnb.print_info(show_token=True, show_password=True)
# Out:
# Timelink version: 1.1.18
# Project name: tutorial
# Project home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial
# Database type: sqlite
# Database name: tutorial2
# Kleio image: timelinkserver/kleio-server
# Kleio server token: 4ngzG...
# Kleio server URL: http://127.0.0.1:8089
# Kleio server home: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial
# Kleio server container: exciting_noyce
# Kleio version requested: latest
# Kleio server version: 12.7.579 (2025-01-29 17:45:15)
# SQLite directory: /Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial/database/sqlite
# Database version: 6ccf1ef385a6
# Call print_info(show_token=True) to show the Kleio Server token
# Call print_info(show_password=True) to show the Postgres password
# TimelinkNotebook(project_name=tutorial, project_home=/Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial, db_type=sqlite, db_name=tutorial2, kleio_image=timelinkserver/kleio-server, kleio_version=latest, postgres_image=postgres, postgres_version=latest)

# %% [markdown]
# ### Listing available databases

# %%
pd = tlnb.get_postgres_databases()
print(f"Postgres databases: {pd}")
sd = tlnb.get_sqlite_databases()
print(f"Sqlite databases: {sd}")
# Out:
# Postgres databases: ['timelink', 'timelink-web', 'test_db', 'tests_users', 'test_project', 'tests']
# Sqlite databases: ['../database/sqlite/tutorial.sqlite', '../database/sqlite/orm_tutorial.sqlite', '../database/sqlite/tutorial2.sqlite']

# %% [markdown]
# ## Database status (table row count)

# %%
tlnb.table_row_count_df()
# Out:
#                table  count
# 0               acts     40
# 1          acusacoes      0
# 2            adendas      0
# 3        aforamentos      0
# 4    alembic_version      1
# 5         aregisters      0
# 6         attributes  15452
# 7             blinks      0
# 8             cartas      0
# 9              casos      0
# 10  class_attributes     63
# 11           classes     13
# 12          entities  18609
# 13        escrituras      0
# 14           eventos      0
# 15       geoentities    215
# 16             goods      0
# 17        kleiofiles      5
# 18             links      4
# 19           objects      0
# 20           persons   1100
# 21         relations   1782
# 22         rentities      2
# 23      rgeoentities      0
# 24          robjects      0
# 25          rpersons      0
# 26           sources      5
# 27            syslog      0
# 28            syspar      0

# %% [markdown]
# ## Dealing with kleio files

# %% [markdown]
# ### List of running Kleio Servers

# %%
from timelink.kleio.kleio_server import list_kleio_server_containers


for (name,home,port,token,cont) in list_kleio_server_containers():
    labels = cont.labels
    build = labels.get("BUILD", "")
    version = labels.get("VERSION", "")
    build_date = labels.get("BUILD_DATE", "")
    print(f"Kleio server: {name:20}  {port} {home} {token} v{version}.{build} {build_date}")
# Out:
# Kleio server: exciting_noyce        8089 /Users/jrc/develop/timelink-py/tests/timelink-home/projects/tutorial 4ngzG9IHHeqd7EAHFhVx7i06howNP2e7 v12.7.579 2025-01-29 17:45:15
# Kleio server: compassionate_ellis   8093 /Users/jrc/develop/timelink-py/tests/timelink-home Z38HoRV7IC8tZiykWosHgPs1VOqEeO0e v12.7.579 2025-01-29 17:45:15
# Kleio server: tender_noether        8091 /Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project J26sSjctZZHj9Y2e9Cwwni1HUUewVRya v12.7.579 2025-01-29 17:45:15
# Kleio server: nostalgic_hawking     8092 /Users/jrc/mhk-home/sources/demo_sources OBsky2ATFqPpRCDIxowtTtkQfNOcf9nq v12.7.579 2025-01-29 17:45:15
# Kleio server: awesome_joliot        8088 /Users/jrc/develop/timelink-py/tests/timelink-home/projects/web-tests lbK1eg2jFT6OLfFWf6Ha6V2moxSKwXXU v12.7.579 2025-01-29 17:45:15
# Kleio server: awesome_ramanujan     8090 /Users/jrc/develop/timelink-py/tests/timelink-home/projects/test-project/sources/reference_sources/rentities 2rbmVn1P8MtSZ3XEYDdQsL5psNpZMfu1 v12.7.579 2025-01-29 17:45:15

# %% [markdown]
# ### List Kleio files available

# %%
kleio_files = tlnb.get_kleio_files()
kleio_files.head()
# Out:
#                                       path                         name  \
# 0                   sources/auc-alunos.cli               auc-alunos.cli
# 1                        sources/b1685.cli                    b1685.cli
# 2                   sources/dehergne-a.cli               dehergne-a.cli
# 3      sources/dehergne-locations-1644.cli  dehergne-locations-1644.cli
# 4  sources/real-entities/real-entities.cli            real-entities.cli
#
#                           modified status                translated  errors  \
# 0 2025-01-10 08:09:08.127463+00:00      V 2025-01-10 08:09:00+00:00       0
# 1 2025-01-10 07:07:03.744927+00:00      W 2025-01-10 07:07:00+00:00       0
# 2 2025-01-10 07:07:07.206591+00:00      V 2025-01-10 07:07:00+00:00       0
# 3 2025-01-10 07:07:05.549587+00:00      V 2025-01-10 07:07:00+00:00       0
# 4 2025-01-10 07:07:05.796856+00:00      V 2025-01-10 07:07:00+00:00       0
#
#    warnings import_status  import_errors  import_warnings  \
# 0         0             I              0                0
# 1         1             I              0                0
# 2         0             E              3                0
# 3         0             I              0                0
# 4         0             I              0                0
#
#                                     import_error_rpt import_warning_rpt  \
# 0                                          No errors        No warnings
# 1                                          No errors        No warnings
# 2  ERROR: dehergne-a.cli processing same_as relat...        No warnings
# 3                                          No errors        No warnings
# 4                                          No errors        No warnings
#
#                     imported  \
# 0 2025-01-10 08:25:44.062796
# 1 2025-01-10 07:40:09.603337
# 2 2025-01-10 07:39:25.763429
# 3 2025-01-10 07:39:42.862503
# 4 2025-01-10 07:39:53.794528
#
#                                              rpt_url  \
# 0               /rest/reports/sources/auc-alunos.rpt
# 1                    /rest/reports/sources/b1685.rpt
# 2               /rest/reports/sources/dehergne-a.rpt
# 3  /rest/reports/sources/dehergne-locations-1644.rpt
# 4  /rest/reports/sources/real-entities/real-entit...
#
#                                              xml_url
# 0               /rest/exports/sources/auc-alunos.xml
# 1                    /rest/exports/sources/b1685.xml
# 2               /rest/exports/sources/dehergne-a.xml
# 3  /rest/exports/sources/dehergne-locations-1644.xml
# 4  /rest/exports/sources/real-entities/real-entit...

# %% [markdown]
# Show only translation and import status

# %%
kleio_files[["name","status","import_status"]]
# Out:
#                           name status import_status
# 0               auc-alunos.cli      V             I
# 1                    b1685.cli      W             I
# 2               dehergne-a.cli      V             E
# 3  dehergne-locations-1644.cli      V             I
# 4            real-entities.cli      V             I

# %% [markdown]
# Show translation and import errors

# %%
kleio_files[["name","errors","warnings","import_errors","import_warnings"]]
# Out:
#                           name  errors  warnings  import_errors  \
# 0               auc-alunos.cli       0         0              0
# 1                    b1685.cli       0         1              0
# 2               dehergne-a.cli       0         0              3
# 3  dehergne-locations-1644.cli       0         0              0
# 4            real-entities.cli       0         0              0
#
#    import_warnings
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# ### Translation and Import reports

# %% [markdown]
# Translation reports.
#
# Pass a dataframe with Kleio files and a row number to get the translation report

# %%
rpt=tlnb.get_translation_report(kleio_files,rows=[1])
print(rpt)
# Out:
# KleioTranslator - server version 12.6 - build 577 2024-10-24 16:53:53
# 10-1-2025 7-7
#
# Processing data file b1685.cli
# -------------------------------------------
# Generic Act translation module with geoentities (XML).
#      Joaquim Ramos de Carvalho (joaquim@uc.pt)
# ** New document: kleio
# =========================
# kleio translation started
# =========================
# Structure: gacto2.str
# Prefix:
# Autorel:
# Translation count: 41
# Obs:
# ** Processing source fonte$baptismos 1685
#
# WARNING: b1685.cli line 3 * Warning: Filename should match source Id to avoid errors. File: b1685 Id: baptismos 1685.
# Near lines: 3
# Near lines: 4       bap$b1685.1/8/7/1685/?/manuel cordeiro
#
# 6: bap$b1685.1
# 22: bap$b1685.2
# 40: bap$b1685.3
# 59: bap$b1685.4
# 70: bap$b1685.5
# 79: bap$b1685.6
# 98: bap$b1685.7
# 113: bap$b1685.8
# 129: bap$b1685.9
# 144: bap$b1685.10
# 156: bap$b1685.11
# 171: bap$b1685.12
# 183: bap$b1685.13
# 201: bap$b1685.14
# 219: bap$b1685.15
# 235: bap$b1685.16
# 250: bap$b1685.17
# 266: bap$b1685.18
# 284: bap$b1685.19
# 301: bap$b1685.20
# 318: bap$b1685.21
# 334: bap$b1685.22
# 351: bap$b1685.23
# 368: bap$b1685.24
# 381: bap$b1685.25
# 396: bap$b1685.26
# 416: bap$b1685.27
# 431: bap$b1685.27b
# 452: bap$b1685.27c
# 466: bap$b1685.27d
# 483: bap$b1685.28
# 502: bap$b1685.29
# 519: bap$b1685.30
# 533: bap$b1685.31
# 552: bap$b1685.32
# 573: bap$b1685.33
# *** End of File
#
#
# Structure file: /usr/local/timelink/clio/src/gacto2.str
# Structure processing report: /usr/local/timelink/clio/src/gacto2.srpt
# Structure in JSON: /usr/local/timelink/clio/src/gacto2.str.json
#
# Kleio file: /kleio-home/kleio/b1685.cli
# Original file: /kleio-home/kleio/b1685.org
# Previous version: /kleio-home/kleio/b1685.old
# Temp file with ids: /kleio-home/kleio/b1685.ids
# ** - /kleio-home/kleio/b1685.cli-renamed to- /kleio-home/kleio/b1685.old
# 0  errors.
# 1  warnings.
# Translation finished.

# %% [markdown]
# Import report

# %%
rpt = tlnb.get_import_rpt(kleio_files,rows=[2,3])
print(rpt)
# Out:
# dehergne-a.cli
# ERROR: dehergne-a.cli processing same_as relation deh-luis-de-almeida-rela44: OccurrenceMissingError: Error, deh-luis-de-almeida-ref2 and deh-belchior-miguel-carneiro-leitao must exist in the database
#
# ERROR: dehergne-a.cli processing same_as relation deh-jean-joseph-marie-amiot-rela66: OccurrenceMissingError: Error, deh-jean-joseph-marie-amiot-ref1 and deh-jean-regis-lieou must exist in the database
#
# ERROR: dehergne-a.cli processing same_as relation deh-pierre-amys-rela76: OccurrenceMissingError: Error, deh-pierre-amys-ref1 and deh-alessandro-cicero must exist in the database
# No warnings
#
# dehergne-locations-1644.cli
# No errors
# No warnings

# %% [markdown]
# # Atualizar base de dados
#
# Atualiza traduções de fontes e importa quando tradução não tem erros.
#
# ---
#
# # Update database
#
# Updates source translations and imports into database sources with no errors.

# %%
import logging
logging.basicConfig(level=logging.INFO)

tlnb.update_from_sources()

# %% [markdown]
# ### Clear the translations

# %%
print("remove comment to clear translations")
# tlnb.kleio_server.translation_clean(path="",recurse="yes")
# Out:
# remove comment to clear translations

# %% [markdown]
# Show imported files status

# %%
imported_files_df = tlnb.get_import_status()
imported_files_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   path                5 non-null      object
#  1   name                5 non-null      object
#  2   size                5 non-null      int64
#  3   directory           5 non-null      object
#  4   modified            5 non-null      datetime64[ns, UTC]
#  5   modified_iso        5 non-null      datetime64[ns, UTC]
#  6   modified_string     5 non-null      object
#  7   qtime               5 non-null      datetime64[ns, UTC]
#  8   qtime_string        5 non-null      object
#  9   source_url          5 non-null      object
#  10  status              5 non-null      object
#  11  translated          5 non-null      datetime64[ns, UTC]
#  12  translated_string   5 non-null      object
#  13  errors              5 non-null      int64
#  14  warnings            5 non-null      int64
#  15  version             5 non-null      object
#  16  rpt_url             5 non-null      object
#  17  xml_url             5 non-null      object
#  18  import_status       5 non-null      object
#  19  import_errors       5 non-null      Int64
#  20  import_warnings     5 non-null      Int64
#  21  import_error_rpt    5 non-null      object
#  22  import_warning_rpt  5 non-null      object
#  23  imported            5 non-null      datetime64[ns]
#  24  imported_string     5 non-null      object
# dtypes: Int64(2), datetime64[ns, UTC](4), datetime64[ns](1), int64(3), object(15)
# memory usage: 1.1+ KB

# %% [markdown]
# Check the import status of the translated files
# ```python
#     I = "I" # imported
#     E = "E" # imported with error
#     W = "W" # imported with warnings no errors
#     N = "N" # not imported
#     U = "U" # translation updated need to reimport
#
# ```

# %%
imported_files_df[["import_status","import_errors","import_warnings","name","imported","path"]].sort_values("name")
# Out:
#   import_status  import_errors  import_warnings                         name  \
# 0             I              0                0               auc-alunos.cli
# 1             I              0                0                    b1685.cli
# 2             E              3                0               dehergne-a.cli
# 3             I              0                0  dehergne-locations-1644.cli
# 4             I              0                0            real-entities.cli
#
#                     imported                                     path
# 0 2025-01-10 08:25:44.062796                   sources/auc-alunos.cli
# 1 2025-01-10 07:40:09.603337                        sources/b1685.cli
# 2 2025-01-10 07:39:25.763429                   sources/dehergne-a.cli
# 3 2025-01-10 07:39:42.862503      sources/dehergne-locations-1644.cli
# 4 2025-01-10 07:39:53.794528  sources/real-entities/real-entities.cli

# %% [markdown]
# ## Todo

# %% [markdown]
# This as data frame in a single function
# * TimelinkNotebook.translate([files_df,rows=List[int],status="T"])
# * TimelinkNotebook.import(files_df, rows=List[int])

# %% [markdown]
# # Explorar a base de dados
# ---
#
# # Exploring the database

# %% [markdown]
# ## Database status
#
# Number of rows of each table in the database

# %%
tlnb.table_row_count_df()
# Out:
#                table  count
# 0               acts     40
# 1    alembic_version      1
# 2         aregisters      0
# 3         attributes  15452
# 4             blinks      0
# 5   class_attributes     63
# 6            classes     13
# 7           entities  18609
# 8        geoentities    215
# 9              goods      0
# 10        kleiofiles      5
# 11             links      4
# 12           objects      0
# 13           persons   1100
# 14         relations   1782
# 15         rentities      2
# 16      rgeoentities      0
# 17          robjects      0
# 18          rpersons      0
# 19           sources      5
# 20            syslog      0
# 21            syspar      0

# %% [markdown]
# ## List of tables available

# %%
tlnb.db.table_names()
# Out:
# ['acts',
#  'alembic_version',
#  'aregisters',
#  'attributes',
#  'blinks',
#  'class_attributes',
#  'classes',
#  'entities',
#  'geoentities',
#  'goods',
#  'kleiofiles',
#  'links',
#  'objects',
#  'persons',
#  'relations',
#  'rentities',
#  'rgeoentities',
#  'robjects',
#  'rpersons',
#  'sources',
#  'syslog',
#  'syspar']

# %% [markdown]
# ## List of models available

# %%
tlnb.db.get_models_ids()
# Out:
# ['attribute',
#  'relation',
#  'act',
#  'source',
#  'aregister',
#  'person',
#  'good',
#  'object',
#  'geoentity',
#  'rgeoentity',
#  'robject',
#  'rperson',
#  'rentity',
#  'class',
#  'entity']

# %% [markdown]
# ### Get a model class by name
#
# The model class is used to build queries (see later receipts on queries)

# %%
person_model = tlnb.db.get_model("person")
print(person_model)
# Out:
# <class 'timelink.api.models.person.Person'>

# %% [markdown]
# ## Describe a table

# %%
tlnb.db.describe("persons",show=True)
print()
tlnb.db.describe("entities",show=True)
# Out:
# persons
# id                   persons              VARCHAR    {ForeignKey('entities.id')}
# name                 persons              VARCHAR
# sex                  persons              VARCHAR(1)
# obs                  persons              VARCHAR
#
# entities
# id                   entities             VARCHAR
# class                entities             VARCHAR
# inside               entities             VARCHAR    {ForeignKey('entities.id')}
# the_source           entities             VARCHAR
# the_order            entities             INTEGER
# the_level            entities             INTEGER
# the_line             entities             INTEGER
# groupname            entities             VARCHAR
# extra_info           entities             JSON
# updated              entities             DATETIME
# indexed              entities             DATETIME
# [Column('id', String(), table=<entities>, primary_key=True, nullable=False),
#  Column('class', String(), table=<entities>, nullable=False),
#  Column('inside', String(), ForeignKey('entities.id'), table=<entities>),
#  Column('the_source', String(), table=<entities>),
#  Column('the_order', Integer(), table=<entities>),
#  Column('the_level', Integer(), table=<entities>),
#  Column('the_line', Integer(), table=<entities>),
#  Column('groupname', String(), table=<entities>),
#  Column('extra_info', JSON(), table=<entities>),
#  Column('updated', DateTime(), table=<entities>, default=CallableColumnDefault(<function datetime.utcnow at 0xffffa9dbc820>)),
#  Column('indexed', DateTime(), table=<entities>)]

# %% [markdown]
# ### Describe a model
#
# A Model includes all the information in the table hierarchy.
#
# For instance, the model Person includes the information in the table "persons"
# but also the information in the table "entities" related to a specific person

# %%
person_model = tlnb.db.get_model("person")
tlnb.db.describe(person_model, show=True)
# Out:
# <class 'timelink.api.models.person.Person'>
# id                   entities             VARCHAR
# class                entities             VARCHAR
# inside               entities             VARCHAR    {ForeignKey('entities.id')}
# the_source           entities             VARCHAR
# the_order            entities             INTEGER
# the_level            entities             INTEGER
# the_line             entities             INTEGER
# groupname            entities             VARCHAR
# extra_info           entities             JSON
# updated              entities             DATETIME
# indexed              entities             DATETIME
# id                   persons              VARCHAR    {ForeignKey('entities.id')}
# name                 persons              VARCHAR
# sex                  persons              VARCHAR(1)
# obs                  persons              VARCHAR
# [Column('id', String(), table=<entities>, primary_key=True, nullable=False),
#  Column('class', String(), table=<entities>, nullable=False),
#  Column('inside', String(), ForeignKey('entities.id'), table=<entities>),
#  Column('the_source', String(), table=<entities>),
#  Column('the_order', Integer(), table=<entities>),
#  Column('the_level', Integer(), table=<entities>),
#  Column('the_line', Integer(), table=<entities>),
#  Column('groupname', String(), table=<entities>),
#  Column('extra_info', JSON(), table=<entities>),
#  Column('updated', DateTime(), table=<entities>, default=CallableColumnDefault(<function datetime.utcnow at 0xffffa9dbc820>)),
#  Column('indexed', DateTime(), table=<entities>),
#  Column('id', String(), ForeignKey('entities.id'), table=<persons>, primary_key=True, nullable=False),
#  Column('name', String(), table=<persons>),
#  Column('sex', String(length=1), table=<persons>),
#  Column('obs', String(), table=<persons>)]

# %% [markdown]
# It is also possibel to import directly the model from
# the Timelink package

# %%
from timelink.api.models import Person

tlnb.db.describe(Person,show=True)
# Out:
# <class 'timelink.api.models.person.Person'>
# id                   entities             VARCHAR
# class                entities             VARCHAR
# inside               entities             VARCHAR    {ForeignKey('entities.id')}
# the_source           entities             VARCHAR
# the_order            entities             INTEGER
# the_level            entities             INTEGER
# the_line             entities             INTEGER
# groupname            entities             VARCHAR
# extra_info           entities             JSON
# updated              entities             DATETIME
# indexed              entities             DATETIME
# id                   persons              VARCHAR    {ForeignKey('entities.id')}
# name                 persons              VARCHAR
# sex                  persons              VARCHAR(1)
# obs                  persons              VARCHAR
# [Column('id', String(), table=<entities>, primary_key=True, nullable=False),
#  Column('class', String(), table=<entities>, nullable=False),
#  Column('inside', String(), ForeignKey('entities.id'), table=<entities>),
#  Column('the_source', String(), table=<entities>),
#  Column('the_order', Integer(), table=<entities>),
#  Column('the_level', Integer(), table=<entities>),
#  Column('the_line', Integer(), table=<entities>),
#  Column('groupname', String(), table=<entities>),
#  Column('extra_info', JSON(), table=<entities>),
#  Column('updated', DateTime(), table=<entities>, default=CallableColumnDefault(<function datetime.utcnow at 0xffffa9dbc820>)),
#  Column('indexed', DateTime(), table=<entities>),
#  Column('id', String(), ForeignKey('entities.id'), table=<persons>, primary_key=True, nullable=False),
#  Column('name', String(), table=<persons>),
#  Column('sex', String(length=1), table=<persons>),
#  Column('obs', String(), table=<persons>)]

# %% [markdown]
# # Searching the database

# %% [markdown]
# ### Procurar pessoa
#
# ---
# ### Search for people

# %% [markdown]
# #### Search persons by name

# %%
from timelink.api.models import Person
from sqlalchemy import select

show_only=30

with tlnb.db.session() as session:
    stmt = select(Person).where(Person.name.like('%vasconcelos')).order_by('name')
    print(stmt)
    persons = session.execute(stmt).scalars().all()
    print()
    for person in persons[:show_only]:
        print(person.id, person.name,person.sex)
        print(person.to_kleio())
# Out:
# SELECT persons.id, entities.id AS id_1, entities.class, entities.inside, entities.the_source, entities.the_order, entities.the_level, entities.the_line, entities.groupname, entities.extra_info, entities.updated, entities.indexed, persons.name, persons.sex, persons.obs
# FROM entities JOIN persons ON entities.id = persons.id
# WHERE persons.name LIKE :name_1 ORDER BY persons.name
#
# b1685.6-per4 joao da costa de vasconcelos m
# pad$joao da costa de vasconcelos/m/id=b1685.6-per4
#   rel$function-in-act/pad/bap/b1685.6/1685-08-27/obs=line: 88
#   ls$residencia/soure/1685-08-27
# b1685.27b-per3 joao da costa de vasconcelos m
# pad$joao da costa de vasconcelos/m/id=b1685.27b-per3
#   rel$function-in-act/pad/bap/b1685.27b/1685-11-25/obs=line: 445
# b1685.29-per4 joao da costa de vasconcelos m
# pad$joao da costa de vasconcelos/m/id=b1685.29-per4
#   rel$function-in-act/pad/bap/b1685.29/1685-12-13/obs=line: 511

# %%
[person.id for person in persons]
# Out:
# ['b1685.6-per4', 'b1685.27b-per3', 'b1685.29-per4']

# %% [markdown]
# ### Search other Entities

# %% [markdown]
# #### get the Entity classes in the database

# %%
from sqlalchemy import select, func
from timelink.api.models import Entity

models = tlnb.db.get_models_ids()
models
# Out:
# ['attribute',
#  'relation',
#  'act',
#  'source',
#  'aregister',
#  'person',
#  'good',
#  'object',
#  'geoentity',
#  'rgeoentity',
#  'robject',
#  'rperson',
#  'rentity',
#  'class',
#  'entity']

# %% [markdown]
# #### Get columns of an entity type

# %%
table = tlnb.db.get_table("entity")
print(table.name)
list(table.columns)
# Out:
# entities
# [Column('id', String(), table=<entities>, primary_key=True, nullable=False),
#  Column('class', String(), table=<entities>, nullable=False),
#  Column('inside', String(), ForeignKey('entities.id'), table=<entities>),
#  Column('the_source', String(), table=<entities>),
#  Column('the_order', Integer(), table=<entities>),
#  Column('the_level', Integer(), table=<entities>),
#  Column('the_line', Integer(), table=<entities>),
#  Column('groupname', String(), table=<entities>),
#  Column('extra_info', JSON(), table=<entities>),
#  Column('updated', DateTime(), table=<entities>, default=CallableColumnDefault(<function datetime.utcnow at 0xffffa9dbc820>)),
#  Column('indexed', DateTime(), table=<entities>)]

# %% [markdown]
# #### Search any entity type

# %%
from timelink.api.models import Entity
from sqlalchemy import select, func

Geoentity = tlnb.db.get_model("geoentity")
tlnb.db.describe(Geoentity,show=True)
stmt = select(Geoentity).where(Geoentity.name.like('Hang%'))
print(stmt)
with tlnb.db.session() as session:

    result = session.execute(stmt).scalars().all()
    for row in result:
        print()
        print(row.the_type,row.name,row.id,row.obs)
        print(row.to_kleio())
# Out:
# <class 'timelink.api.models.geoentity.Geoentity'>
# id                   entities             VARCHAR
# class                entities             VARCHAR
# inside               entities             VARCHAR    {ForeignKey('entities.id')}
# the_source           entities             VARCHAR
# the_order            entities             INTEGER
# the_level            entities             INTEGER
# the_line             entities             INTEGER
# groupname            entities             VARCHAR
# extra_info           entities             JSON
# updated              entities             DATETIME
# indexed              entities             DATETIME
# id                   geoentities          VARCHAR    {ForeignKey('entities.id')}
# name                 geoentities          VARCHAR
# the_type             geoentities          VARCHAR(32)
# obs                  geoentities          VARCHAR
# SELECT geoentities.id, entities.id AS id_1, entities.class, entities.inside, entities.the_source, entities.the_order, entities.the_level, entities.the_line, entities.groupname, entities.extra_info, entities.updated, entities.indexed, geoentities.name, geoentities.the_type, geoentities.obs
# FROM entities JOIN geoentities ON entities.id = geoentities.id
# WHERE geoentities.name LIKE :name_1
#
# geo2 Hangchou deh-r1644-hangchou
# geo2$Hangchou#Hang-tcheou, hoje: Hangzhou, 杭州, @wikidata:Q4970/geo2
#   atr$activa/sim/1611
#   atr$residencia-missao/Jesuíta/1611
#   rel$function-in-act/geo2/geodesc/deh-chre-1644/1644/obs=line: 100
#   atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q4970"#Hang-tcheou, hoje: Hangzhou, 杭州, @wikidata:Q4970%Q4970/1644

# %% [markdown]
# ### Search Acts by date

# %%
from timelink.api.models import Act
from sqlalchemy import select, func

tlnb.db.describe(Act,show=True)

stmt = select(Act).where(Act.the_date > '16850800',
                         Act.the_date < '16850900')

print(stmt)
with tlnb.db.session() as session:

    result = session.execute(stmt).scalars().all()
    for row in result:
        print()
        print(row.groupname,row.the_date,row.loc,row.obs)
        print(row.to_kleio())
# Out:
# <class 'timelink.api.models.act.Act'>
# id                   entities             VARCHAR
# class                entities             VARCHAR
# inside               entities             VARCHAR    {ForeignKey('entities.id')}
# the_source           entities             VARCHAR
# the_order            entities             INTEGER
# the_level            entities             INTEGER
# the_line             entities             INTEGER
# groupname            entities             VARCHAR
# extra_info           entities             JSON
# updated              entities             DATETIME
# indexed              entities             DATETIME
# id                   acts                 VARCHAR    {ForeignKey('entities.id')}
# the_type             acts                 VARCHAR(32)
# the_date             acts                 VARCHAR
# loc                  acts                 VARCHAR
# ref                  acts                 VARCHAR
# obs                  acts                 VARCHAR
# SELECT acts.id, entities.id AS id_1, entities.class, entities.inside, entities.the_source, entities.the_order, entities.the_level, entities.the_line, entities.groupname, entities.extra_info, entities.updated, entities.indexed, acts.the_type, acts.the_date, acts.loc, acts.ref, acts.obs
# FROM entities JOIN acts ON entities.id = acts.id
# WHERE acts.the_date > :the_date_1 AND acts.the_date < :the_date_2
#
# bap 16850802 igreja de s. tiago
# bap$b1685.3/16850802/type=bap/ref=?/loc=igreja de s. tiago
#   n$ana/f/id=b1685.3-per1
#     <rel$parentesco/pai/antonio joao/b1685.3-per1-per2/1685-08-02
#     <rel$parentesco/mae/maria de oliveira/b1685.3-per1-per3/1685-08-02
#     rel$function-in-act/n/bap/b1685.3/1685-08-02/obs=line: 42
#     pai$antonio joao/m/id=b1685.3-per1-per2
#       rel$function-in-act/pai/bap/b1685.3/1685-08-02/obs=line: 43
#       rel$parentesco/pai/ana/b1685.3-per1-per2/1685-08-02
#       rel$parentesco/marido/maria de oliveira/b1685.3-per1-per2/1685-08-02
#       ls$residencia/montais/1685-08-02
#       ls$ec/c/1685-08-02
#     mae$maria de oliveira/f/id=b1685.3-per1-per3
#       <rel$parentesco/marido/antonio joao/b1685.3-per1-per2/1685-08-02
#       rel$function-in-act/mae/bap/b1685.3/1685-08-02/obs=line: 47
#       rel$parentesco/mae/ana/b1685.3-per1-per3/1685-08-02
#       ls$ec/c/1685-08-02
#     pad$domingos simoes/m/id=b1685.3-per4
#       rel$function-in-act/pad/bap/b1685.3/1685-08-02/obs=line: 48
#       ls$residencia/sobral/1685-08-02
#       ls$profissao/padre/1685-08-02
#     mad$ana velho/f/id=b1685.3-per5
#       <rel$parentesco/marido/nomes desconhecido/b1685.3-per6/1685-08-02
#       rel$function-in-act/mad/bap/b1685.3/1685-08-02/obs=line: 53
#       mrmad$nomes desconhecido/m/id=b1685.3-per6
#         rel$function-in-act/mrmad/bap/b1685.3/1685-08-02/obs=line: 54
#         rel$parentesco/marido/ana velho/b1685.3-per6/1685-08-02
#         ls$profissao/boticario/1685-08-02
#         ls$residencia/soure/1685-08-02
#
# bap 16850822 igreja de s. tiago sem madrinha
# bap$b1685.4/16850822/type=bap/ref=?/loc=igreja de s. tiago/obs=sem madrinha
#   n$mariana/f/id=b1685.4-per1
#     <rel$parentesco/pai/simao luis/b1685.4-per1-per2/1685-08-22
#     <rel$parentesco/mae/nome desconhecido/b1685.4-per1-per3/1685-08-22
#     rel$function-in-act/n/bap/b1685.4/1685-08-22/obs=line: 61
#     pai$simao luis/m/id=b1685.4-per1-per2
#       rel$function-in-act/pai/bap/b1685.4/1685-08-22/obs=line: 62
#       rel$parentesco/pai/mariana/b1685.4-per1-per2/1685-08-22
#       rel$parentesco/marido/nome desconhecido/b1685.4-per1-per2/1685-08-22
#       ls$residencia/corujeira/1685-08-22
#       ls$ec/c/1685-08-22
#     mae$nome desconhecido/f/id=b1685.4-per1-per3
#       <rel$parentesco/marido/simao luis/b1685.4-per1-per2/1685-08-22
#       rel$function-in-act/mae/bap/b1685.4/1685-08-22/obs=line: 66
#       rel$parentesco/mae/mariana/b1685.4-per1-per3/1685-08-22
#       ls$ec/c/1685-08-22
#     pad$manuel colaco de soares?/m/id=b1685.4-per4
#       rel$function-in-act/pad/bap/b1685.4/1685-08-22/obs=line: 68
#
# bap 16850825 igreja de s. tiago
# bap$b1685.5/16850825/type=bap/ref=?/loc=igreja de s. tiago
#   n$manuel/m/id=b1685.5-per1
#     <rel$parentesco/pai/manuel carvalho/b1685.5-per1-per2/1685-08-25
#     <rel$parentesco/mae/maria joao/b1685.5-per1-per3/1685-08-25
#     rel$function-in-act/n/bap/b1685.5/1685-08-25/obs=line: 72
#     pai$manuel carvalho/m/id=b1685.5-per1-per2
#       rel$function-in-act/pai/bap/b1685.5/1685-08-25/obs=line: 73
#       rel$parentesco/pai/manuel/b1685.5-per1-per2/1685-08-25
#       rel$parentesco/marido/maria joao/b1685.5-per1-per2/1685-08-25
#       ls$residencia/sobral/1685-08-25
#       ls$ec/c/1685-08-25
#     mae$maria joao/f/id=b1685.5-per1-per3
#       <rel$parentesco/marido/manuel carvalho/b1685.5-per1-per2/1685-08-25
#       rel$function-in-act/mae/bap/b1685.5/1685-08-25/obs=line: 77
#       rel$parentesco/mae/manuel/b1685.5-per1-per3/1685-08-25
#       ls$ec/c/1685-08-25
#
# bap 16850827 igreja de s. tiago
# bap$b1685.6/16850827/type=bap/ref=?/loc=igreja de s. tiago
#   n$manuel/m/id=b1685.6-per1
#     <rel$parentesco/pai/manuel nunes/b1685.6-per1-per2/1685-08-27
#     <rel$parentesco/mae/catarina francisca/b1685.6-per1-per3/1685-08-27
#     rel$function-in-act/n/bap/b1685.6/1685-08-27/obs=line: 81
#     pai$manuel nunes/m/id=b1685.6-per1-per2
#       rel$function-in-act/pai/bap/b1685.6/1685-08-27/obs=line: 82
#       rel$parentesco/pai/manuel/b1685.6-per1-per2/1685-08-27
#       rel$parentesco/marido/catarina francisca/b1685.6-per1-per2/1685-08-27
#       ls$alcunha/moco/1685-08-27
#       ls$residencia/casa velha/1685-08-27
#       ls$ec/c/1685-08-27
#     mae$catarina francisca/f/id=b1685.6-per1-per3
#       <rel$parentesco/marido/manuel nunes/b1685.6-per1-per2/1685-08-27
#       rel$function-in-act/mae/bap/b1685.6/1685-08-27/obs=line: 87
#       rel$parentesco/mae/manuel/b1685.6-per1-per3/1685-08-27
#       ls$ec/c/1685-08-27
#     pad$joao da costa de vasconcelos/m/id=b1685.6-per4
#       rel$function-in-act/pad/bap/b1685.6/1685-08-27/obs=line: 88
#       ls$residencia/soure/1685-08-27
#     mad$maria/f/id=b1685.6-per5
#       <rel$parentesco/pai/calvo/b1685.6-per6/1685-08-27
#       rel$function-in-act/mad/bap/b1685.6/1685-08-27/obs=line: 91
#       ls$ec/s/1685-08-27
#       pmad$calvo/m/id=b1685.6-per6
#         rel$function-in-act/pmad/bap/b1685.6/1685-08-27/obs=line: 94
#         rel$parentesco/pai/maria/b1685.6-per6/1685-08-27
#         ls$residencia/casa velha/1685-08-27
#
# bap 16850828 igreja de s. tiago
# bap$b1685.7/16850828/type=bap/ref=?/loc=igreja de s. tiago
#   n$joao/m/id=b1685.7-per1
#     <rel$parentesco/pai/joao rodrigues/b1685.7-per1-per2/1685-08-28
#     <rel$parentesco/mae/isabel joao/b1685.7-per1-per3/1685-08-28
#     rel$function-in-act/n/bap/b1685.7/1685-08-28/obs=line: 100
#     pai$joao rodrigues/m/id=b1685.7-per1-per2
#       rel$function-in-act/pai/bap/b1685.7/1685-08-28/obs=line: 101
#       rel$parentesco/pai/joao/b1685.7-per1-per2/1685-08-28
#       rel$parentesco/marido/isabel joao/b1685.7-per1-per2/1685-08-28
#       ls$residencia/simoes/1685-08-28
#       ls$ec/c/1685-08-28
#     mae$isabel joao/f/id=b1685.7-per1-per3
#       <rel$parentesco/marido/joao rodrigues/b1685.7-per1-per2/1685-08-28
#       rel$function-in-act/mae/bap/b1685.7/1685-08-28/obs=line: 105
#       rel$parentesco/mae/joao/b1685.7-per1-per3/1685-08-28
#       ls$ec/c/1685-08-28
#     pad$diogo domingues/m/id=b1685.7-per4
#       rel$function-in-act/pad/bap/b1685.7/1685-08-28/obs=line: 106
#       ls$residencia/simoes/1685-08-28
#     mad$brites goncalves/f/id=b1685.7-per5
#       rel$function-in-act/mad/bap/b1685.7/1685-08-28/obs=line: 109
#       ls$residencia/simoes/1685-08-28
#
# bap 16850830 igreja de s. tiago
# bap$b1685.8/16850830/type=bap/ref=?/loc=igreja de s. tiago
#   n$manuel/m/id=b1685.8-per1
#     <rel$parentesco/pai/manuel rodrigues/b1685.8-per1-per2/1685-08-30
#     <rel$parentesco/mae/maria esteves/b1685.8-per1-per3/1685-08-30
#     rel$function-in-act/n/bap/b1685.8/1685-08-30/obs=line: 115
#     pai$manuel rodrigues/m/id=b1685.8-per1-per2
#       rel$function-in-act/pai/bap/b1685.8/1685-08-30/obs=line: 116
#       rel$parentesco/pai/manuel/b1685.8-per1-per2/1685-08-30
#       rel$parentesco/marido/maria esteves/b1685.8-per1-per2/1685-08-30
#       ls$residencia/barril/1685-08-30
#       ls$ec/c/1685-08-30
#     mae$maria esteves/f/id=b1685.8-per1-per3
#       <rel$parentesco/marido/manuel rodrigues/b1685.8-per1-per2/1685-08-30
#       rel$function-in-act/mae/bap/b1685.8/1685-08-30/obs=line: 120
#       rel$parentesco/mae/manuel/b1685.8-per1-per3/1685-08-30
#       ls$ec/c/1685-08-30
#     pad$manuel cordeiro/m/id=b1685.8.4
#       <rel$parentesco/irma/? coelho/b1685.8-per4/1685-08-30
#       rel$function-in-act/pad/bap/b1685.8/1685-08-30/obs=line: 121
#       ls$titulo/licenciado/1685-08-30
#       ls$residencia/casais do espirito santo/1685-08-30
#     mad$? coelho/f/id=b1685.8-per4
#       rel$function-in-act/mad/bap/b1685.8/1685-08-30/obs=line: 125
#       rel$parentesco/irma/manuel cordeiro/b1685.8-per4/1685-08-30

# %% [markdown]
# ### Search relations

# %%
from timelink.api.models import Relation
from sqlalchemy import select

tlnb.db.describe(Relation,show=True)

stmt = select(Relation).where(Relation.destination=='b1685.8-per1')
print(stmt)
with tlnb.db.session() as session:

    result = session.execute(stmt).scalars().all()
    for row in result:
        print()
        print(row.origin,row.the_type, row.the_value,row.destination)
        print(row.to_kleio())
# Out:
# <class 'timelink.api.models.relation.Relation'>
# id                   entities             VARCHAR
# class                entities             VARCHAR
# inside               entities             VARCHAR    {ForeignKey('entities.id')}
# the_source           entities             VARCHAR
# the_order            entities             INTEGER
# the_level            entities             INTEGER
# the_line             entities             INTEGER
# groupname            entities             VARCHAR
# extra_info           entities             JSON
# updated              entities             DATETIME
# indexed              entities             DATETIME
# id                   relations            VARCHAR    {ForeignKey('entities.id')}
# origin               relations            VARCHAR    {ForeignKey('entities.id')}
# destination          relations            VARCHAR    {ForeignKey('entities.id')}
# the_type             relations            VARCHAR
# the_value            relations            VARCHAR
# the_date             relations            VARCHAR
# obs                  relations            VARCHAR
# SELECT relations.id, entities.id AS id_1, entities.class, entities.inside, entities.the_source, entities.the_order, entities.the_level, entities.the_line, entities.groupname, entities.extra_info, entities.updated, entities.indexed, relations.origin, relations.destination, relations.the_type, relations.the_value, relations.the_date, relations.obs
# FROM entities JOIN relations ON relations.id = entities.id
# WHERE relations.destination = :destination_1
#
# b1685.8-per1-per2 parentesco pai b1685.8-per1
# rel$parentesco/pai/manuel/b1685.8-per1-per2/1685-08-30
#
# b1685.8-per1-per3 parentesco mae b1685.8-per1
# rel$parentesco/mae/manuel/b1685.8-per1-per3/1685-08-30

# %% [markdown]
# #### Get person by id

# %% [markdown]
# Show a single person or entity in Kleio notation

# %%
p = tlnb.db.get_person(person.id)
print(p.to_kleio())
# Out:
# pad$joao da costa de vasconcelos/m/id=b1685.29-per4
#   rel$function-in-act/pad/bap/b1685.29/1685-12-13/obs=line: 511

# %% [markdown]
# ### Show other type of entities by id in Kleio

# %%
from timelink.api.models import Entity

with tlnb.db.session() as session:
    ent = tlnb.db.get_entity("deh-r1644-chekiang",session)
    print(ent.to_kleio())
# Out:
# geo1$Chekiang#Tche-kiang, hoje:Zhejiang, 浙江, @wikidata:Q16967/geo1
#   rel$function-in-act/geo1/geodesc/deh-chre-1644/1644/obs=line: 99
#   atr$geoentity:name@wikidata/"https://www.wikidata.org/wiki/Q16967"#Tche-kiang, hoje:Zhejiang, 浙江, @wikidata:Q16967%Q16967/1644

# %% [markdown]
# ###  Obter um dataframe a partir de atributos
#
# ---
#
#
# ###  Get a Dataframe from attributes

# %% [markdown]
# #### Exemplo: Faculdade, data de entrada e data de saída e grau dos naturais de Coimbra

# %%
from sqlalchemy import inspect

inspect(tlnb.db.engine).get_view_names()
# Out:
# ['eattributes', 'nattributes', 'nfunctions']

# %%
eview = tlnb.db.create_eattribute_view()
tlnb.db.describe(eview,show=True)
# Out:
# eattributes
# id                   eattributes          VARCHAR
# the_line             eattributes          INTEGER
# the_level            eattributes          INTEGER
# the_order            eattributes          INTEGER
# groupname            eattributes          VARCHAR
# updated              eattributes          DATETIME
# indexed              eattributes          DATETIME
# e_extra_info         eattributes          JSON
# entity               eattributes          VARCHAR    {ForeignKey('entities.id')}
# the_type             eattributes          VARCHAR
# the_value            eattributes          VARCHAR
# the_date             eattributes          VARCHAR
# aobs                 eattributes          VARCHAR
# a_extra_info         eattributes          JSON
# [Column('id', String(), table=<eattributes>, primary_key=True, nullable=False),
#  Column('the_line', Integer(), table=<eattributes>),
#  Column('the_level', Integer(), table=<eattributes>),
#  Column('the_order', Integer(), table=<eattributes>),
#  Column('groupname', String(), table=<eattributes>),
#  Column('updated', DateTime(), table=<eattributes>),
#  Column('indexed', DateTime(), table=<eattributes>),
#  Column('e_extra_info', JSON(), table=<eattributes>),
#  Column('entity', String(), ForeignKey('entities.id'), table=<eattributes>),
#  Column('the_type', String(), table=<eattributes>),
#  Column('the_value', String(), table=<eattributes>),
#  Column('the_date', String(), table=<eattributes>),
#  Column('aobs', String(), table=<eattributes>),
#  Column('a_extra_info', JSON(), table=<eattributes>)]

# %%
from timelink.pandas import entities_with_attribute


# Get list of people with with a certain value in a specific attribute
df = entities_with_attribute(
                    entity_type='person',
                    the_type='naturalidade',
                    the_value='soure',
                    show_elements=['name','sex'],
                    name_like='%',
                    more_attributes=['profissao'],
                    db=tlnb.db,
                    sql_echo=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 140554 to 140533
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     4 non-null      object
#  1   sex                      4 non-null      object
#  2   naturalidade.type        4 non-null      object
#  3   naturalidade             4 non-null      object
#  4   naturalidade.date        4 non-null      object
#  5   naturalidade.line        4 non-null      int64
#  6   naturalidade.level       4 non-null      int64
#  7   naturalidade.obs         4 non-null      object
#  8   naturalidade.extra_info  4 non-null      object
#  9   profissao                0 non-null      object
# dtypes: int64(2), object(8)
# memory usage: 352.0+ bytes

# %%
df.head(5)
# Out:
#                                              name sex residencia.type  \
# id
# b1685.27d-per1-per2             antonio francisco   m      residencia
# b1685.27d-r1                     antonio da rocha   m      residencia
# b1685.3-per6                   nomes desconhecido   m      residencia
# b1685.6-per4         joao da costa de vasconcelos   m      residencia
# b1685.10-per1-per2             matias de carvalho   m      residencia
#
#                     residencia residencia.date  residencia.line  \
# id
# b1685.27d-per1-per2      soure        16850430              469
# b1685.27d-r1             soure        16850430              474
# b1685.3-per6             soure        16850802               54
# b1685.6-per4             soure        16850827               88
# b1685.10-per1-per2       soure        16850912              147
#
#                      residencia.level residencia.obs residencia.extra_info  \
# id
# b1685.27d-per1-per2                 4                                   {}
# b1685.27d-r1                        4                                   {}
# b1685.3-per6                        5                                   {}
# b1685.6-per4                        4                                   {}
# b1685.10-per1-per2                  4                                   {}
#
#                      profissao profissao.date profissao.obs  \
# id
# b1685.27d-per1-per2        NaN            NaN           NaN
# b1685.27d-r1               NaN            NaN           NaN
# b1685.3-per6         boticario       16850802
# b1685.6-per4               NaN            NaN           NaN
# b1685.10-per1-per2         NaN            NaN           NaN
#
#                     profissao.extra_info
# id
# b1685.27d-per1-per2                  NaN
# b1685.27d-r1                         NaN
# b1685.3-per6                          {}
# b1685.6-per4                         NaN
# b1685.10-per1-per2                   NaN

# %% [markdown]
# #### obter attributos de outras entidades

# %%
from timelink.pandas import entities_with_attribute


# Get list of people with with a certain value in a specific attribute
df = entities_with_attribute(
                    entity_type='geoentity',
                    show_elements=['name'],
                    the_type='activa',
                    the_value='sim',
                    more_attributes=['residencia-missao'],
                    db=tlnb.db,
                    sql_echo=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, deh-r1644-lampacao to deh-r1644-yunnan
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          165 non-null    object
#  1   activa.type                   165 non-null    object
#  2   activa                        165 non-null    object
#  3   activa.date                   165 non-null    object
#  4   activa.line                   165 non-null    int64
#  5   activa.level                  165 non-null    int64
#  6   activa.obs                    165 non-null    object
#  7   activa.extra_info             165 non-null    object
#  8   activa.date.comment           26 non-null     object
#  9   activa.date.original          5 non-null      object
#  10  residencia-missao             38 non-null     object
#  11  residencia-missao.date        38 non-null     object
#  12  residencia-missao.obs         38 non-null     object
#  13  residencia-missao.extra_info  38 non-null     object
# dtypes: int64(2), object(12)
# memory usage: 19.3+ KB

# %%
df.head(30)
# Out:
#                                name activa activa.date activa.obs  \
# id
# deh-r1644-anhai               Anhai    sim        1634       None
# deh-r1644-bankao             Bankao    sim        1636       None
# deh-r1644-cantao             Cantão    sim        1555       None
# deh-r1644-cantao             Cantão    sim        1555       None
# deh-r1644-cantao             Cantão    sim        1555       None
# deh-r1644-chala               Chala    sim        1610       None
# deh-r1644-changchow-fou   Changchow    sim        1643       None
# deh-r1644-changshu         Changshu    sim        1623       None
# deh-r1644-chengting       Chengting    sim        1621       None
# deh-r1644-chinkiang       Chinkiang    sim        1611       None
# deh-r1644-chowchih         Chowchih    sim        1633       None
# deh-r1644-chuanchow       Chüanchow    sim        1625       None
# deh-r1644-chuanchow       Chüanchow    sim        1625       None
# deh-r1644-chuchow           Chüchow    sim    16130000       None
# deh-r1644-chuchow-tcheou    Chuchow    sim        1616       None
# deh-r1644-chuking           Chuking    sim        1642       None
# deh-r1644-chungan           Chungan    sim        1635       None
# deh-r1644-chungking       Chungking    sim        1642       None
# deh-r1644-chwansha         Chwansha    sim        1630       None
# deh-r1644-diongloh         Diongloh    sim        1637       None
# deh-r1644-fenghsien       Fenghsien    sim        1625       None
# deh-r1644-foochow           Foochow    sim        1617       None
# deh-r1644-fuan                 Fuan    sim    16440000       None
# deh-r1644-funing             Funing    sim        1638       None
# deh-r1644-fushan             Fushan    sim        1638       None
# deh-r1644-futsing           Futsing    sim        1631       None
# deh-r1644-fuyang             Fuyang    sim    16420000       None
# deh-r1644-hanchung         Hanchung    sim        1635       None
# deh-r1644-hangchou         Hangchou    sim    16110000       None
# deh-r1644-hiapoey           Hiapoey    sim        1634       None
#
#                          residencia-missao residencia-missao.date  \
# id
# deh-r1644-anhai                        NaN                    NaN
# deh-r1644-bankao                       NaN                    NaN
# deh-r1644-cantao               Dominicanos                   0000
# deh-r1644-cantao              Franciscanos                   0000
# deh-r1644-cantao                   Jesuíta                   1580
# deh-r1644-chala                        NaN                    NaN
# deh-r1644-changchow-fou                NaN                    NaN
# deh-r1644-changshu                 Jesuíta                   1635
# deh-r1644-chengting                    NaN                    NaN
# deh-r1644-chinkiang                    NaN                    NaN
# deh-r1644-chowchih                     NaN                    NaN
# deh-r1644-chuanchow            Dominicanos                   1632
# deh-r1644-chuanchow                Jesuíta               16440000
# deh-r1644-chuchow                      NaN                    NaN
# deh-r1644-chuchow-tcheou               NaN                    NaN
# deh-r1644-chuking                      NaN                    NaN
# deh-r1644-chungan                      NaN                    NaN
# deh-r1644-chungking                    NaN                    NaN
# deh-r1644-chwansha                     NaN                    NaN
# deh-r1644-diongloh                     NaN                    NaN
# deh-r1644-fenghsien                    NaN                    NaN
# deh-r1644-foochow                  Jesuíta               16440000
# deh-r1644-fuan                 Dominicanos                   1632
# deh-r1644-funing               Dominicanos                   1638
# deh-r1644-fushan                       NaN                    NaN
# deh-r1644-futsing                      NaN                    NaN
# deh-r1644-fuyang                       NaN                    NaN
# deh-r1644-hanchung                 Jesuíta                   1644
# deh-r1644-hangchou                 Jesuíta               16110000
# deh-r1644-hiapoey                      NaN                    NaN
#
#                                                 residencia-missao.obs
# id
# deh-r1644-anhai                                                   NaN
# deh-r1644-bankao                                                  NaN
# deh-r1644-cantao                                                 None
# deh-r1644-cantao                                                 None
# deh-r1644-cantao                                                 None
# deh-r1644-chala                                                   NaN
# deh-r1644-changchow-fou                                           NaN
# deh-r1644-changshu        R 1635 «Cham Xo», cf AHSI 28 (1951) 311-312
# deh-r1644-chengting                                               NaN
# deh-r1644-chinkiang                                               NaN
# deh-r1644-chowchih                                                NaN
# deh-r1644-chuanchow                                              None
# deh-r1644-chuanchow                                              None
# deh-r1644-chuchow                                                 NaN
# deh-r1644-chuchow-tcheou                                          NaN
# deh-r1644-chuking                                                 NaN
# deh-r1644-chungan                                                 NaN
# deh-r1644-chungking                                               NaN
# deh-r1644-chwansha                                                NaN
# deh-r1644-diongloh                                                NaN
# deh-r1644-fenghsien                                               NaN
# deh-r1644-foochow                                                None
# deh-r1644-fuan                                                   None
# deh-r1644-funing                                                 None
# deh-r1644-fushan                                                  NaN
# deh-r1644-futsing                                                 NaN
# deh-r1644-fuyang                                                  NaN
# deh-r1644-hanchung                                               None
# deh-r1644-hangchou                                               None
# deh-r1644-hiapoey                                                 NaN

# %% [markdown]
# ###  Remover colunas sem valores
#
# ---
#
#
#
# ###  Remove empty columns

# %%
df.dropna(how='all', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, deh-r1644-anhai to deh-r1644-yunnan
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    165 non-null    object
#  1   activa                  165 non-null    object
#  2   activa.date             165 non-null    object
#  3   activa.obs              4 non-null      object
#  4   residencia-missao       38 non-null     object
#  5   residencia-missao.date  38 non-null     object
#  6   residencia-missao.obs   4 non-null      object
# dtypes: object(7)
# memory usage: 10.3+ KB

# %%
df.head(5)
# Out:
#                     name activa activa.date activa.obs residencia-missao  \
# id
# deh-r1644-anhai    Anhai    sim        1634       None               NaN
# deh-r1644-bankao  Bankao    sim        1636       None               NaN
# deh-r1644-cantao  Cantão    sim        1555       None           Jesuíta
# deh-r1644-cantao  Cantão    sim        1555       None      Franciscanos
# deh-r1644-cantao  Cantão    sim        1555       None       Dominicanos
#
#                  residencia-missao.date residencia-missao.obs
# id
# deh-r1644-anhai                     NaN                   NaN
# deh-r1644-bankao                    NaN                   NaN
# deh-r1644-cantao                   1580                  None
# deh-r1644-cantao                   0000                  None
# deh-r1644-cantao                   0000                  None

# %% [markdown]
# ## Contagens
#
# ---
#
# ## Counting

# %% [markdown]
# ###  Contagem de atributos a partir de uma tabela em memória
#
# ---
#
# ###  Count attributes from an existing dataframe

# %%
# create a column with the index values which are the id numbers
# Get list of people with with a certain value in a specific attribute
from timelink.pandas import entities_with_attribute
import pandas as pd

df = entities_with_attribute(
                    entity_type='person',
                    the_type='naturalidade',
                    the_value='Coimbra',
                    show_elements=['name','sex'],
                    more_attributes=['faculdade','uc.entrada','uc.saida'],
                    db=tlnb.db,
                    sql_echo=False)
df.info()
df['id'] = df.index.values

col = 'faculdade' # subotal by this column

# Use pandas groupby and specify unique value count for id
df_totals = df.groupby(col).agg({'id':'nunique',
                                                  'uc.entrada':'min',
                                                  'uc.saida':'max'})

df_totals.sort_values('id',ascending= False).head(30)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, 140349 to 140367
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     14 non-null     object
#  1   sex                      14 non-null     object
#  2   naturalidade.type        14 non-null     object
#  3   naturalidade             14 non-null     object
#  4   naturalidade.date        14 non-null     object
#  5   naturalidade.line        14 non-null     int64
#  6   naturalidade.level       14 non-null     int64
#  7   naturalidade.obs         14 non-null     object
#  8   naturalidade.extra_info  14 non-null     object
#  9   faculdade                14 non-null     object
#  10  faculdade.date           14 non-null     object
#  11  faculdade.obs            14 non-null     object
#  12  faculdade.extra_info     14 non-null     object
#  13  uc.entrada               14 non-null     object
#  14  uc.entrada.date          14 non-null     object
#  15  uc.entrada.obs           14 non-null     object
#  16  uc.entrada.extra_info    14 non-null     object
#  17  uc.saida                 14 non-null     object
#  18  uc.saida.date            14 non-null     object
#  19  uc.saida.obs             14 non-null     object
#  20  uc.saida.extra_info      14 non-null     object
# dtypes: int64(2), object(19)
# memory usage: 2.9+ KB
#             id  uc.entrada    uc.saida
# faculdade
# Cânones      7  0000-00-00  1767-07-27
# Medicina     5  1670-10-01  1823-10-20
# Direito      1  1748-10-19  1748-10-19
# Matemática   1  1868-10-02  1872-10-03

# %% [markdown]
# ### Contagens na base de dados
#
# Quando o atributo tem muitos valores e não é necessário
# ter todas as pessoas em memória: contagem feita na base de dados
#
# ---
#
# ### Counting directly in the database
# When there are many values and it is not
# necessary to have all the people in memory:
# count directly in the database.

# %%
from timelink.pandas import attribute_values

df_totals = attribute_values('grau',db=tlnb.db)

# %%
df_totals.head(10)
# Out:
#                      count    date_min    date_max
# value
# Bacharel               170  1554-07-19  1912-08-03
# Formatura              153  1574-07-24  1905-06-19
# Licenciado              33  1574-06-03  1886-02-27
# Bacharel em Artes       25  1574-03-14  1766-07-19
# Doutor                  11  1560-12-22  1887-11-27
# Licenciado em Artes      5  1574-05-15  1738-06-17
# Mestre                   2  1710-10-05  1768-10-23

# %% [markdown]
# #### Filtrar por datas
# ---
#
# #### Filter by dates

# %%
df_totals = attribute_values('grau',dates_between=('1772','1919'),db=tlnb.db)

# %%
df_totals.head(10)
# Out:
#             count    date_min    date_max
# value
# Bacharel       53  1775-06-10  1912-08-03
# Formatura      42  1776-05-11  1905-06-19
# Licenciado      4  1800-07-26  1886-02-27
# Doutor          3  1800-07-31  1887-11-27

# %% [markdown]
# ## Visualizar entidades
#
# ---
#
# ## View entities

# %% [markdown]
# ### Atributos de uma entidade numa tabela, uma linha por attributo
#
# ---
#
# ### Entitiy attributes in a dataframe, one line per attribute

# %% [markdown]
# #### A specifc entity
#
# Use `filter_by` to filter a list of entites

# %%
# Get list of people with with a certain value in a specific attribute
from timelink.pandas import entities_with_attribute

df = entities_with_attribute(
                    entity_type='person',
                    the_type='uc.entrada',  # we need a base attribute
                    show_elements=['name','sex'],
                    more_attributes=['instituta','matricula.ano'],
                    filter_by=['140349'],
                    db=tlnb.db,
                    sql_echo=False)
df.sort_values('matricula.ano.date')
# Out:
#                     name sex  uc.entrada uc.entrada.date uc.entrada.obs  \
# id
# 140349  António de Aboim   m  1566-12-20      1566-12-20           None
# 140349  António de Aboim   m  1566-12-20      1566-12-20           None
# 140349  António de Aboim   m  1566-12-20      1566-12-20           None
#
#        instituta matricula.ano matricula.ano.date matricula.ano.obs
# id
# 140349      None  Cânones.1571         1571-07-20        20.07.1571
# 140349      None  Cânones.1573         1573-10-07        07.10.1573
# 140349      None  Cânones.1574         1574-07-24        24.07.1574

# %%
from timelink.pandas import entities_with_attribute

neighbors = entities_with_attribute(
                                entity_type="person",
                                show_elements=["groupname","name","sex"],
                                the_type='residencia',
                                column_name="residencia",
                                the_value="soure",
                                more_attributes=['profissao'],
                                db=tlnb.db)
neighbors.head(10)
# Out:
#                     groupname                          name sex residencia  \
# id
# b1685.27d-per1-per2       pai             antonio francisco   m      soure
# b1685.27d-r1              pad              antonio da rocha   m      soure
# b1685.3-per6            mrmad            nomes desconhecido   m      soure
# b1685.6-per4              pad  joao da costa de vasconcelos   m      soure
# b1685.10-per1-per2        pai            matias de carvalho   m      soure
# b1685.14-per4             pad       manuel duarte de morais   m      soure
# b1685.14-per5             mad      maria rosado de carvalho   f      soure
# b1685.21-per6           mrmad              manuel de tavora   m      soure
# b1685.27c-per1-per2       pai              manuel rodrigues   m      soure
# b1685.29-per6            pmad          paulo ribeiro cabral   m      soure
#
#                     residencia.date residencia.obs  profissao profissao.date  \
# id
# b1685.27d-per1-per2        16850430           None        NaN            NaN
# b1685.27d-r1               16850430           None        NaN            NaN
# b1685.3-per6               16850802           None  boticario       16850802
# b1685.6-per4               16850827           None        NaN            NaN
# b1685.10-per1-per2         16850912           None        NaN            NaN
# b1685.14-per4              16850923           None      padre       16850923
# b1685.14-per5              16850923           None        NaN            NaN
# b1685.21-per6              16851104           None        NaN            NaN
# b1685.27c-per1-per2        16851125           None        NaN            NaN
# b1685.29-per6              16851213           None        NaN            NaN
#
#                     profissao.obs
# id
# b1685.27d-per1-per2           NaN
# b1685.27d-r1                  NaN
# b1685.3-per6                 None
# b1685.6-per4                  NaN
# b1685.10-per1-per2            NaN
# b1685.14-per4                None
# b1685.14-per5                 NaN
# b1685.21-per6                 NaN
# b1685.27c-per1-per2           NaN
# b1685.29-per6                 NaN

# %% [markdown]
# ### Visualizar um grupo de entidades
#
# ---
#
# #### Show the attributes of a group of entites

# %%
from timelink.api.models import Person
from sqlalchemy import select

select(Person).selected_columns.keys()
# Out:
# ['id',
#  'id_1',
#  'class',
#  'inside',
#  'the_order',
#  'the_level',
#  'the_line',
#  'groupname',
#  'updated',
#  'indexed',
#  'name',
#  'sex',
#  'obs']

# %%
from timelink.pandas.entities_with_attribute import entities_with_attribute
from timelink.pandas.group_attributes import group_attributes

# Get list of people with with a certain value in a specific attribute
colleagues_df = entities_with_attribute(entity_type='person',
                        the_type='uc.entrada.ano',
                        the_value='1750',db=tlnb.db)

colleagues = colleagues_df.index.values
print(colleagues)

# show their attributes
colleagues_cv = group_attributes(colleagues,
    entity_type='person',
    show_elements=['name'],
    include_attributes=['instituta','matricula','faculdade','grau','exame'],
    exclude_attributes=['data-do-registo'],
    sql_echo=True,
    db=tlnb.db)

colleagues_cv.sort_values(['the_date','the_type','the_value'])
# Out:
# ['140387' '140442' '140449' '140488' '140568' '140652' '140461' '140477'
#  '140589']
# SELECT persons.id, persons.name, attributes.the_type, attributes.the_value, attributes.the_date, attributes.obs AS attr_obs
# FROM entities JOIN persons ON entities.id = persons.id LEFT OUTER JOIN attributes ON attributes.entity = persons.id
# WHERE persons.id IN (__[POSTCOMPILE_id_1]) AND attributes.the_type IN (__[POSTCOMPILE_the_type_1]) AND (attributes.the_type NOT IN (__[POSTCOMPILE_the_type_2]))
#                                             name   the_type   the_value  \
# id
# 140387  António Lobo da Costa Borges e Abranches  faculdade     Cânones
# 140449                 Luís António de Abranches  faculdade     Cânones
# 140488                  José Ribeiro de Abrantes  faculdade     Cânones
# 140568                  António da Costa e Abreu  faculdade     Cânones
# 140652                          Caetano de Abreu  faculdade        Leis
# 140442                      José Nunes Abranches  faculdade    Medicina
# 140387  António Lobo da Costa Borges e Abranches  instituta  1750-10-01
# 140449                 Luís António de Abranches  instituta  1750-10-01
# 140488                  José Ribeiro de Abrantes  instituta  1750-10-01
# 140568                  António da Costa e Abreu  instituta  1750-10-01
# 140387  António Lobo da Costa Borges e Abranches  matricula     Cânones
# 140449                 Luís António de Abranches  matricula     Cânones
# 140449                 Luís António de Abranches  matricula     Cânones
# 140488                  José Ribeiro de Abrantes  matricula     Cânones
# 140652                          Caetano de Abreu  matricula        Leis
# 140442                      José Nunes Abranches  matricula    Medicina
# 140461     Manuel Inácio de Figueiredo Abranches  instituta  1750-10-27
# 140477                    Bartolomeu de Abrantes  instituta  1750-11-01
# 140589               António José Gomes de Abreu  faculdade     Cânones
# 140589               António José Gomes de Abreu  matricula     Cânones
# 140449                 Luís António de Abranches  matricula     Cânones
# 140488                  José Ribeiro de Abrantes  matricula     Cânones
# 140568                  António da Costa e Abreu  matricula     Cânones
# 140589               António José Gomes de Abreu  matricula     Cânones
# 140652                          Caetano de Abreu  matricula        Leis
# 140442                      José Nunes Abranches  matricula    Medicina
# 140387  António Lobo da Costa Borges e Abranches  matricula     Cânones
# 140568                  António da Costa e Abreu  matricula     Cânones
# 140589               António José Gomes de Abreu  matricula     Cânones
# 140652                          Caetano de Abreu  matricula        Leis
# 140442                      José Nunes Abranches  matricula    Medicina
# 140568                  António da Costa e Abreu  matricula     Cânones
# 140652                          Caetano de Abreu  matricula        Leis
# 140442                      José Nunes Abranches  matricula    Medicina
# 140442                      José Nunes Abranches       grau   Formatura
# 140568                  António da Costa e Abreu  matricula     Cânones
# 140652                          Caetano de Abreu  matricula        Leis
# 140442                      José Nunes Abranches  matricula    Medicina
# 140442                      José Nunes Abranches       grau    Bacharel
# 140568                  António da Costa e Abreu  matricula     Cânones
# 140568                  António da Costa e Abreu       grau    Bacharel
# 140652                          Caetano de Abreu       grau    Bacharel
# 140568                  António da Costa e Abreu       grau   Formatura
# 140652                          Caetano de Abreu       grau   Formatura
# 140488                  José Ribeiro de Abrantes  matricula     Cânones
# 140488                  José Ribeiro de Abrantes  matricula     Cânones
# 140589               António José Gomes de Abreu  matricula     Cânones
# 140589               António José Gomes de Abreu  matricula     Cânones
# 140589               António José Gomes de Abreu  matricula     Cânones
# 140589               António José Gomes de Abreu       grau    Bacharel
# 140589               António José Gomes de Abreu       grau   Formatura
# 140589               António José Gomes de Abreu  matricula     Cânones
#
#           the_date                                           attr_obs
# id
# 140387  1750-10-01                                               None
# 140449  1750-10-01                                               None
# 140488  1750-10-01                                               None
# 140568  1750-10-01                                               None
# 140652  1750-10-01                                               None
# 140442  1750-10-01                                               None
# 140387  1750-10-01                              01.10.1750 1750-10-01
# 140449  1750-10-01                              01.10.1750 1750-10-01
# 140488  1750-10-01                              01.10.1750 1750-10-01
# 140568  1750-10-01                              01.10.1750 1750-10-01
# 140387  1750-10-01                                         01.10.1750
# 140449  1750-10-01                                         01.10.1750
# 140449  1750-10-01                                         01.10.1750
# 140488  1750-10-01                                         01.10.1750
# 140652  1750-10-01                                         01.10.1750
# 140442  1750-10-01                                         01.10.1750
# 140461  1750-10-27                              27.10.1750 1750-10-27
# 140477  1750-11-01                              01.11.1750 1750-11-01
# 140589  1750-12-16                                               None
# 140589  1750-12-16                                         16.12.1750
# 140449  1751-10-01                                         01.10.1751
# 140488  1751-10-01                                         01.10.1751
# 140568  1751-10-01                                         01.10.1751
# 140589  1751-10-01                                         01.10.1751
# 140652  1751-10-01                                         01.10.1751
# 140442  1751-10-01                                         01.10.1751
# 140387  1751-12-14                                         14.12.1751
# 140568  1752-10-01                                         01.10.1752
# 140589  1752-10-01                                         01.10.1752
# 140652  1752-10-01                                         01.10.1752
# 140442  1752-10-01                                         01.10.1752
# 140568  1753-10-01                                         01.10.1753
# 140652  1753-10-01                                         01.10.1753
# 140442  1753-10-01                                         01.10.1753
# 140442  1754-03-21                                         21.03.1754
# 140568  1754-10-01                                         01.10.1754
# 140652  1754-10-01                                         01.10.1754
# 140442  1754-10-01                                         01.10.1754
# 140442  1754-12-07  Incorporação de Bacharel e Iniciação em Filoso...
# 140568  1755-10-01                                         01.10.1755
# 140568  1756-03-19                                         19.03.1756
# 140652  1756-03-31         Bacharel 31.03.1756, Atos n.º 90, fl. 82v.
# 140568  1756-05-05                      05.05.1756, Atos 90, fl. 60 v
# 140652  1757-01-31         Formatura 31.01.1757, Atos n.º 91, fl. 139
# 140488  1757-10-01                                         01.10.1757
# 140488  1758-10-01                                         01.10.1758
# 140589  1758-10-01                                         01.10.1758
# 140589  1759-10-01                                         01.10.1759
# 140589  1760-10-01                                         01.10.1760
# 140589  1762-05-25                  25.05.1762, Atos nº 98, fl. 57 v.
# 140589  1764-07-23                  23.07.1764, Atos nº 98, fl. 70 v.
# 140589  1764-10-01                                         01.10.1764

# %%
from timelink.notebooks import TimelinkNotebook

tlnb = TimelinkNotebook(db_type='postgres', db_name="tests")
tlnb.print_info()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /workspaces/timelink-py/.venv/lib/python3.10/site-packages/docker/api/client.py:268, in APIClient._raise_for_status(self, response)
#     267 try:
# --> 268     response.raise_for_status()
#     269 except requests.exceptions.HTTPError as e:
#
# File /workspaces/timelink-py/.venv/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: Internal Server Error for url: http+docker://localhost/v1.43/containers/d512c88d57256670292320f6094c0f98c78c243fd5519d5a069e13d10d1d900f/start
#
# The above exception was the direct cause of the following exception:
#
# APIError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 from timelink.notebooks import TimelinkNotebook
# ----> 3 tlnb = TimelinkNotebook(db_type='postgres', db_name="tests")
#       4 tlnb.print_info()
#
# File /workspaces/timelink-py/timelink/notebooks/timelink_notebook.py:112, in TimelinkNotebook.__init__(self, project_name, project_home, db_type, db_name, kleio_image, kleio_version, postgres_image, postgres_version, sqlite_dir, stop_duplicates, **extra_args)
#     109     if not is_valid_postgres_db_name(self.db_name):
#     110         raise Exception(f"Invalid database name: {self.db_name}")
# --> 112 self.db: TimelinkDatabase = TimelinkDatabase(
#     113     db_name=self.db_name,
#     114     db_type=self.db_type,
#     115     db_path=self.sqlite_dir,
#     116     kleio_home=self.project_home,
#     117     kleio_image=self.kleio_image,
#     118     kleio_version=self.kleio_version,
#     119     postgres_image=self.postgres_image,
#     120     postgres_version=self.postgres_version,
#     121     stop_duplicates=stop_duplicates,
#     122     **extra_args,
#     123 )
#     124 self.kleio_server = self.db.get_kleio_server()
#
# File /workspaces/timelink-py/timelink/api/database.py:410, in TimelinkDatabase.__init__(self, db_name, db_type, db_url, db_user, db_pwd, db_path, kleio_server, kleio_home, kleio_image, kleio_version, postgres_image, postgres_version, stop_duplicates, **connect_args)
#     408 else:
#     409     if kleio_home is not None:
# --> 410         self.kserver: KleioServer = KleioServer.start(
#     411             kleio_home=kleio_home,
#     412             kleio_image=kleio_image,
#     413             kleio_version=kleio_version,
#     414             stop_duplicates=stop_duplicates,
#     415         )
#
# File /workspaces/timelink-py/timelink/kleio/kleio_server.py:87, in KleioServer.start(kleio_image, kleio_version, kleio_home, kleio_token, consistency, port, update, reuse, stop_duplicates)
#      85 if not is_docker_running():
#      86     raise Exception("Docker is not running")
# ---> 87 container: docker.models.containers.Container = start_kleio_server(
#      88     image=kleio_image,
#      89     version=kleio_version,
#      90     kleio_home=kleio_home,
#      91     token=kleio_token,
#      92     consistency=consistency,
#      93     port=port,
#      94     update=update,
#      95     reuse=reuse,
#      96     stop_duplicates=stop_duplicates,
#      97 )
#      99 return KleioServer(container)
#
# File /workspaces/timelink-py/timelink/kleio/kleio_server.py:798, in start_kleio_server(image, version, kleio_home, token, consistency, port, update, reuse, stop_duplicates)
#     795     logging.info(f"Pulling {image}:{version}")
#     796     client.images.pull(f"{image}:{version}")
# --> 798 kleio_container = client.containers.run(
#     799     image=f"{image}:{version}",
#     800     detach=True,
#     801     ports={"8088/tcp": port},
#     802     environment={
#     803         "KLEIO_ADMIN_TOKEN": token,
#     804         # TODO ports, workers and DEBUG
#     805     },
#     806     mounts=[
#     807         docker.types.Mount(
#     808             target="/kleio-home",
#     809             source=kleio_home,
#     810             type="bind",
#     811             read_only=False,
#     812             consistency=consistency,
#     813         )
#     814     ],
#     815 )
#     816 kleio_container.start()  # redundant?
#     818 timeout = 15
#
# File /workspaces/timelink-py/.venv/lib/python3.10/site-packages/docker/models/containers.py:854, in ContainerCollection.run(self, image, command, stdout, stderr, remove, **kwargs)
#     850     self.client.images.pull(image, platform=platform)
#     851     container = self.create(image=image, command=command,
#     852                             detach=detach, **kwargs)
# --> 854 container.start()
#     856 if detach:
#     857     return container
#
# File /workspaces/timelink-py/.venv/lib/python3.10/site-packages/docker/models/containers.py:405, in Container.start(self, **kwargs)
#     396 def start(self, **kwargs):
#     397     """
#     398     Start this container. Similar to the ``docker start`` command, but
#     399     doesn't support attach options.
#    (...)
#     403             If the server returns an error.
#     404     """
# --> 405     return self.client.api.start(self.id, **kwargs)
#
# File /workspaces/timelink-py/.venv/lib/python3.10/site-packages/docker/utils/decorators.py:19, in check_resource.<locals>.decorator.<locals>.wrapped(self, resource_id, *args, **kwargs)
#      15 if not resource_id:
#      16     raise errors.NullResource(
#      17         'Resource ID was not provided'
#      18     )
# ---> 19 return f(self, resource_id, *args, **kwargs)
#
# File /workspaces/timelink-py/.venv/lib/python3.10/site-packages/docker/api/container.py:1126, in ContainerApiMixin.start(self, container, *args, **kwargs)
#    1124 url = self._url("/containers/{0}/start", container)
#    1125 res = self._post(url)
# -> 1126 self._raise_for_status(res)
#
# File /workspaces/timelink-py/.venv/lib/python3.10/site-packages/docker/api/client.py:270, in APIClient._raise_for_status(self, response)
#     268     response.raise_for_status()
#     269 except requests.exceptions.HTTPError as e:
# --> 270     raise create_api_error_from_http_exception(e) from e
#
# File /workspaces/timelink-py/.venv/lib/python3.10/site-packages/docker/errors.py:39, in create_api_error_from_http_exception(e)
#      37     else:
#      38         cls = NotFound
# ---> 39 raise cls(e, response=response, explanation=explanation) from e
#
# APIError: 500 Server Error for http+docker://localhost/v1.43/containers/d512c88d57256670292320f6094c0f98c78c243fd5519d5a069e13d10d1d900f/start: Internal Server Error ("driver failed programming external connectivity on endpoint focused_turing (e0441959c5511e48888395ccaa55d051e4faaa9e3ed6ef72c51bfe75ebd28109): Bind for 0.0.0.0:8088 failed: port is already allocated")

# %%
from timelink.pandas.group_attributes import display_group_attributes
import pandas as pd

display_group_attributes(
    colleagues,
    entity_type='person',
    header_elements=['name'],
    header_attributes=['uc.entrada'],
    include_attributes=['instituta','matricula','faculdade','grau','exame'],
    sort_attributes=['the_date','the_type','the_value'],
    cmap_name='Pastel1',
    db=tlnb.db)
# Out:
# <style type="text/css">
# #T_fbf92_row0_col0, #T_fbf92_row0_col1, #T_fbf92_row0_col2, #T_fbf92_row0_col3, #T_fbf92_row0_col4 {
#   background-color: #fbb4ae;
# }
# #T_fbf92_row1_col0, #T_fbf92_row1_col1, #T_fbf92_row1_col2, #T_fbf92_row1_col3, #T_fbf92_row1_col4 {
#   background-color: #b3cde3;
# }
# #T_fbf92_row2_col0, #T_fbf92_row2_col1, #T_fbf92_row2_col2, #T_fbf92_row2_col3, #T_fbf92_row2_col4 {
#   background-color: #ccebc5;
# }
# #T_fbf92_row3_col0, #T_fbf92_row3_col1, #T_fbf92_row3_col2, #T_fbf92_row3_col3, #T_fbf92_row3_col4 {
#   background-color: #decbe4;
# }
# #T_fbf92_row4_col0, #T_fbf92_row4_col1, #T_fbf92_row4_col2, #T_fbf92_row4_col3, #T_fbf92_row4_col4 {
#   background-color: #fed9a6;
# }
# #T_fbf92_row5_col0, #T_fbf92_row5_col1, #T_fbf92_row5_col2, #T_fbf92_row5_col3, #T_fbf92_row5_col4 {
#   background-color: #ffffcc;
# }
# #T_fbf92_row6_col0, #T_fbf92_row6_col1, #T_fbf92_row6_col2, #T_fbf92_row6_col3, #T_fbf92_row6_col4 {
#   background-color: #e5d8bd;
# }
# #T_fbf92_row7_col0, #T_fbf92_row7_col1, #T_fbf92_row7_col2, #T_fbf92_row7_col3, #T_fbf92_row7_col4 {
#   background-color: #fddaec;
# }
# #T_fbf92_row8_col0, #T_fbf92_row8_col1, #T_fbf92_row8_col2, #T_fbf92_row8_col3, #T_fbf92_row8_col4 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_fbf92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbf92_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_fbf92_level0_col1" class="col_heading level0 col1" >uc.entrada</th>
#       <th id="T_fbf92_level0_col2" class="col_heading level0 col2" >uc.entrada.date</th>
#       <th id="T_fbf92_level0_col3" class="col_heading level0 col3" >uc.entrada.obs</th>
#       <th id="T_fbf92_level0_col4" class="col_heading level0 col4" >id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbf92_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fbf92_row0_col0" class="data row0 col0" >António Lobo da Costa Borges e Abranches</td>
#       <td id="T_fbf92_row0_col1" class="data row0 col1" >1750-10-01</td>
#       <td id="T_fbf92_row0_col2" class="data row0 col2" >1750-10-01</td>
#       <td id="T_fbf92_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_fbf92_row0_col4" class="data row0 col4" >140387</td>
#     </tr>
#     <tr>
#       <th id="T_fbf92_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fbf92_row1_col0" class="data row1 col0" >José Nunes Abranches</td>
#       <td id="T_fbf92_row1_col1" class="data row1 col1" >1750-10-01</td>
#       <td id="T_fbf92_row1_col2" class="data row1 col2" >1750-10-01</td>
#       <td id="T_fbf92_row1_col3" class="data row1 col3" >None</td>
#       <td id="T_fbf92_row1_col4" class="data row1 col4" >140442</td>
#     </tr>
#     <tr>
#       <th id="T_fbf92_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fbf92_row2_col0" class="data row2 col0" >Luís António de Abranches</td>
#       <td id="T_fbf92_row2_col1" class="data row2 col1" >1750-10-01</td>
#       <td id="T_fbf92_row2_col2" class="data row2 col2" >1750-10-01</td>
#       <td id="T_fbf92_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_fbf92_row2_col4" class="data row2 col4" >140449</td>
#     </tr>
#     <tr>
#       <th id="T_fbf92_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fbf92_row3_col0" class="data row3 col0" >José Ribeiro de Abrantes</td>
#       <td id="T_fbf92_row3_col1" class="data row3 col1" >1750-10-01</td>
#       <td id="T_fbf92_row3_col2" class="data row3 col2" >1750-10-01</td>
#       <td id="T_fbf92_row3_col3" class="data row3 col3" >None</td>
#       <td id="T_fbf92_row3_col4" class="data row3 col4" >140488</td>
#     </tr>
#     <tr>
#       <th id="T_fbf92_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fbf92_row4_col0" class="data row4 col0" >António da Costa e Abreu</td>
#       <td id="T_fbf92_row4_col1" class="data row4 col1" >1750-10-01</td>
#       <td id="T_fbf92_row4_col2" class="data row4 col2" >1750-10-01</td>
#       <td id="T_fbf92_row4_col3" class="data row4 col3" >None</td>
#       <td id="T_fbf92_row4_col4" class="data row4 col4" >140568</td>
#     </tr>
#     <tr>
#       <th id="T_fbf92_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fbf92_row5_col0" class="data row5 col0" >Caetano de Abreu</td>
#       <td id="T_fbf92_row5_col1" class="data row5 col1" >1750-10-01</td>
#       <td id="T_fbf92_row5_col2" class="data row5 col2" >1750-10-01</td>
#       <td id="T_fbf92_row5_col3" class="data row5 col3" >None</td>
#       <td id="T_fbf92_row5_col4" class="data row5 col4" >140652</td>
#     </tr>
#     <tr>
#       <th id="T_fbf92_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fbf92_row6_col0" class="data row6 col0" >Manuel Inácio de Figueiredo Abranches</td>
#       <td id="T_fbf92_row6_col1" class="data row6 col1" >1750-10-27</td>
#       <td id="T_fbf92_row6_col2" class="data row6 col2" >1750-10-27</td>
#       <td id="T_fbf92_row6_col3" class="data row6 col3" >None</td>
#       <td id="T_fbf92_row6_col4" class="data row6 col4" >140461</td>
#     </tr>
#     <tr>
#       <th id="T_fbf92_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fbf92_row7_col0" class="data row7 col0" >Bartolomeu de Abrantes</td>
#       <td id="T_fbf92_row7_col1" class="data row7 col1" >1750-11-01</td>
#       <td id="T_fbf92_row7_col2" class="data row7 col2" >1750-11-01</td>
#       <td id="T_fbf92_row7_col3" class="data row7 col3" >None</td>
#       <td id="T_fbf92_row7_col4" class="data row7 col4" >140477</td>
#     </tr>
#     <tr>
#       <th id="T_fbf92_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fbf92_row8_col0" class="data row8 col0" >António José Gomes de Abreu</td>
#       <td id="T_fbf92_row8_col1" class="data row8 col1" >1750-12-16</td>
#       <td id="T_fbf92_row8_col2" class="data row8 col2" >1750-12-16</td>
#       <td id="T_fbf92_row8_col3" class="data row8 col3" >None</td>
#       <td id="T_fbf92_row8_col4" class="data row8 col4" >140589</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5b671_row0_col0, #T_5b671_row0_col1, #T_5b671_row0_col2, #T_5b671_row0_col3, #T_5b671_row0_col4, #T_5b671_row0_col5, #T_5b671_row6_col0, #T_5b671_row6_col1, #T_5b671_row6_col2, #T_5b671_row6_col3, #T_5b671_row6_col4, #T_5b671_row6_col5, #T_5b671_row10_col0, #T_5b671_row10_col1, #T_5b671_row10_col2, #T_5b671_row10_col3, #T_5b671_row10_col4, #T_5b671_row10_col5, #T_5b671_row26_col0, #T_5b671_row26_col1, #T_5b671_row26_col2, #T_5b671_row26_col3, #T_5b671_row26_col4, #T_5b671_row26_col5 {
#   background-color: #fbb4ae;
# }
# #T_5b671_row1_col0, #T_5b671_row1_col1, #T_5b671_row1_col2, #T_5b671_row1_col3, #T_5b671_row1_col4, #T_5b671_row1_col5, #T_5b671_row7_col0, #T_5b671_row7_col1, #T_5b671_row7_col2, #T_5b671_row7_col3, #T_5b671_row7_col4, #T_5b671_row7_col5, #T_5b671_row11_col0, #T_5b671_row11_col1, #T_5b671_row11_col2, #T_5b671_row11_col3, #T_5b671_row11_col4, #T_5b671_row11_col5, #T_5b671_row12_col0, #T_5b671_row12_col1, #T_5b671_row12_col2, #T_5b671_row12_col3, #T_5b671_row12_col4, #T_5b671_row12_col5, #T_5b671_row20_col0, #T_5b671_row20_col1, #T_5b671_row20_col2, #T_5b671_row20_col3, #T_5b671_row20_col4, #T_5b671_row20_col5 {
#   background-color: #b3cde3;
# }
# #T_5b671_row2_col0, #T_5b671_row2_col1, #T_5b671_row2_col2, #T_5b671_row2_col3, #T_5b671_row2_col4, #T_5b671_row2_col5, #T_5b671_row8_col0, #T_5b671_row8_col1, #T_5b671_row8_col2, #T_5b671_row8_col3, #T_5b671_row8_col4, #T_5b671_row8_col5, #T_5b671_row13_col0, #T_5b671_row13_col1, #T_5b671_row13_col2, #T_5b671_row13_col3, #T_5b671_row13_col4, #T_5b671_row13_col5, #T_5b671_row21_col0, #T_5b671_row21_col1, #T_5b671_row21_col2, #T_5b671_row21_col3, #T_5b671_row21_col4, #T_5b671_row21_col5, #T_5b671_row44_col0, #T_5b671_row44_col1, #T_5b671_row44_col2, #T_5b671_row44_col3, #T_5b671_row44_col4, #T_5b671_row44_col5, #T_5b671_row45_col0, #T_5b671_row45_col1, #T_5b671_row45_col2, #T_5b671_row45_col3, #T_5b671_row45_col4, #T_5b671_row45_col5 {
#   background-color: #ccebc5;
# }
# #T_5b671_row3_col0, #T_5b671_row3_col1, #T_5b671_row3_col2, #T_5b671_row3_col3, #T_5b671_row3_col4, #T_5b671_row3_col5, #T_5b671_row9_col0, #T_5b671_row9_col1, #T_5b671_row9_col2, #T_5b671_row9_col3, #T_5b671_row9_col4, #T_5b671_row9_col5, #T_5b671_row22_col0, #T_5b671_row22_col1, #T_5b671_row22_col2, #T_5b671_row22_col3, #T_5b671_row22_col4, #T_5b671_row22_col5, #T_5b671_row27_col0, #T_5b671_row27_col1, #T_5b671_row27_col2, #T_5b671_row27_col3, #T_5b671_row27_col4, #T_5b671_row27_col5, #T_5b671_row31_col0, #T_5b671_row31_col1, #T_5b671_row31_col2, #T_5b671_row31_col3, #T_5b671_row31_col4, #T_5b671_row31_col5, #T_5b671_row35_col0, #T_5b671_row35_col1, #T_5b671_row35_col2, #T_5b671_row35_col3, #T_5b671_row35_col4, #T_5b671_row35_col5, #T_5b671_row39_col0, #T_5b671_row39_col1, #T_5b671_row39_col2, #T_5b671_row39_col3, #T_5b671_row39_col4, #T_5b671_row39_col5, #T_5b671_row40_col0, #T_5b671_row40_col1, #T_5b671_row40_col2, #T_5b671_row40_col3, #T_5b671_row40_col4, #T_5b671_row40_col5, #T_5b671_row42_col0, #T_5b671_row42_col1, #T_5b671_row42_col2, #T_5b671_row42_col3, #T_5b671_row42_col4, #T_5b671_row42_col5 {
#   background-color: #decbe4;
# }
# #T_5b671_row4_col0, #T_5b671_row4_col1, #T_5b671_row4_col2, #T_5b671_row4_col3, #T_5b671_row4_col4, #T_5b671_row4_col5, #T_5b671_row14_col0, #T_5b671_row14_col1, #T_5b671_row14_col2, #T_5b671_row14_col3, #T_5b671_row14_col4, #T_5b671_row14_col5, #T_5b671_row24_col0, #T_5b671_row24_col1, #T_5b671_row24_col2, #T_5b671_row24_col3, #T_5b671_row24_col4, #T_5b671_row24_col5, #T_5b671_row29_col0, #T_5b671_row29_col1, #T_5b671_row29_col2, #T_5b671_row29_col3, #T_5b671_row29_col4, #T_5b671_row29_col5, #T_5b671_row32_col0, #T_5b671_row32_col1, #T_5b671_row32_col2, #T_5b671_row32_col3, #T_5b671_row32_col4, #T_5b671_row32_col5, #T_5b671_row36_col0, #T_5b671_row36_col1, #T_5b671_row36_col2, #T_5b671_row36_col3, #T_5b671_row36_col4, #T_5b671_row36_col5, #T_5b671_row41_col0, #T_5b671_row41_col1, #T_5b671_row41_col2, #T_5b671_row41_col3, #T_5b671_row41_col4, #T_5b671_row41_col5, #T_5b671_row43_col0, #T_5b671_row43_col1, #T_5b671_row43_col2, #T_5b671_row43_col3, #T_5b671_row43_col4, #T_5b671_row43_col5 {
#   background-color: #fed9a6;
# }
# #T_5b671_row5_col0, #T_5b671_row5_col1, #T_5b671_row5_col2, #T_5b671_row5_col3, #T_5b671_row5_col4, #T_5b671_row5_col5, #T_5b671_row15_col0, #T_5b671_row15_col1, #T_5b671_row15_col2, #T_5b671_row15_col3, #T_5b671_row15_col4, #T_5b671_row15_col5, #T_5b671_row25_col0, #T_5b671_row25_col1, #T_5b671_row25_col2, #T_5b671_row25_col3, #T_5b671_row25_col4, #T_5b671_row25_col5, #T_5b671_row30_col0, #T_5b671_row30_col1, #T_5b671_row30_col2, #T_5b671_row30_col3, #T_5b671_row30_col4, #T_5b671_row30_col5, #T_5b671_row33_col0, #T_5b671_row33_col1, #T_5b671_row33_col2, #T_5b671_row33_col3, #T_5b671_row33_col4, #T_5b671_row33_col5, #T_5b671_row34_col0, #T_5b671_row34_col1, #T_5b671_row34_col2, #T_5b671_row34_col3, #T_5b671_row34_col4, #T_5b671_row34_col5, #T_5b671_row37_col0, #T_5b671_row37_col1, #T_5b671_row37_col2, #T_5b671_row37_col3, #T_5b671_row37_col4, #T_5b671_row37_col5, #T_5b671_row38_col0, #T_5b671_row38_col1, #T_5b671_row38_col2, #T_5b671_row38_col3, #T_5b671_row38_col4, #T_5b671_row38_col5 {
#   background-color: #ffffcc;
# }
# #T_5b671_row16_col0, #T_5b671_row16_col1, #T_5b671_row16_col2, #T_5b671_row16_col3, #T_5b671_row16_col4, #T_5b671_row16_col5 {
#   background-color: #e5d8bd;
# }
# #T_5b671_row17_col0, #T_5b671_row17_col1, #T_5b671_row17_col2, #T_5b671_row17_col3, #T_5b671_row17_col4, #T_5b671_row17_col5 {
#   background-color: #fddaec;
# }
# #T_5b671_row18_col0, #T_5b671_row18_col1, #T_5b671_row18_col2, #T_5b671_row18_col3, #T_5b671_row18_col4, #T_5b671_row18_col5, #T_5b671_row19_col0, #T_5b671_row19_col1, #T_5b671_row19_col2, #T_5b671_row19_col3, #T_5b671_row19_col4, #T_5b671_row19_col5, #T_5b671_row23_col0, #T_5b671_row23_col1, #T_5b671_row23_col2, #T_5b671_row23_col3, #T_5b671_row23_col4, #T_5b671_row23_col5, #T_5b671_row28_col0, #T_5b671_row28_col1, #T_5b671_row28_col2, #T_5b671_row28_col3, #T_5b671_row28_col4, #T_5b671_row28_col5, #T_5b671_row46_col0, #T_5b671_row46_col1, #T_5b671_row46_col2, #T_5b671_row46_col3, #T_5b671_row46_col4, #T_5b671_row46_col5, #T_5b671_row47_col0, #T_5b671_row47_col1, #T_5b671_row47_col2, #T_5b671_row47_col3, #T_5b671_row47_col4, #T_5b671_row47_col5, #T_5b671_row48_col0, #T_5b671_row48_col1, #T_5b671_row48_col2, #T_5b671_row48_col3, #T_5b671_row48_col4, #T_5b671_row48_col5, #T_5b671_row49_col0, #T_5b671_row49_col1, #T_5b671_row49_col2, #T_5b671_row49_col3, #T_5b671_row49_col4, #T_5b671_row49_col5, #T_5b671_row50_col0, #T_5b671_row50_col1, #T_5b671_row50_col2, #T_5b671_row50_col3, #T_5b671_row50_col4, #T_5b671_row50_col5, #T_5b671_row51_col0, #T_5b671_row51_col1, #T_5b671_row51_col2, #T_5b671_row51_col3, #T_5b671_row51_col4, #T_5b671_row51_col5 {
#   background-color: #f2f2f2;
# }
# </style>
# <table id="T_5b671">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b671_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_5b671_level0_col1" class="col_heading level0 col1" >the_type</th>
#       <th id="T_5b671_level0_col2" class="col_heading level0 col2" >the_value</th>
#       <th id="T_5b671_level0_col3" class="col_heading level0 col3" >the_date</th>
#       <th id="T_5b671_level0_col4" class="col_heading level0 col4" >attr_obs</th>
#       <th id="T_5b671_level0_col5" class="col_heading level0 col5" >id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b671_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b671_row0_col0" class="data row0 col0" >António Lobo da Costa Borges e Abranches</td>
#       <td id="T_5b671_row0_col1" class="data row0 col1" >faculdade</td>
#       <td id="T_5b671_row0_col2" class="data row0 col2" >Cânones</td>
#       <td id="T_5b671_row0_col3" class="data row0 col3" >1750-10-01</td>
#       <td id="T_5b671_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_5b671_row0_col5" class="data row0 col5" >140387</td>
#     </tr>
#     <tr>
#       <th id="T_5b671_level0_row

# %% [markdown]
# #### Notação Kleio
#
# Ver [Kleio notation](README_kleio.md) [EN]
#
# ---
#
# #### Kleio notation
#
# See [Kleio notation](README_kleio.md)

# %% [markdown]
# #### Notação Kleio directamente da base de dados
#
# Ver [Kleio notation](README_kleio.md) [EN]
#
# ---
#
# #### Kleio notation directly from database
#
# See [Kleio notation](README_kleio.md)

# %%
from timelink.mhk.models.person import Person

with tlnb.db.session() as session:

    p: Person = session.query(Person).order_by(Person.id).first()
    k = p.to_kleio()
    print(p.to_kleio())
# Out:
# n$António Pinto Abadeço/m/id=140337/obs="""
#       """
#
#                   Id: 140337
#                   Código de referência: PT/AUC/ELU/UC-AUC/B/001-001/A/000001
#
#                   Nome        : António Pinto Abadeço
#                   Data inicial: 1705-10-01
#                   Data final  : 1710-10-01
#                   Filiação: António Pinto
#
#                   Naturalidade: Abrantes
#                   Faculdade: Cânones
#
#                   Matrícula(s): 01.10.1705
#                   01.10.1706
#                   01.01.1707
#                   01.10.1708
#                   01.10.1709
#                   01.10.1710
#                   Instituta:
#                   Bacharel: 28.06.1709
#                   Formatura:
#                   Licenciado:
#                   Doutor:
#
#                   Outras informações:
#               """
#   """
#   rel$function-in-act/n/António Pinto Abadeço/auc-alumni-A-140337-140771/20200211
#   atr$código-de-referência/""PT/AUC/ELU/UC-AUC/B/001-001/A/000001""/2021-05-17
#   atr$data-do-registo/2021-05-17/2021-05-17
#   atr$url/""https://pesquisa.auc.uc.pt/details?id=140337""/2021-05-17
#   ls$uc.entrada/1705-10-01/1705-10-01
#   ls$uc.saida/1710-10-01/1710-10-01
#   ls$uc.entrada.ano/1705/1705-10-01
#   ls$uc.saida.ano/1710/1710-10-01
#   ls$nome/António Pinto Abadeço/1705-10-01
#   ls$nome.primeiro/António/1705-10-01
#   ls$nome.apelido/Pinto Abadeço/1705-10-01
#   ls$nome.apelido/Abadeço/1705-10-01
#   ls$naturalidade/Abrantes/1705-10-01
#   ls$naturalidade.ano/Abrantes.1705/1705-10-01
#   ls$nome-geografico/Abrantes/1705-10-01
#   ls$nome-geografico.ano/Abrantes.1705/1705-10-01
#   ls$faculdade/Cânones/1705-10-01
#   ls$faculdade.ano/Cânones.1705/1705-10-01
#   ls$matricula/Cânones/1705-10-01/obs=01.10.1705
#   ls$matricula.ano/Cânones.1705/1705-10-01/obs=01.10.1705
#   ls$matricula/Cânones/1706-10-01/obs=01.10.1706
#   ls$matricula.ano/Cânones.1706/1706-10-01/obs=01.10.1706
#   ls$matricula/Cânones/1707-01-01/obs=01.01.1707
#   ls$matricula.ano/Cânones.1707/1707-01-01/obs=01.01.1707
#   ls$matricula/Cânones/1708-10-01/obs=01.10.1708
#   ls$matricula.ano/Cânones.1708/1708-10-01/obs=01.10.1708
#   ls$matricula/Cânones/1709-10-01/obs=01.10.1709
#   ls$matricula.ano/Cânones.1709/1709-10-01/obs=01.10.1709
#   ls$matricula/Cânones/1710-10-01/obs=01.10.1710
#   ls$matricula.ano/Cânones.1710/1710-10-01/obs=01.10.1710
#   ls$matricula/Cânones/1709-06-28/obs=28.06.1709
#   ls$matricula.ano/Cânones.1709/1709-06-28/obs=28.06.1709
#   ls$grau/Bacharel/1709-06-28/obs=28.06.1709
#   ls$grau.ano/Bacharel.1709/1709-06-28/obs=28.06.1709
#   pai$António Pinto/m/id=140337-pai
#     rel$function-in-act/pai/António Pinto/auc-alumni-A-140337-140771/20200211
